# %% [markdown]
# This notebook demonstrates 3.0 data model plotting programs.

# %% [markdown]
# ## getting started

# %%
#import pmagpy.ipmag as ipmag
from pmagpy import pmagplotlib
from pmagpy import pmag
from IPython.display import Image
import matplotlib as plt
import sys
# %matplotlib inline

# %% [markdown]
# ## aarm_magic.py

# %%
# !rm ../aarm_magic/specimens.txt
# !aarm_magic.py -DM 3 -WD ../aarm_magic/ -f aarm_measurements3.txt
# !cat ../aarm_magic/specimens.txt | head
# Out:
# 7  records written to file  ../aarm_magic/specimens.txt
# specimen data stored in ../aarm_magic/specimens.txt
# tab 	specimens
# aniso_ftest	aniso_ftest12	aniso_ftest23	aniso_s	aniso_s_mean	aniso_s_n_measurements	aniso_s_sigma	aniso_s_unit	aniso_tilt_correction	aniso_type	aniso_v1	aniso_v2	aniso_v3	description	experiments	method_codes	specimen
# 13.7	21.4	0.6	0.332247 : 0.302233 : 0.365520 : 0.015696 : 0.010975 : 0.041089	2.108e-05	9	0.013383	Am^2	-1	AARM	0.396615  :    18.5  :    53.8	0.309027  :   220.8  :    34.1	0.294357  :   123.5  :    10.7	Critical F: 2.6848;Critical F12/F13: 3.4668	bg2.01:AARM	LP-AN-ARM:AE-H	bg2.01
# 25.6	19.8	12.5	0.331119 : 0.327058 : 0.341823 : 0.017774 : -0.000675 : 0.040700	1.814e-05	9	0.007963	Am^2	-1	AARM	0.380002  :    17.9  :    45.3	0.329939  :   261.7  :    23.6	0.290060  :   153.7  :    35.4	Critical F: 2.6848;Critical F12/F13: 3.4668	bg2.03:AARM	LP-AN-ARM:AE-H	bg2.03
# 1.6	1.5	0.6	0.307437 : 0.316737 : 0.375826 : -0.013998 : 0.011727 : 0.039843	1.598e-05	9	0.040176	Am^2	-1	AARM	0.394445  :     9.0  :    65.7	0.325042  :   115.4  :     7.3	0.280512  :   208.5  :    23.1	Critical F: 2.6848;Critical F12/F13: 3.4668	bg2.06:AARM	LP-AN-ARM:AE-H	bg2.06
# 10.0	15.7	0.4	0.319743 : 0.285420 : 0.394837 : 0.004911 : -0.006778 : 0.086509	1.754e-05	9	0.029195	Am^2	-1	AARM	0.451649  :   358.1  :    56.8	0.287831  :   254.7  :     8.6	0.260520  :   159.3  :    31.8	Critical F: 2.6848;Critical F12/F13: 3.4668	bg2.07:AARM	LP-AN-ARM:AE-H	bg2.07
# 1.6	0.6	1.5	0.338109 : 0.353508 : 0.308383 : -0.004783 : -0.013922 : 0.108382	1.735e-05	9	0.078675	Am^2	-1	AARM	0.434654  :   348.1  :    40.8	0.351884  :    81.2  :     3.6	0.213462  :   175.4  :    49.0	Critical F: 2.6848;Critical F12/F13: 3.4668	bg2.08:AARM	LP-AN-ARM:AE-H	bg2.08
# 17.8	16.1	6.8	0.299866 : 0.314276 : 0.385859 : 0.020949 : 0.015140 : 0.003175	2.179e-05	9	0.011228	Am^2	-1	AARM	0.389554  :    68.7  :    76.4	0.325926  :   232.5  :    13.1	0.284519  :   323.3  :     3.7	Critical F: 2.6848;Critical F12/F13: 3.4668	bg2.09:AARM	LP-AN-ARM:AE-H	bg2.09
# 6.9	5.2	3.5	0.324454 : 0.328738 : 0.346808 : -0.006912 : -0.003913 : -0.045767	1.796e-05	9	0.016370	Am^2	-1	AARM	0.382770  :   177.9  :    51.7	0.330191  :   277.6  :     7.6	0.287039  :    13.4  :    37.2	Critical F: 2.6848;Critical F12/F13: 3.4668	bg2.12:AARM	LP-AN-ARM:AE-H	bg2.12

# %% [markdown]
# ## aniso_magic.py

# %%
# !aniso_magic.py -WD ../3_0/McMurdo/ -B -x -par -crd g -f specimens.txt \
-fsa samples.txt -fsi sites.txt -sav -fmt png
# Out:
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# 1  saved in  McMurdo_s_aniso-data.png
# 2  saved in  McMurdo_s_aniso-conf.png

# %%
Image("McMurdo_s_aniso-data.png")

# %%
Image("McMurdo_s_aniso-conf.png")

# %% [markdown]
# ## atrm_magic.py

# %%
# !rm ../atrm_magic/specimens.txt
# !atrm_magic.py -WD ../atrm_magic -f atrm_measurements3.txt
# !cat ../atrm_magic/specimens.txt | head
# Out:
# 30  records written to file  ../atrm_magic/specimens.txt
# specimen data stored in ../atrm_magic/specimens.txt
# tab 	specimens
# aniso_ftest	aniso_ftest12	aniso_ftest23	aniso_s	aniso_s_mean	aniso_s_n_measurements	aniso_s_sigma	aniso_s_unit	aniso_tilt_correction	aniso_type	aniso_v1	aniso_v2	aniso_v3	description	experiments	method_codes	specimen
# 15.8	2.8	19.5	0.320620 : 0.340852 : 0.338528 : 0.010075 : -0.002932 : 0.027117	1.948e-08	6	0.006994	Am^2	-1	ATRM	0.358892  :    19.3  :    50.4	0.342419  :   266.5  :    17.8	0.298689  :   163.9  :    34.0	Critical F: 3.1059;Critical F12/F13: 3.8853	ak01a:ATRM	LP-AN-TRM:AE-H	ak01a
# 1.8	0.2	2.5	0.351180 : 0.343893 : 0.304926 : 0.001119 : -0.000509 : -0.012140	7.400e-09	6	0.018660	Am^2	-1	ATRM	0.354313  :   186.8  :    13.8	0.343755  :    96.5  :     1.3	0.301933  :     1.3  :    76.2	Critical F: 3.1059;Critical F12/F13: 3.8853	ak01b:ATRM	LP-AN-TRM:AE-H	ak01b
# 7.1	0.4	10.9	0.339590 : 0.327797 : 0.332613 : -0.027877 : 0.023913 : 0.016300	2.045e-08	6	0.013637	Am^2	-1	ATRM	0.362559  :   136.5  :     8.8	0.350488  :    33.1  :    56.2	0.286953  :   232.1  :    32.3	Critical F: 3.1059;Critical F12/F13: 3.8853	ak01c:ATRM	LP-AN-TRM:AE-H	ak01c
# 3.3	0.1	5.5	0.315177 : 0.343196 : 0.341626 : -0.000310 : 0.001497 : 0.009358	1.674e-08	6	0.009116	Am^2	-1	ATRM	0.345411  :    64.4  :    54.9	0.342406  :   281.7  :    29.2	0.312183  :   181.5  :    17.7	Critical F: 3.1059;Critical F12/F13: 3.8853	ak01d:ATRM	LP-AN-TRM:AE-H	ak01d
# 20.5	9.7	16.2	0.350156 : 0.345154 : 0.304690 : 0.019606 : -0.010957 : 0.012371	1.322e-08	6	0.007063	Am^2	-1	ATRM	0.367495  :    40.5  :     2.1	0.336349  :   309.4  :    27.3	0.296157  :   134.5  :    62.6	Critical F: 3.1059;Critical F12/F13: 3.8853	ak03a:ATRM	LP-AN-TRM:AE-H	ak03a
# 7.9	1.5	9.4	0.344158 : 0.306198 : 0.349644 : -0.003284 : -0.020702 : 0.004837	8.963e-09	6	0.010188	Am^2	-1	ATRM	0.359991  :   313.7  :    60.5	0.342129  :   186.2  :    19.0	0.297879  :    88.3  :    21.7	Critical F: 3.1059;Critical F12/F13: 3.8853	ak03b:ATRM	LP-AN-TRM:AE-H	ak03b
# 102.8	7.8	150.7	0.302977 : 0.350641 : 0.346382 : 0.002240 : -0.006580 : 0.016298	1.020e-08	6	0.002803	Am^2	-1	ATRM	0.356930  :   285.4  :    45.3	0.345867  :    69.4  :    38.6	0.297204  :   175.2  :    18.9	Critical F: 3.1059;Critical F12/F13: 3.8853	ak03c:ATRM	LP-AN-TRM:AE-H	ak03c
# 12.8	4.2	12.5	0.341299 : 0.310807 : 0.347894 : 0.010964 : -0.003338 : -0.008051	2.305e-08	6	0.006057	Am^2	-1	ATRM	0.355190  :   198.9  :    50.0	0.337549  :    16.7  :    40.0	0.307261  :   107.6  :     1.0	Critical F: 3.1059;Critical F12/F13: 3.8853	ak04a:ATRM	LP-AN-TRM:AE-H	ak04a

# %% [markdown]
# ## dayplot_magic.py

# %%
# !dayplot_magic.py -WD ../3_0/McMurdo -f specimens.txt -sav -fmt png
# Out:
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# 1  saved in  _day.png
# 2  saved in  _S-Bc.png
# 3  saved in  _S-Bcr.png

# %%
Image("_day.png")

# %% [markdown]
# ## dmag_magic.py

# %%
# !dmag_magic.py -WD ../3_0/McMurdo -fsp specimens.txt -obj spc -sav -fmt "png" -LT T |tail
# Out:
# /Users/nebula/anaconda/lib/python3.6/site-packages/past/utils/__init__.py:95: RuntimeWarning: invalid value encountered in double_scalars
#   return a / b
# 1  saved in  mc49e_LT-T-Z.png
# 1  saved in  mc49g_LT-T-Z.png
# 1  saved in  mc49h_LT-T-Z.png
# 1  saved in  mc50a_LT-T-Z.png
# 1  saved in  mc50b_LT-T-Z.png
# 1  saved in  mc50c_LT-T-Z.png
# 1  saved in  mc50e_LT-T-Z.png
# 1  saved in  mc50f_LT-T-Z.png
# 1  saved in  mc50g_LT-T-Z.png
# 1  saved in  mc50h_LT-T-Z.png

# %%
Image(filename="mc01a_LT-T-Z.png")

# %%
Image("mc141c1_LT-T-Z.png")

# %%
# !dmag_magic.py -WD ../3_0/McMurdo -fsp specimens.txt \
-fsa samples.txt -obj sit -sav -fmt "png" -LT T
# Out:
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# 25470  records read from  measurements.txt
# 1  saved in  mc01_LT-T-Z.png
# 1  saved in  mc02_LT-T-Z.png
# 1  saved in  mc03_LT-T-Z.png
# 1  saved in  mc04_LT-T-Z.png
# 1  saved in  mc06_LT-T-Z.png
# 1  saved in  mc07_LT-T-Z.png
# 1  saved in  mc08_LT-T-Z.png
# 1  saved in  mc09_LT-T-Z.png
# 1  saved in  mc10_LT-T-Z.png
# 1  saved in  mc100_LT-T-Z.png
# 1  saved in  mc102_LT-T-Z.png
# 1  saved in  mc103_LT-T-Z.png
# 1  saved in  mc104_LT-T-Z.png
# 1  saved in  mc105_LT-T-Z.png
# 1  saved in  mc107_LT-T-Z.png
# 1  saved in  mc108_LT-T-Z.png
# 1  saved in  mc109_LT-T-Z.png
# /Users/nebula/anaconda/lib/python3.6/site-packages/past/utils/__init__.py:95: RuntimeWarning: invalid value encountered in double_scalars
#   return a / b
# 1  saved in  mc11_LT-T-Z.png
# 1  saved in  mc110_LT-T-Z.png
# 1  saved in  mc111_LT-T-Z.png
# 1  saved in  mc112_LT-T-Z.png
# 1  saved in  mc113_LT-T-Z.png
# 1  saved in  mc115_LT-T-Z.png
# 1  saved in  mc116_LT-T-Z.png
# 1  saved in  mc117_LT-T-Z.png
# 1  saved in  mc119_LT-T-Z.png
# 1  saved in  mc120_LT-T-Z.png
# 1  saved in  mc121_LT-T-Z.png
# 1  saved in  mc122_LT-T-Z.png
# 1  saved in  mc123_LT-T-Z.png
# 1  saved in  mc124_LT-T-Z.png
# 1  saved in  mc125_LT-T-Z.png
# 1  saved in  mc126_LT-T-Z.png
# 1  saved in  mc127_LT-T-Z.png
# 1  saved in  mc128_LT-T-Z.png
# 1  saved in  mc129_LT-T-Z.png
# 1  saved in  mc13_LT-T-Z.png
# 1  saved in  mc130_LT-T-Z.png
# 1  saved in  mc131_LT-T-Z.png
# 1  saved in  mc132_LT-T-Z.png
# 1  saved in  mc133_LT-T-Z.png
# 1  saved in  mc134_LT-T-Z.png
# 1  saved in  mc135_LT-T-Z.png
# 1  saved in  mc136_LT-T-Z.png
# 1  saved in  mc139_LT-T-Z.png
# 1  saved in  mc14_LT-T-Z.png
# 1  saved in  mc140_LT-T-Z.png
# 1  saved in  mc141_LT-T-Z.png
# 1  saved in  mc142_LT-T-Z.png
# 1  saved in  mc144_LT-T-Z.png
# 1  saved in  mc145_LT-T-Z.png
# 1  saved in  mc146_LT-T-Z.png
# 1  saved in  mc147_LT-T-Z.png
# 1  saved in  mc148_LT-T-Z.png
# 1  saved in  mc149_LT-T-Z.png
# 1  saved in  mc15_LT-T-Z.png
# 1  saved in  mc152_LT-T-Z.png
# 1  saved in  mc153_LT-T-Z.png
# 1  saved in  mc154_LT-T-Z.png
# 1  saved in  mc155_LT-T-Z.png
# 1  saved in  mc156_LT-T-Z.png
# 1  saved in  mc157_LT-T-Z.png
# 1  saved in  mc158_LT-T-Z.png
# 1  saved in  mc160_LT-T-Z.png
# 1  saved in  mc161_LT-T-Z.png
# 1  saved in  mc162_LT-T-Z.png
# 1  saved in  mc163_LT-T-Z.png
# 1  saved in  mc164_LT-T-Z.png
# 1  saved in  mc165_LT-T-Z.png
# 1  saved in  mc166_LT-T-Z.png
# 1  saved in  mc167_LT-T-Z.png
# 1  saved in  mc168_LT-T-Z.png
# 1  saved in  mc19_LT-T-Z.png
# 1  saved in  mc20_LT-T-Z.png
# 1  saved in  mc200_LT-T-Z.png
# 1  saved in  mc201_LT-T-Z.png
# 1  saved in  mc202_LT-T-Z.png
# 1  saved in  mc203_LT-T-Z.png
# 1  saved in  mc204_LT-T-Z.png
# 1  saved in  mc205_LT-T-Z.png
# 1  saved in  mc206_LT-T-Z.png
# 1  saved in  mc207_LT-T-Z.png
# 1  saved in  mc208_LT-T-Z.png
# 1  saved in  mc209_LT-T-Z.png
# 1  saved in  mc21_LT-T-Z.png
# 1  saved in  mc210_LT-T-Z.png
# 1  saved in  mc211_LT-T-Z.png
# 1  saved in  mc212_LT-T-Z.png
# 1  saved in  mc213_LT-T-Z.png
# 1  saved in  mc214_LT-T-Z.png
# 1  saved in  mc215_LT-T-Z.png
# 1  saved in  mc216_LT-T-Z.png
# 1  saved in  mc217_LT-T-Z.png
# 1  saved in  mc218_LT-T-Z.png
# 1  saved in  mc219_LT-T-Z.png
# 1  saved in  mc220_LT-T-Z.png
# 1  saved in  mc221_LT-T-Z.png
# 1  saved in  mc222_LT-T-Z.png
# 1  saved in  mc223_LT-T-Z.png
# 1  saved in  mc224_LT-T-Z.png
# 1  saved in  mc225_LT-T-Z.png
# 1  saved in  mc226_LT-T-Z.png
# 1  saved in  mc227_LT-T-Z.png
# 1  saved in  mc228_LT-T-Z.png
# 1  saved in  mc229_LT-T-Z.png
# 1  saved in  mc26_LT-T-Z.png
# 1  saved in  mc28_LT-T-Z.png
# 1  saved in  mc29_LT-T-Z.png
# 1  saved in  mc30_LT-T-Z.png
# 1  saved in  mc31_LT-T-Z.png
# 1  saved in  mc32_LT-T-Z.png
# 1  saved in  mc33_LT-T-Z.png
# 1  saved in  mc34_LT-T-Z.png
# 1  saved in  mc35_LT-T-Z.png
# 1  saved in  mc36_LT-T-Z.png
# 1  saved in  mc37_LT-T-Z.png
# 1  saved in  mc38_LT-T-Z.png
# 1  saved in  mc39_LT-T-Z.png
# 1  saved in  mc40_LT-T-Z.png
# 1  saved in  mc41_LT-T-Z.png
# 1  saved in  mc42_LT-T-Z.png
# 1  saved in  mc43_LT-T-Z.png
# 1  saved in  mc44_LT-T-Z.png
# 1  saved in  mc48_LT-T-Z.png
# 1  saved in  mc49_LT-T-Z.png
# 1  saved in  mc50_LT-T-Z.png

# %%
Image(filename="mc01_LT-T-Z.png")

# %% [markdown]
# ## eqarea_magic.py

# %%
# !eqarea_magic.py -WD ../3_0/McMurdo -f sites.txt -sav -fmt "png"
# Out:
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# 1  saved in  McMurdo_mc01_g_eqarea.png

# %%
Image(filename="McMurdo_mc01_g_eqarea.png")

# %% [markdown]
# ## quick_hyst.py

# %%
# !quick_hyst.py -WD ../3_0/McMurdo -spc mc04c-1 -fmt png
#Image("LO___SI___SA___SP__mc04c-1_TY__hyst_.png")
# Out:
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# ['mc04c-1' 'mc113a1-1' 'mc117a2-1' 'mc120a2-1' 'mc129a1-1' 'mc164a2-1'
#  'mc205a1-1' 'mc217a2-1']
# working on t:  273
# 1  saved in  McMurdo_mc04c_mc04c_mc04c-1_hyst.png

# %%
Image("McMurdo_mc04c_mc04c_mc04c-1_hyst.png")

# %% [markdown]
# ## vgpmap_magic.py

# %%
# !vgpmap_magic.py -WD ../3_0/McMurdo -f sites.txt -crd g -prj ortho -eye 60 0  -sym ko 10 -fmt png -S -sav
# Out:
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# /Users/nebula/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# 1  saved in  McMurdo_VGP_map.png

# %%
Image("McMurdo_VGP_map.png")

# %% [markdown]
# ## zeq_magic.py

# %%
# !zeq_magic.py -WD ../3_0/McMurdo -spc mc01a -fmt png
# should be a test here....
# Out:
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# mc01a 1 out of  1038
# mc01b 2 out of  1038
# mc01c 3 out of  1038
# mc01d 4 out of  1038
# mc01e 5 out of  1038
# mc01f 6 out of  1038
# 1  saved in  mc01f_eqarea.png
# 2  saved in  mc01f_zijd.png
# 3  saved in  mc01f_demag.png

# %% [markdown]
# ## cleanup

# %%
# !rm sites.txt samples.txt specimens.txt measurements.txt ages.txt contribution.txt images.txt criteria.txt locations.txt
# !rm *.png
# !rm *.jpg
# !rm ../3_0/McMurdo/_*.txt
# !rm ../3_0/McMurdo/fancy_sites.txt
# !rm ../3_0/Osler/_*.txt
# !rm ../3_0/_*.txt
# !rm stored.json
# !rm _*.txt
# Out:
# rm: sites.txt: No such file or directory
# rm: samples.txt: No such file or directory
# rm: measurements.txt: No such file or directory
# rm: ages.txt: No such file or directory
# rm: contribution.txt: No such file or directory
# rm: images.txt: No such file or directory
# rm: criteria.txt: No such file or directory
# rm: locations.txt: No such file or directory
# rm: *.jpg: No such file or directory
# rm: ../3_0/McMurdo/_*.txt: No such file or directory
# rm: ../3_0/McMurdo/fancy_sites.txt: No such file or directory
# rm: ../3_0/Osler/_*.txt: No such file or directory
# rm: ../3_0/_*.txt: No such file or directory
# rm: stored.json: No such file or directory
# rm: _*.txt: No such file or directory
