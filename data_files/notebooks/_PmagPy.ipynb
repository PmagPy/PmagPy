# %% [markdown]
# This notebook tests the PmagPy distribution files using the examples in the PmagPy cookbook:  http://earthref.org/PmagPy/
#
# It is meant to function from within the PmagPy data_files/notebooks directory and calls are relative to that.
# To specify a working directory, many programs have the hidden command line argument -WD.

# %%
#import pmagpy.ipmag as ipmag
import pmagpy.pmagplotlib as pmagplotlib
import pmagpy.pmag as pmag
from IPython.display import Image
import matplotlib as plt
basemap_present = True
try: 
    from mpl_toolkits.basemap import Basemap
except ImportError:
    print("Your Python installation doesn't have Basemap.  You won't be able to run certain plotting programs")
    basemap_present = False

# %matplotlib inline

# %% [markdown]
# # aarm_magic.py

# %%
# !sio_magic2.py -f ../aarm_magic/arm_magic_example.dat -loc Bushveld -LP AF:ANI \
    -F ../aarm_magic/aarm_measurements.txt -ncn 3 -ac 180 -dc 50 -1 -1
# Out:
# 126  records written to file  ../aarm_magic/aarm_measurements.txt
# results put in  ../aarm_magic/aarm_measurements.txt

# %%
# !aarm_magic.py -f ../aarm_magic/aarm_measurements.txt
# Out:
# 7  records written to file  ./arm_anisotropy.txt
# specimen tensor elements stored in  ./arm_anisotropy.txt
# 7  records written to file  ./aarm_results.txt
# specimen statistics and eigenparameters stored in  ./aarm_results.txt

# %% [markdown]
# # angle.py

# %%
# !angle.py -f ../angle/angle.dat | tail
# Out:
#   107.1
#   115.8
#   111.3
#   124.6
#    88.1
#    66.9
#    99.9
#    76.7
#    71.4
#   100.8

# %% [markdown]
# # ANI_depthplot.py

# %%
# !ani_depthplot.py -f ../ani_depthplot/rmag_anisotropy.txt -fsa ../ani_depthplot/er_samples.txt \
    -fb ../ani_depthplot/magic_measurements.txt -sav -fmt png
Image(filename='U1361A_ani_depthplot.png')
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fa
# -
# -I- using default for arg: fsum
# -
# -I- using default for arg: ds
# -
# -I- using default for arg: d
# -
# Saved file: U1361A_ani_depthplot.png in folder: /Users/nebula/Python/PmagPy/data_files/notebooks

# %% [markdown]
# # aniso_magic2.py

# %%
# !aniso_magic2.py -f ../aniso_magic/dike_anisotropy.txt -gtc 110 2 -par -v -crd g \
   -F ../aniso_magic/rmag_results.txt -fmt png -sav
# Out:
# 2017-05-11 15:50:20.290 python[27773:18248015] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:20.304 python[27773:18248015] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:20.450 python[27773:18248015] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:20.463 python[27773:18248015] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:20.567 python[27773:18248015] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:20.580 python[27773:18248015] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Doing bootstrap - be patient
# 1  saved in  Scripps Beach_g_TY__aniso-data_.png
# 3  saved in  Scripps Beach_g_TY__aniso-tcdf_.png
# 2  saved in  Scripps Beach_g_TY__aniso-conf_.png
# 7  records written to file  ./../aniso_magic/rmag_results.txt

# %%
Image(filename='Scripps Beach_g_TY__aniso-tcdf_.png')

# %%
Image(filename='Scripps Beach_g_TY__aniso-data_.png')

# %%
Image(filename='Scripps Beach_g_TY__aniso-conf_.png')

# %% [markdown]
# # apwp.py

# %%
# !apwp.py -f ../apwp/apwp_example.dat
# Out:
#    100.0    38.8   352.4    58.1    81.5   198.3

# %% [markdown]
# # atrm_magic.py

# %%
# !sio_magic2.py -f ../atrm_magic/atrm_magic_example.dat -loc Africa -LP T:ANI\
    -F ../atrm_magic/atrm_measurements.txt -ncn 1 -dc 40 -1 -1
# Out:
# 210  records written to file  ../atrm_magic/atrm_measurements.txt
# results put in  ../atrm_magic/atrm_measurements.txt

# %%
# !atrm_magic.py -f ../atrm_magic/atrm_measurements.txt\
   -Fa ../atrm_magic/trm_anisotropy.txt -Fr ../atrm_magic/atrm_results.txt
# Out:
# 30  records written to file  ./../atrm_magic/trm_anisotropy.txt
# specimen tensor elements stored in  ./../atrm_magic/trm_anisotropy.txt
# 30  records written to file  ./../atrm_magic/atrm_results.txt
# specimen statistics and eigenparameters stored in  ./../atrm_magic/atrm_results.txt

# %% [markdown]
# # azdip_magic.py

# %%
# !azdip_magic.py -f ../azdip_magic/azdip_magic_example.dat -ncn 1\
   -mcd FS-FD:SO-POM -loc "Northern Iceland" -F ../azdip_magic/er_samples.txt
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: app
# -
# checked_args: [['f', '../azdip_magic/azdip_magic_example.dat'], ['ncn', '1'], ['mcd', 'FS-FD:SO-POM'], ['loc', 'Northern', 'Iceland'], ['F', '../azdip_magic/er_samples.txt'], ['A', ''], ['WD', '.'], ['ID', '.'], ['Fsa', 'er_samples.txt'], ['Fsi', 'er_sites.txt'], ['app', False]]
# 916  records written to file  ./er_samples.txt
# Data saved in  ./er_samples.txt

# %% [markdown]
# # b_vdm.py

# %%
# !b_vdm.py -f ../b_vdm/b_vdm_example.dat
# Out:
#  7.159e+22

# %% [markdown]
# # basemap_magic.py

# %% [markdown]
# basemap_magic doesn't work anymore.

# %% [markdown]
# # biplot_magic.py

# %%
# !biplot_magic.py -f ../biplot_magic/biplot_magic_example.dat \
       -x LP-X -y LT-AF-I -fmt png -sav
# Out:
# 2017-05-11 15:50:33.980 python[27851:18249368] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:33.992 python[27851:18249368] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# LP-X  selected for X axis
# LT-AF-I  selected for Y axis
# All
# measurement_magn_mass  being used for plotting Y
# measurement_chi_mass  being used for plotting X.
# 1  saved in  All_fig.png

# %%
Image(filename='All_fig.png')

# %% [markdown]
# # bootams.py

# %%
# !bootams.py -par -f ../bootams/bootams_example.dat
# Out:
# Doing bootstrap - be patient
#
# tau tau_sigma V_dec V_inc V_eta V_eta_dec V_eta_inc V_zeta V_zeta_dec V_zeta_inc
#
# 0.33505 0.00021     5.3    14.7    10.8   266.3    29.4    25.1   120.2    55.8
# 0.33334 0.00022   124.5    61.7    19.2   236.1    11.1    23.3   331.2    24.3
# 0.33161 0.00026   268.8    23.6    10.4     6.8    18.5    20.8   131.2    59.3

# %% [markdown]
# # cart_dir.py

# %%
# !cart_dir.py -f ../cart_dir/cart_dir_example.dat
# Out:
#   340.0    65.0  1.000e+00
#   176.0   -55.0  1.000e+00

# %% [markdown]
# ## chartmaker.py

# %% [markdown]
# You can't do chartmaker from within the notebook.  And chi_magic.py is still a bit buggy (problem with legend and 4th plot still shows up.)

# %% [markdown]
# ## chi_magic.py

# %%
# !chi_magic.py -f ../chi_magic/chi_magic_example.dat -fmt png -sav
# Out:
# IRM-Kappa-2352 1 out of  2
# IRM-OldBlue-1892 2 out of  2
# 2017-05-11 15:50:45.220 python[27888:18250339] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:45.460 python[27888:18250339] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:46.068 python[27888:18250339] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:46.079 python[27888:18250339] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:46.221 python[27888:18250339] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:46.231 python[27888:18250339] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Skipping susceptibitily - AC field plot as a function of temperature
# 2  saved in  IRM-OldBlue-1892_2.png
# 3  saved in  IRM-OldBlue-1892_3.png
# 1  saved in  IRM-OldBlue-1892_1.png

# %%
Image(filename='IRM-OldBlue-1892_1.png')

# %%
Image(filename='IRM-OldBlue-1892_3.png')

# %%
Image(filename='IRM-OldBlue-1892_2.png')

# %% [markdown]
# ## common_mean.py

# %%
# !common_mean.py -f ../common_mean/common_mean_ex_file1.dat\
   -f2 ../common_mean/common_mean_ex_file2.dat -sav -fmt png
# Out:
# Doing first set of directions, please be patient..
# Doing second  set of directions, please be patient..
# 2017-05-11 15:50:49.849 python[27904:18250914] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:49.860 python[27904:18250914] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:49.972 python[27904:18250914] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:49.983 python[27904:18250914] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:50.105 python[27904:18250914] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:50.117 python[27904:18250914] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 3  saved in  CD_Z.png
# 1  saved in  CD_X.png
# 2  saved in  CD_Y.png

# %%
Image(filename='CD_X.png')

# %%
Image(filename='CD_Y.png')

# %%
Image(filename='CD_Z.png')

# %% [markdown]
# ## cont_rot.py

# %%
# !cont_rot.py -con af:sam -prj ortho\
    -eye -20 0 -sym k-  1 -age 180 -res l  -fmt png -sav
# Out:
# 2017-05-11 15:50:52.448 python[27920:18251578] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:50:52.460 python[27920:18251578] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Cont_rot.png

# %%
if basemap_present:
    image = Image(filename="Cont_rot.png")
else: 
    image = None
image

# %% [markdown]
# # convert_samples.py

# %%
# !convert_samples.py -f ../convert_samples/convert_samples_example.dat\
   -F ../convert_samples/orient_Northern_Iceland.txt
# Out:
# file_type er_samples
# 916  records written to file  ./../convert_samples/orient_Northern_Iceland.txt
# Data saved in:  ./../convert_samples/orient_Northern_Iceland.txt

# %% [markdown]
# ## core_depthplot.py

# %%
# !core_depthplot.py -fsa ../core_depthplot/er_samples.txt -LP AF 15 \
    -f ../core_depthplot/magic_measurements.txt -log \
    -d 50 150 -ts gts12 23 34 -D -fmt png -sav
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fsum
# -
# -I- using default for arg: fwig
# -
# -I- using default for arg: fa
# -
# -I- using default for arg: fsp
# -
# -I- using default for arg: fres
# -
# -I- using default for arg: n
# -
# -I- using default for arg: L
# -
# -I- using default for arg: S
# -
# -I- using default for arg: I
# -
# -I- using default for arg: M
# -
# -I- using default for arg: ds
# -
# -I- using default for arg: sym
# -
# 9328  measurements read in from  ./../core_depthplot/magic_measurements.txt
# spec file found

# %%
Image(filename='DSDP Site 522_m__LT-AF-Z_core-depthplot.png')

# %% [markdown]
# # curie.py

# %%
# !curie.py -f ../curie/curie_example.dat -w 10 -fmt png -sav
# Out:
# 2017-05-11 15:51:16.622 python[27987:18255070] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:16.635 python[27987:18255070] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:16.827 python[27987:18255070] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:16.839 python[27987:18255070] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:17.013 python[27987:18255070] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:17.024 python[27987:18255070] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# second derivative maximum is at T=552
# 2017-05-11 15:51:17.438 python[27987:18255070] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:17.456 python[27987:18255070] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  M_T.png
# 3  saved in  der2.png
# 4  saved in  Curie.png
# 2  saved in  der1.png

# %%
Image(filename='M_T.png')

# %% [markdown]
# # customize_criteria.py

# %% [markdown]
# You can't use customize_criteria in the notebook.

# %% [markdown]
# # dayplot_magic2.py

# %%
# !dayplot_magic2.py -WD ../dayplot_magic/ -f dayplot_magic_example.dat \
    -fmt png -sav
# Out:
# 2017-05-11 15:51:20.102 python[28012:18255641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:20.118 python[28012:18255641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:20.239 python[28012:18255641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:20.249 python[28012:18255641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:20.381 python[28012:18255641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:20.391 python[28012:18255641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:20.484 python[28012:18255641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:20.494 python[28012:18255641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2  saved in  unknown_S-Bc.png
# 3  saved in  unknown_S-Bcr.png
# 1  saved in  unknown_day.png

# %%
Image(filename='unknown_day.png')

# %% [markdown]
# # demag_gui.py

# %% [markdown]
# Use demag_gui.py from the command line or from within pmag_gui.py (Pmag GUI).

# %% [markdown]
# # di_eq.py

# %%
# !di_eq.py -f ../di_eq/di_eq_example.dat | tail #|head
# Out:
# 0.393981 0.117451
# -0.017726 0.406002
# 0.154273 0.367000
# 0.213903 0.335760
# 0.103221 0.372202
# 0.231833 0.283245
# 0.072160 0.351538
# 0.007802 0.319236
# 0.152583 0.265350
# 0.248133 0.136412

# %% [markdown]
# # di_geo.py

# %%
# !di_geo.py -f ../di_geo/di_geo_example.dat -F ../di_geo/di_geo.out
# Out:
# ../di_geo/di_geo.out  opened for output

# %% [markdown]
# # di_rot.py

# %%
# !eqarea.py -f ../di_geo/di_geo.out -fmt png -sav
# Out:
# 2017-05-11 15:51:27.339 python[28066:18256614] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:27.351 python[28066:18256614] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  di_geo_eq.png

# %%
Image(filename='di_geo_eq.png')

# %%
# !fishrot.py -I 42 > ../di_rot/fishrot.out
# !gofish.py -f ../di_rot/fishrot.out
# Out:
#   358.9    43.3    100    94.8563     19.2     3.3    18.5

# %%
# !di_rot.py -f ../di_rot/fishrot.out -F ../di_rot/dirot.out -D 359.3 -I 42.1
# !eqarea.py -f ../di_rot/fishrot.out -fmt png -sav
# Out:
# 2017-05-11 15:51:34.821 python[28144:18257279] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:34.834 python[28144:18257279] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  fishrot_eq.png

# %%
Image(filename='fishrot_eq.png')

# %%
# !eqarea.py -f ../di_rot/dirot.out -fmt png -sav
# Out:
# 2017-05-11 15:51:36.854 python[28160:18257416] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:36.867 python[28160:18257416] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  dirot_eq.png

# %%
Image(filename='dirot_eq.png')

# %% [markdown]
# # di_tilt.py

# %%
# !di_tilt.py < ../di_tilt/di_tilt_example.dat | tail
# Out:
#   179.6   -27.0
#   180.1   -29.0
#   172.0   -47.0
#   171.0   -38.9
#   177.8   -58.0
#   195.0   -25.7
#   188.4   -56.8
#   166.3   -27.0
#   182.3   -57.6
#   181.9   -40.0

# %% [markdown]
# # di_vgp.py

# %%
# !di_vgp.py -f ../di_vgp/di_vgp_example.dat
# Out:
#   154.7    77.3
#     6.6   -69.6

# %% [markdown]
# # dipole_pinc.py

# %%
# !dipole_pinc.py -f ../dipole_pinc/dipole_pinc_example.dat
# Out:
#   -41.7

# %% [markdown]
# # dipole_plat.py

# %%
# !dipole_plat.py -f ../dipole_plat/dipole_plat_example.dat
# Out:
#    12.0

# %% [markdown]
# # dir_cart.py

# %%
# !dir_cart.py -f ../dir_cart/dir_cart_example.dat
# Out:
# 8.4859e-01 3.0886e-01 9.3514e-01
# -3.8223e+00 3.3441e-01 -1.7083e+00

# %% [markdown]
# # dmag_magic2.py

# %%
# !dmag_magic2.py -f ../dmag_magic/dmag_magic_example.dat -LT AF -fmt png -sav
# Out:
# 2017-05-11 15:51:49.300 python[28217:18259038] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:49.312 python[28217:18259038] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 5921  records read from  ../dmag_magic/dmag_magic_example.dat
# 1  saved in  McMurdo_LT-AF-Z.png

# %%
Image(filename='McMurdo_LT-AF-Z.png')

# %% [markdown]
# # download_magic.py

# %%
# !download_magic.py -WD ../download_magic -f ../download_magic/zmab0083201tmp03.txt
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: O
# -
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/download_magic.py", line 54, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/download_magic.py", line 49, in main
#     ipmag.download_magic(infile, dir_path, input_dir_path, overwrite, data_model)
#   File "/Users/nebula/Python/PmagPy/pmagpy/ipmag.py", line 2926, in download_magic
#     infile = f.readlines()
#   File "/Users/nebula/anaconda/lib/python3.5/codecs.py", line 321, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa1 in position 6048: invalid start byte

# %% [markdown]
# # eigs_s.py

# %%
# !eigs_s.py -f ../eigs_s/eigs_s_example.dat
# Out:
# 0.33416328 0.33280227 0.33303446 -0.00016631 0.00123163 0.00135521
# 0.33555713 0.33197427 0.33246869 0.00085685 0.00025266 0.00098151
# 0.33585301 0.33140355 0.33274350 0.00132308 0.00117787 0.00000455
# 0.33479390 0.33140817 0.33379796 -0.00043088 0.00048858 0.00045610
# 0.33502916 0.33117944 0.33379149 -0.00106313 0.00029828 0.00035883
# 0.33407047 0.33226910 0.33366045 -0.00000638 0.00098445 0.00005996
# 0.33486328 0.33215088 0.33298591 -0.00034279 0.00038178 0.00020145
# 0.33509853 0.33195898 0.33294258 0.00076976 0.00056717 0.00011960

# %% [markdown]
# # eq_di.py

# %%
# !eq_di.py -f ../eq_di/eq_di_example.dat > ../eq_di/eq_di.out
# !eqarea.py -f ../eq_di/eq_di.out -fmt png -sav
# Out:
# 2017-05-11 15:51:59.518 python[28264:18260063] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:51:59.530 python[28264:18260063] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  eq_di_eq.png

# %%
Image(filename='eq_di_eq.png')

# %% [markdown]
# # eqarea.py

# %%
# !eqarea.py -f ../eqarea/fishrot.out -fmt png -sav
# Out:
# 2017-05-11 15:52:01.486 python[28280:18260493] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:01.498 python[28280:18260493] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  fishrot_eq.png

# %%
Image(filename='fishrot_eq.png')

# %% [markdown]
# # eqarea_ell.py

# %%
# !eqarea_ell.py -f ../eqarea_ell/tk03.out -ell B -fmt png -sav
# Out:
# 2017-05-11 15:52:03.432 python[28305:18260663] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:03.443 python[28305:18260663] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
#      Zeta     4.5
#      dec   357.8
#      inc    60.3
#      Edec   105.7
#      n        20
#      Eta     4.5
#      Einc    10.0
#      Zdec    21.0
#      Zinc   -27.6
# 1  saved in  ..-eqarea_ell-tk03.out_eq.png

# %%
Image(filename='..-eqarea_ell-tk03.out_eq.png')

# %% [markdown]
# # eqarea_magic2.py

# %%
# !eqarea_magic2.py -obj loc -crd g -f ../eqarea_magic/pmag_results.txt\
    -ell Be -fmt png -sav
# Out:
# 2017-05-11 15:52:05.494 python[28321:18260951] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:05.505 python[28321:18260951] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  Snake_River_gu_eqarea.png

# %%
Image(filename='Snake_River_gu_eqarea.png')

# %% [markdown]
# # find_EI.py

# %%
# !find_EI.py -f ../find_EI/find_EI_example.dat -fmt png -sav
# Out:
# 2017-05-11 15:52:08.832 python[28348:18261244] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:08.844 python[28348:18261244] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:08.988 python[28348:18261244] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:09.006 python[28348:18261244] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:09.061 python[28348:18261244] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:09.073 python[28348:18261244] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:09.129 python[28348:18261244] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:52:09.141 python[28348:18261244] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Bootstrapping.... be patient
# 25  out of  1000
# 50  out of  1000
# 75  out of  1000
# 100  out of  1000
# 125  out of  1000
# 150  out of  1000
# 175  out of  1000
# 200  out of  1000
# 225  out of  1000
# 250  out of  1000
# 275  out of  1000
# 300  out of  1000
# 325  out of  1000
# 350  out of  1000
# 375  out of  1000
# 400  out of  1000
# 425  out of  1000
# 450  out of  1000
# 475  out of  1000
# 500  out of  1000
# 525  out of  1000
# 550  out of  1000
# 575  out of  1000
# 600  out of  1000
# 625  out of  1000
# 650  out of  1000
# 675  out of  1000
# 700  out of  1000
# 725  out of  1000
# 750  out of  1000
# 775  out of  1000
# 800  out of  1000
# 825  out of  1000
# 850  out of  1000
# 875  out of  1000
# 900  out of  1000
# 925  out of  1000
# 950  out of  1000
# 975  out of  1000
# 1000  out of  1000
# 1  saved in  findEI_eq.png
# 2  saved in  findEI_ei.png
# 3  saved in  findEI_cdf.png
# 4  saved in  findEI_v2.png

# %%
Image(filename='findEI_ei.png')

# %%
Image(filename='findEI_cdf.png')

# %%
Image(filename='findEI_eq.png')

# %%
Image(filename='findEI_v2.png')

# %% [markdown]
# # fisher.py

# %%
# !fisher.py -k 30 -n 10 |head
# Out:
#   220.3    69.7
#   114.6    82.4
#   193.6    74.2
#   173.8    85.1
#    56.6    83.8
#   206.5    74.0
#   271.8    87.8
#   241.9    74.6
#   267.9    86.2
#   213.7    71.1

# %% [markdown]
# # fishqq.py

# %%
# !fishqq.py -f ../fishqq/fishqq_example.txt -fmt png -sav
# Out:
# 2017-05-11 15:53:08.634 python[28498:18265951] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:53:08.650 python[28498:18265951] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:53:08.768 python[28498:18265951] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:53:08.782 python[28498:18265951] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  ..-fishqq-fishqq_example.txt_unf1.png
# 2  saved in  ..-fishqq-fishqq_example.txt_exp1.png

# %%
Image(filename='..-fishqq-fishqq_example.txt_unf1.png')

# %%
Image(filename='..-fishqq-fishqq_example.txt_exp1.png')

# %% [markdown]
# # fishrot.py

# %%
# !fishrot.py -n 5 -D 33 -I 41 -k 50
# Out:
#    44.7    32.2
#    38.7    40.7
#    36.4    53.6
#    26.8    36.3
#    34.0    42.4

# %% [markdown]
# # foldtest.py

# %%
# !foldtest.py -f ../foldtest/foldtest_example.dat -fmt png -sav
# Out:
# 2017-05-11 15:53:13.099 python[28527:18266251] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:53:13.112 python[28527:18266251] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:53:13.238 python[28527:18266251] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:53:13.247 python[28527:18266251] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:53:13.371 python[28527:18266251] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:53:13.393 python[28527:18266251] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# doing  1000  iterations...please be patient.....
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 84 - 119 Percent Unfolding
# range of all bootstrap samples:  73  -  130
# 1  saved in  foldtest_ge.png
# 2  saved in  foldtest_st.png
# 3  saved in  foldtest_ta.png

# %%
Image(filename='foldtest_ta.png')

# %%
Image(filename='foldtest_st.png')

# %%
Image(filename='foldtest_ge.png')

# %% [markdown]
# # foldtest_magic.py

# %%
# !download_magic.py -WD ../foldtest_magic -f ../foldtest_magic/magic_contribution_11087.txt |tail
# Out:
# -I- using default for arg: Fsi
# -
# -I- using default for arg: O
# -
# 2  records written to file  ../foldtest_magic/er_locations.txt
# 30  records written to file  ../foldtest_magic/er_sites.txt
# 5  records written to file  ../foldtest_magic/er_citations.txt
# 60  records written to file  ../foldtest_magic/pmag_sites.txt
# 32  records written to file  ../foldtest_magic/pmag_results.txt
# 9  records written to file  ../foldtest_magic/magic_methods.txt

# %%
# !foldtest_magic.py -f ../foldtest_magic/pmag_sites.txt \
    -fsi ../foldtest_magic/er_sites.txt -fmt png -sav
# Out:
# 2017-05-11 15:55:32.071 python[28641:18274126] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:55:32.081 python[28641:18274126] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:55:32.219 python[28641:18274126] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:55:32.231 python[28641:18274126] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:55:32.337 python[28641:18274126] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:55:32.356 python[28641:18274126] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# doing  1000  iterations...please be patient.....
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 96 - 149 Percent Unfolding
# 2  saved in  foldtest_st.png
# 3  saved in  foldtest_ta.png
# 1  saved in  foldtest_ge.png

# %%
Image(filename='foldtest_ge.png')

# %%
Image(filename='foldtest_st.png')

# %%
Image(filename='foldtest_ta.png')

# %% [markdown]
# # gaussian.py

# %%
# !gaussian.py -s 3 -n 1000 -m 10. -F ../gaussian/gaussian.out
# !histplot.py -f ../gaussian/gaussian.out -fmt png -sav
# Out:
# hist.png
# 2017-05-11 15:56:55.513 python[28679:18282515] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:56:55.527 python[28679:18282515] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# plot saved in  hist.png

# %%
Image(filename='hist.png')

# %% [markdown]
# # gobing.py

# %%
# !gobing.py -f ../eqarea_ell/tk03.out
# Out:
#   357.8    60.3     4.5   105.7    10.0     4.5    21.0   -27.6 20

# %% [markdown]
# # gofish.py

# %%
# !gofish.py -f ../gofish/fishrot.out
# Out:
#    10.8    39.6    10     9.8484     59.4     6.3    10.5

# %% [markdown]
# # gokent.py

# %%
# !gokent.py -f ../gokent/tk03.out
# Out:
#   359.2    55.0     9.3   147.7    30.8     7.8   246.8    14.9 20

# %% [markdown]
# # goprinc.py

# %%
# !goprinc.py -f ../goprinc/tk03.out
# Out:
# 0.93863    11.0    58.6 0.04258   226.4    26.5 0.01879   128.3    15.6 20

# %% [markdown]
# # grab_magic_key.py

# %%
# !grab_magic_key.py -f ../download_magic/er_sites.txt -key site_lat |head
# Out:
# 42.60264
# 42.60264
# 42.60352
# 42.60104
# 42.73656
# 42.8418
# 42.8657
# 42.92031
# 42.56857
# 42.49964

# %% [markdown]
# # histplot.py
#
# see gaussian.py

# %% [markdown]
# # hysteresis_magic.py

# %%
# !hysteresis_magic.py -f ../hysteresis_magic/hysteresis_magic_example.dat \
    -spc IS06a-1  -fmt png -sav
# Out:
# 2017-05-11 15:57:08.255 python[28724:18284151] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:08.268 python[28724:18284151] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:08.375 python[28724:18284151] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:08.387 python[28724:18284151] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:08.509 python[28724:18284151] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:08.523 python[28724:18284151] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# IS06a-1
# 2017-05-11 15:57:08.816 python[28724:18284151] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:08.827 python[28724:18284151] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 3  saved in  _IS06a-1_DdeltaM.png
# 1  saved in  _IS06a-1_hyst.png
# 5  saved in  _IS06a-1_irm.png
# 2  saved in  _IS06a-1_deltaM.png

# %%
Image(filename='_IS06a-1_hyst.png')

# %% [markdown]
# # igrf.py

# %%
# !igrf.py -ages -3000 1950 50 -loc 33 -117 -mod pfm9k -plt -fmt png -sav
# Out:
# 2017-05-11 15:57:12.102 python[28730:18284392] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:12.114 python[28730:18284392] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Figure saved as:  igrf.png

# %%
Image(filename='igrf.png')

# %% [markdown]
# # install_etopo.py

# %%
# !install_etopo.py
# Out:
# installing etopo20 files from  /Users/nebula/Python/PmagPy/data_files/etopo20/etopo20*
# to the basemap data directory:  /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/data

# %% [markdown]
# # incfish.py

# %%
# !incfish.py -f ../incfish/incfish_example_inc.dat
# Out:
#    57.1    61.0  100     92.9    13.9     1.0

# %% [markdown]
# # irmaq_magic.py

# %%
# !sio_magic2.py -f ../irmaq_magic/U1359A_IRM_coil2.txt -LP I -V 2 \
    -F ../irmaq_magic/U1359A_IRM_coil2.magic -loc U1359A -spc 0 -ncn 5
# !sio_magic2.py -f ../irmaq_magic/U1359A_IRM_coil3.txt -LP I -V 3 \
    -F ../irmaq_magic/U1359A_IRM_coil3.magic -loc U1359A -spc 0 -ncn 5
# !combine_magic.py -F ../irmaq_magic/magic_measurements.txt \
    -f ../irmaq_magic/U1359A_IRM_coil2.magic \
    ../irmaq_magic/U1359A_IRM_coil3.magic
# Out:
# 536  records written to file  ../irmaq_magic/U1359A_IRM_coil2.magic
# results put in  ../irmaq_magic/U1359A_IRM_coil2.magic
# 23  records written to file  ../irmaq_magic/U1359A_IRM_coil3.magic
# results put in  ../irmaq_magic/U1359A_IRM_coil3.magic
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: dm
# -
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# -I- Using cached 3.0 data model
# -W- You are missing the 'treat_step_num' column in your measurements file
#     This may cause strange behavior in the analysis GUIs
# Traceback (most recent call last):
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/indexes/base.py", line 2393, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)
#   File "pandas/_libs/index.pyx", line 154, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1207, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1215, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)
# KeyError: 'experiment'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/combine_magic.py", line 60, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/combine_magic.py", line 57, in main
#     combine(filenames,outfile,dir_path,data_model)
#   File "/Users/nebula/Python/PmagPy/programs/combine_magic.py", line 31, in combine
#     ipmag.combine_magic(files, outfile, data_model=data_model)
#   File "/Users/nebula/Python/PmagPy/pmagpy/ipmag.py", line 2077, in combine_magic
#     con.add_magic_table(dtype=file_type, df=df)
#   File "/Users/nebula/Python/PmagPy/pmagpy/new_builder.py", line 164, in add_magic_table
#     data_container = MagicDataFrame(dtype=dtype, df=df)
#   File "/Users/nebula/Python/PmagPy/pmagpy/new_builder.py", line 1240, in __init__
#     self.df['measurement'] = self.df['experiment'] + self.df['treat_step_num'].astype(str)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/frame.py", line 2062, in __getitem__
#     return self._getitem_column(key)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/frame.py", line 2069, in _getitem_column
#     return self._get_item_cache(key)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/generic.py", line 1534, in _get_item_cache
#     values = self._data.get(item)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/internals.py", line 3590, in get
#     loc = self.items.get_loc(item)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/indexes/base.py", line 2395, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)
#   File "pandas/_libs/index.pyx", line 154, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1207, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1215, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)
# KeyError: 'experiment'

# %%
# !irmaq_magic.py -f ../irmaq_magic/magic_measurements.txt -fmt png -sav
# Out:
# 2017-05-11 15:57:25.911 python[28779:18286321] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:25.923 python[28779:18286321] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# U1359A
# 1  saved in  U1359A_LP-IRM.png

# %%
Image(filename='U1359A_LP-IRM.png')

# %% [markdown]
# # k15_magic.py

# %%
# !k15_magic.py -WD ../k15_magic  -spc 0 -f ../k15_s/k15_example.dat -loc "Troodos Ophiolite"
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: Fa
# -
# -I- using default for arg: Fr
# -
# -I- using default for arg: ncn
# -
# 12  records written to file  ../k15_magic/er_samples.txt
# 24  records written to file  ../k15_magic/rmag_anisotropy.txt
# 24  records written to file  ../k15_magic/rmag_results.txt
# 120  records written to file  ../k15_magic/magic_measurements.txt
# Data saved to:  ../k15_magic/er_samples.txt ../k15_magic/rmag_anisotropy.txt ../k15_magic/rmag_results.txt ../k15_magic/magic_measurements.txt

# %%
# !k15_s.py -f ../k15_s/k15_example.dat
# Out:
# 0.33146986 0.33413991 0.33439023 0.00075095 -0.00083439 -0.00016688 0.00008618
# 0.33335925 0.33335925 0.33328149 -0.00155521 -0.00132193 0.00116641 0.00017193
# 0.33097634 0.33573565 0.33328801 0.00163177 0.00013598 0.00000000 0.00018131
# 0.33150029 0.33465420 0.33384551 -0.00064696 -0.00056609 -0.00048522 0.00014863
# 0.33121986 0.33521197 0.33356816 -0.00046966 -0.00046966 -0.00086104 0.00018376
# 0.33179570 0.33405602 0.33414828 -0.00009226 -0.00004613 -0.00027677 0.00010474
# 0.33243163 0.33439898 0.33316939 0.00106564 0.00032789 0.00000000 0.00017624
# 0.33175478 0.33512715 0.33311808 0.00078928 0.00000000 -0.00007175 0.00011116

# %%
# !kly4s_magic.py -ID kly4s_magic -WD kly4s_magic -f KLY4S_magic_example.dat -spc 0 -ncn 5
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fad
# -
# -I- using default for arg: fsa
# -
# -I- using default for arg: fsp
# -
# -I- using default for arg: Fsp
# -
# -I- using default for arg: Fa
# -
# -I- using default for arg: ocn
# -
# -I- using default for arg: usr
# -
# -I- using default for arg: loc
# -
# -I- using default for arg: ins
# -
# Error opening file:  kly4s_magic/KLY4S_magic_example.dat

# %% [markdown]
# # lnp_magic.py

# %%
# !download_magic.py  -WD ../lnp_magic -ID ../lnp_magic -f zmab0001193tmp02.txt |head
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: O
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/download_magic.py", line 54, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/download_magic.py", line 49, in main
#     ipmag.download_magic(infile, dir_path, input_dir_path, overwrite, data_model)
#   File "/Users/nebula/Python/PmagPy/pmagpy/ipmag.py", line 2926, in download_magic
#     infile = f.readlines()
#   File "/Users/nebula/anaconda/lib/python3.5/codecs.py", line 321, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 4557: invalid start byte

# %%
# !lnp_magic.py -f ../lnp_magic/pmag_specimens.txt -crd g -fmt png -sav |head
# Out:
# 2017-05-11 15:57:37.696 python[28843:18287457] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:37.708 python[28843:18287457] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# sv01
# Site lines planes  kappa   a95   dec   inc
# sv01 0  5     286      6.6    179.0    -54.3  4.9948
# % tilt correction:  0
# 1  saved in  sv01_g_eqarea.png
# sv02
# Site lines planes  kappa   a95   dec   inc
# sv02 4  2     113      6.6    338.8     38.6  5.9647
# % tilt correction:  0
# 1  saved in  sv02_g_eqarea.png

# %%
Image(filename='sv01_g_eqarea.png')

# %%
# !lowrie.py -f ../lowrie/lowrie_example.dat -fmt png -sav |head
# Out:
# 2017-05-11 15:57:48.233 python[28906:18289341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:57:48.243 python[28906:18289341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/lowrie.py", line 124, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/lowrie.py", line 64, in main
#     data = open(in_file).readlines()  # open the SIO format file
#   File "/Users/nebula/anaconda/lib/python3.5/codecs.py", line 321, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa1 in position 95: invalid start byte

# %%
Image(filename='lowrie__318-U1359A-002H-1-W-109_.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-104-5aca447b7c5f> in <module>()
# ----> 1 Image(filename='lowrie__318-U1359A-002H-1-W-109_.png')
#
# /Users/nebula/anaconda/lib/python3.5/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     956         self.unconfined = unconfined
#     957         self.metadata = metadata
# --> 958         super(Image, self).__init__(data=data, url=url, filename=filename)
#     959
#     960         if retina:
#
# /Users/nebula/anaconda/lib/python3.5/site-packages/IPython/core/display.py in __init__(self, data, url, filename)
#     495         self.filename = filename
#     496
# --> 497         self.reload()
#     498         self._check_data()
#     499
#
# /Users/nebula/anaconda/lib/python3.5/site-packages/IPython/core/display.py in reload(self)
#     978         """Reload the raw data from file or URL."""
#     979         if self.embed:
# --> 980             super(Image,self).reload()
#     981             if self.retina:
#     982                 self._retina_shape()
#
# /Users/nebula/anaconda/lib/python3.5/site-packages/IPython/core/display.py in reload(self)
#     513         """Reload the raw data from file or URL."""
#     514         if self.filename is not None:
# --> 515             with open(self.filename, self._read_flags) as f:
#     516                 self.data = f.read()
#     517         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lowrie__318-U1359A-002H-1-W-109_.png'

# %% [markdown]
# # lowrie_magic.py

# %%
# !lowrie_magic.py -f ../lowrie_magic/lowrie_magic_example.dat -fmt png -sav |head
# Out:
# 2017-05-11 15:59:56.666 python[28931:18304219] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 15:59:56.679 python[28931:18304219] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# ./../lowrie_magic/lowrie_magic_example.dat
# 318-U1359A-002H-1-W-109
# 1  saved in  lowrie__318-U1359A-002H-1-W-109_.png
# 318-U1359A-002H-4-W-65
# 1  saved in  lowrie__318-U1359A-002H-4-W-65_.png
# 318-U1359A-002H-6-W-7
# 1  saved in  lowrie__318-U1359A-002H-6-W-7_.png
# 318-U1359A-003H-2-W-37
# 1  saved in  lowrie__318-U1359A-003H-2-W-37_.png
# 318-U1359A-003H-6-W-66

# %%
Image(filename='lowrie__318-U1359A-002H-1-W-109_.png')

# %% [markdown]
# # magic_select.py

# %%
# !magic_select.py -f ../magic_select/pmag_specimens.txt \
    -key magic_method_codes LP-DIR-AF has -F ../magic_select/AF_specimens.txt
# Out:
# 76  records written to file  ./../magic_select/AF_specimens.txt

# %% [markdown]
# # measurements_normalize.py

# %%
# !measurements_normalize.py -f ../measurements_normalize/irm_measurements.txt \
    -fsp ../measurements_normalize/specimens_weights.txt \
    -F ../measurements_normalize/irm_norm_measurements.txt
# Out:
# 17721  records written to file  ./../measurements_normalize/irm_norm_measurements.txt
# Data saved in  ./../measurements_normalize/irm_norm_measurements.txt

# %% [markdown]
# # mk_redo.py

# %%
# !mk_redo.py -f pmag_specimens.txt -WD ../mk_redo
# Out:
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/mk_redo.py", line 91, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/mk_redo.py", line 72, in main
#     comp_name=string.uppercase[specs.count(spec['er_specimen_name'])-1]
# AttributeError: module 'string' has no attribute 'uppercase'

# %%
# !head ../mk_redo/zeq_redo
# Out:
# sr01a1 DE-BFL 473 823 A
# sr01a2 DE-BFL 473 848 A
# sr01c2 DE-BFL 473 823 A
# sr01d1 DE-BFL 373 798 A
# sr01e2 DE-BFL 0.01 0.18 A
# sr01f2 DE-BFL 423 923 A
# sr01g2 DE-BFL 0.01 0.16 A
# sr01i1 DE-BFL 473 823 A
# sr03a1 DE-BFL 473 823 A
# sr03b1 DE-BFL 673 823 A

# %%
# !head ../mk_redo/thellier_redo
# Out:
# sr01a1 573 823
# sr01a2 573 848
# sr01c2 673 823
# sr01d1 373 823
# sr01i1 373 773
# sr03a1 373 673
# sr03b1 373 673
# sr03c1 423 673
# sr03e1 423 673
# sr09f1 373 573

# %% [markdown]
# # nrm_specimens_magic.py

# %%
# !download_magic.py -WD ../nrm_specimens_magic \
-f ../nrm_specimens_magic/zmab0083201tmp03.txt |tail
# Out:
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/download_magic.py", line 54, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/download_magic.py", line 49, in main
#     ipmag.download_magic(infile, dir_path, input_dir_path, overwrite, data_model)
#   File "/Users/nebula/Python/PmagPy/pmagpy/ipmag.py", line 2926, in download_magic
#     infile = f.readlines()
#   File "/Users/nebula/anaconda/lib/python3.5/codecs.py", line 321, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa1 in position 6048: invalid start byte
# -I- using default for arg: A
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: O
# -

# %%
# !nrm_specimens_magic.py -WD ../nrm_specimens_magic -crd g
# Out:
# ../nrm_specimens_magic/er_samples.txt  read in with  271  records
# 177  records written to file  ../nrm_specimens_magic/nrm_specimens.txt
# Data saved in  ../nrm_specimens_magic/nrm_specimens.txt

# %%
# !eqarea_magic.py -f ../nrm_specimens_magic/nrm_specimens.txt -crd g -fmt png -sav
# Out:
# 2017-05-11 16:00:18.436 python[29045:18307352] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:00:18.446 python[29045:18307352] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# -I- Using cached 3.0 data model
# -I- Using cached method codes
# -I- Using cached vocabularies
# -I- Importing suggested vocabularies from https://earthref.org
# -I- Using cached suggested vocabularies
# Traceback (most recent call last):
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/indexes/base.py", line 2393, in get_loc
#     return self._engine.get_loc(key)
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)
#   File "pandas/_libs/index.pyx", line 154, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1207, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1215, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)
# KeyError: 'pmag_specimen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/eqarea_magic.py", line 415, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/eqarea_magic.py", line 118, in main
#     single_file=in_file)
#   File "/Users/nebula/Python/PmagPy/pmagpy/new_builder.py", line 72, in __init__
#     self.add_magic_table('unknown', single_file)
#   File "/Users/nebula/Python/PmagPy/pmagpy/new_builder.py", line 137, in add_magic_table
#     data_container = MagicDataFrame(filename, dmodel=self.data_model)
#   File "/Users/nebula/Python/PmagPy/pmagpy/new_builder.py", line 1200, in __init__
#     self.df.index = self.df[name].astype(str)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/frame.py", line 2062, in __getitem__
#     return self._getitem_column(key)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/frame.py", line 2069, in _getitem_column
#     return self._get_item_cache(key)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/generic.py", line 1534, in _get_item_cache
#     values = self._data.get(item)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/internals.py", line 3590, in get
#     loc = self.items.get_loc(item)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/pandas/core/indexes/base.py", line 2395, in get_loc
#     return self._engine.get_loc(self._maybe_cast_indexer(key))
#   File "pandas/_libs/index.pyx", line 132, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)
#   File "pandas/_libs/index.pyx", line 154, in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1207, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1215, in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)
# KeyError: 'pmag_specimen'

# %%
Image(filename='Snake_River_g_eqarea.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-115-30c339870677> in <module>()
# ----> 1 Image(filename='Snake_River_g_eqarea.png')
#
# /Users/nebula/anaconda/lib/python3.5/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     956         self.unconfined = unconfined
#     957         self.metadata = metadata
# --> 958         super(Image, self).__init__(data=data, url=url, filename=filename)
#     959
#     960         if retina:
#
# /Users/nebula/anaconda/lib/python3.5/site-packages/IPython/core/display.py in __init__(self, data, url, filename)
#     495         self.filename = filename
#     496
# --> 497         self.reload()
#     498         self._check_data()
#     499
#
# /Users/nebula/anaconda/lib/python3.5/site-packages/IPython/core/display.py in reload(self)
#     978         """Reload the raw data from file or URL."""
#     979         if self.embed:
# --> 980             super(Image,self).reload()
#     981             if self.retina:
#     982                 self._retina_shape()
#
# /Users/nebula/anaconda/lib/python3.5/site-packages/IPython/core/display.py in reload(self)
#     513         """Reload the raw data from file or URL."""
#     514         if self.filename is not None:
# --> 515             with open(self.filename, self._read_flags) as f:
#     516                 self.data = f.read()
#     517         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Snake_River_g_eqarea.png'

# %% [markdown]
# # orientation_magic.py

# %%
# !orientation_magic.py -WD ../orienation_magic -f orient_example.txt | tail
# Out:
# -I- using default for arg: gmt
# -
# -I- using default for arg: mcd
# -
# -I- using default for arg: a
# -
# -I- using default for arg: DM
# -
# saving data...
# Data saved in  ../orienation_magic/samples.txt  and  ../orienation_magic/sites.txt

# %%
# !parse_measurements.py -WD ../parse_measurements |tail
# Out:
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/parse_measurements.py", line 59, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/parse_measurements.py", line 56, in main
#     pmag.ParseMeasFile(infile,sitefile,instout,specout)
#   File "/Users/nebula/Python/PmagPy/pmagpy/pmag.py", line 761, in ParseMeasFile
#     if "magic_instrument_codes" in list(rec.keys()):
# UnboundLocalError: local variable 'list' referenced before assignment

# %% [markdown]
# # pca.py

# %%
# !pca.py -dir L 1 10 -f ../pca/zeq_example.dat
# Out:
# eba24a DE-BFL
# 0 0.00 339.9 57.9 9.2830e-05
# 1 2.50 325.7 49.1 7.5820e-05
# 2 5.00 321.3 45.9 6.2920e-05
# 3 10.00 314.8 41.7 5.2090e-05
# 4 15.00 310.3 38.7 4.4550e-05
# 5 20.00 305.0 37.0 3.9540e-05
# 6 30.00 303.9 34.7 3.2570e-05
# 7 40.00 303.0 32.3 2.5670e-05
# 8 50.00 303.6 32.4 2.2520e-05
# 9 60.00 299.8 30.8 1.9820e-05
# 10 70.00 292.5 31.0 1.3890e-05
# 11 80.00 297.0 25.6 1.2570e-05
# 12 90.00 299.3 11.3 0.5030e-05
# eba24a DE-BFL 10    2.50  70.00    8.8   334.9    51.5

# %% [markdown]
# # plotXY.py

# %%
# !plotXY.py -f ../plotXY/plotXY_example.txt -fmt png -sav
# Out:
# Figure saved as  plotXY.png

# %%
Image(filename='plotXY.png')

# %% [markdown]
# # plot_cdf.py

# %%
# !plot_cdf.py -f ../plot_cdf/gaussian.out -fmt png -sav
# Out:
# 2017-05-11 16:01:45.745 python[29094:18318373] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:01:45.757 python[29094:18318373] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  CDF_.png

# %%
Image(filename='CDF_.png')

# %% [markdown]
# # plot_mapPTS.py

# %%
# !plot_map_pts.py -f ../plot_mapPTS/uniform.out -B -R \
    -prj ortho -eye 30 0 -etp -sym wo 10 -fmt png -sav
# Out:
# 2017-05-11 16:01:47.556 python[29106:18318649] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:01:47.568 python[29106:18318649] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# please wait to draw points
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Map_PTS.png

# %%
if basemap_present:
    image = Image(filename='Map_PTS.png')
else:
    image = None
image

# %% [markdown]
# # plotdi_a.py

# %%
# !plotdi_a.py -f ../plotdi_a/plotdi_a_example.dat -fmt png -sav
# Out:
# 2017-05-11 16:01:51.911 python[29121:18318807] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:01:51.925 python[29121:18318807] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  eq.png

# %%
Image(filename='eq.png')

# %% [markdown]
# # pmag_results_extract.py

# %%
# !pmag_results_extract.py -WD ../pmag_results_extract -f pmag_results.txt
# Out:
# data saved in:  /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/Directions.txt /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/Intensities.txt /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/SiteNfo.txt

# %% [markdown]
# # pt_rot.py

# %%
# !awk '{print $1,$2}' ../pt_rot/pt_rot.input > ../pt_rot/lon_lat
# !plot_map_pts.py -prj moll -f ../pt_rot/lon_lat -sym g^ 10 -R -B -eye 0 0 -fmt png -sav
# Out:
# 2017-05-11 16:01:55.879 python[29153:18319419] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:01:55.889 python[29153:18319419] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# please wait to draw points
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Map_PTS.png

# %%
if basemap_present:
    image = Image(filename='Map_PTS.png')
else:
    image = None
image

# %%
# !cat ../pt_rot/pt_rot.input
# !pt_rot.py -f ../pt_rot/pt_rot.input > ../pt_rot/pt_rot.out
# Out:
# -84.7 39.1 nam 80 saf

# %%
# !plot_map_pts.py -prj moll -f ../pt_rot/pt_rot.out -sym ro 10 -R -B -eye 0 0 -fmt png -sav
# Out:
# 2017-05-11 16:02:00.709 python[29191:18320013] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:00.721 python[29191:18320013] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# please wait to draw points
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Map_PTS.png

# %%
if basemap_present:
    image = Image(filename='Map_PTS.png')
else:
    image = None
image

# %% [markdown]
# Something still weird about pt_rot.py (the -ff option).

# %%
# !pt_rot.py -ff ../pt_rot/nam_180-200.txt ../pt_rot/nam_panA.frp > ../pt_rot/pt_rot_panA.out

# %%
# !plot_map_pts.py -f ../pt_rot/pt_rot_panA.out -prj ortho -eye 60 90 -sym ro 10 -B -R -fmt png -sav
# Out:
# 2017-05-11 16:02:05.433 python[29228:18320447] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:05.444 python[29228:18320447] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# please wait to draw points
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Map_PTS.png

# %%
if basemap_present:
    image = Image(filename='Map_PTS.png')
else:
    image = None
image

# %% [markdown]
# # qqplot.py

# %%
# !qqplot.py -f ../qqplot/gauss.out -fmt png -sav
# Out:
# 2017-05-11 16:02:08.852 python[29252:18320673] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:08.864 python[29252:18320673] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# mean,sigma, d, Dc
# -0.09482124000000011 0.941267146559 0.0770098421346 0.0886
# 1  saved in  qq.png

# %%
Image(filename='qq.png')

# %% [markdown]
# # quick_hyst2.py

# %%
# !quick_hyst2.py -f ../hysteresis_magic/hysteresis_magic_example.dat -fmt png -sav |head
# Out:
# 2017-05-11 16:02:10.752 python[29265:18320840] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:10.762 python[29265:18320840] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# verbose 0
# working on t:  273
# 1  saved in  IS06_IS06a_IS06a-1_hyst.png
# working on t:  273
# 1  saved in  IS06_IS06a_IS06a-2_hyst.png
# working on t:  273
# 1  saved in  IS06_IS06a_IS06a-3_hyst.png
# working on t:  273
# 1  saved in  IS06_IS06a_IS06a-4_hyst.png
# working on t:  273

# %%
Image(filename='IS06_IS06a_IS06a-1_hyst.png')

# %% [markdown]
# # revtest.py

# %%
# !revtest.py -f ../revtest/revtest_example.txt -fmt png -sav
# Out:
# 2017-05-11 16:02:13.725 python[29280:18321252] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:13.739 python[29280:18321252] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:13.852 python[29280:18321252] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:13.866 python[29280:18321252] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:13.979 python[29280:18321252] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:13.992 python[29280:18321252] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# doing first mode, be patient
# doing second mode, be patient
# 3  saved in  REV_Z.png
# 1  saved in  REV_X.png
# 2  saved in  REV_Y.png

# %%
Image(filename='REV_X.png')

# %%
Image(filename='REV_Y.png')

# %%
Image(filename='REV_Z.png')

# %% [markdown]
# # revtest_magic.py

# %%
# !revtest_magic.py -f ../revtest_magic/revtest_magic_example.txt -fmt png -sav
# Out:
# 2017-05-11 16:02:18.572 python[29296:18321881] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:18.585 python[29296:18321881] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:18.703 python[29296:18321881] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:18.715 python[29296:18321881] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:18.826 python[29296:18321881] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:18.837 python[29296:18321881] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# doing first mode, be patient
# doing second mode, be patient
# 3  saved in  REV_Z.png
# 2  saved in  REV_Y.png
# 1  saved in  REV_X.png

# %%
Image(filename='REV_X.png')

# %% [markdown]
# # s_eigs.py

# %%
# !s_eigs.py -f ../s_eigs/s_eigs_example.dat
# Out:
# 0.33127186 239.53  44.70 0.33351338 126.62  21.47 0.33521473  19.03  37.54
# 0.33177859 281.12   6.18 0.33218277 169.79  73.43 0.33603862  12.82  15.32
# 0.33046979 283.57  27.30 0.33328307 118.37  61.91 0.33624712  16.75   6.13
# 0.33123776 261.36  12.07 0.33377582 141.40  66.82 0.33498645 355.70  19.48
# 0.33085680 255.71   7.13 0.33379164 130.85  77.65 0.33535156 346.97  10.03
# 0.33175930 268.51  26.79 0.33405024 169.66  16.95 0.33419049  51.04  57.53
# 0.33194992 261.59  20.68 0.33313262  92.18  68.99 0.33491743 352.93   3.54
# 0.33157593 281.42  21.32 0.33312121 117.04  67.94 0.33530283  13.54   5.41

# %% [markdown]
# # s_geo.py

# %%
# !s_geo.py -f ../s_geo/s_geo_example.dat
# Out:
# 0.33412680 0.33282733 0.33304587 -0.00015289 0.00124843 0.00135721
# 0.33556300 0.33198264 0.33245432 0.00087259 0.00024141 0.00096166
# 0.33584908 0.33140627 0.33274469 0.00131845 0.00118816 0.00002986
# 0.33479756 0.33142531 0.33377719 -0.00047493 0.00049539 0.00044303
# 0.33505613 0.33114848 0.33379540 -0.00101375 0.00028536 0.00034852
# 0.33406156 0.33226916 0.33366925 -0.00002267 0.00098548 0.00005553
# 0.33486596 0.33216032 0.33297369 -0.00035492 0.00039254 0.00015403
# 0.33510646 0.33196402 0.33292958 0.00075965 0.00057242 0.00010112

# %% [markdown]
# # s_hext.py

# %%
# !s_geo.py -f ../s_geo/s_geo_example.dat | s_hext.py
# Out:
# F =  5.79 F12 =  3.55 F23 =  3.66
# N =  8  sigma =  0.000641809950
# 0.33505     5.3    14.7    25.5   124.5    61.7    13.3   268.8    23.6
# 0.33334   124.5    61.7    25.1   268.8    23.6    25.5     5.3    14.7
# 0.33161   268.8    23.6    13.3     5.3    14.7    25.1   124.5    61.7

# %% [markdown]
# # s_tilt.py

# %%
# !s_tilt.py -f ../s_tilt/s_tilt_example.dat
# Out:
# 0.33455709 0.33192658 0.33351630 -0.00043562 0.00092779 0.00105006
# 0.33585501 0.33191565 0.33222935 0.00055960 -0.00005316 0.00064732
# 0.33586669 0.33084923 0.33328408 0.00142266 0.00013234 0.00009203
# 0.33488664 0.33138493 0.33372843 -0.00056597 -0.00039085 0.00004873
# 0.33506602 0.33127019 0.33366373 -0.00105193 -0.00057257 -0.00029959
# 0.33407688 0.33177567 0.33414748 0.00007007 0.00018447 0.00005073
# 0.33483925 0.33197853 0.33318222 -0.00028447 0.00003518 -0.00029262
# 0.33513144 0.33175036 0.33311823 0.00077914 -0.00006402 0.00004612

# %% [markdown]
# # s_magic.py

# %%
# !s_magic.py -WD ../s_magic -f s_magic_example.dat
# Out:
# 8  records written to file  ../s_magic/rmag_anisotropy.txt
# data saved in  ../s_magic/rmag_anisotropy.txt

# %% [markdown]
# # scalc.py

# %%
# !scalc.py -f ../scalc/scalc_example.txt
# Out:
# 99    19.5     90.0

# %%
# !scalc.py -f ../scalc/scalc_example.txt -v
# Out:
# 89    15.2     32.3

# %%
# !scalc.py -f ../scalc/scalc_example.txt -v -b
# Out:
# please be patient...   bootstrapping
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/scalc.py", line 144, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/scalc.py", line 129, in main
#     random.reseed()
# AttributeError: module 'random' has no attribute 'reseed'

# %% [markdown]
# # scalc_magic.py

# %%
# !scalc_magic.py -f ../scalc_magic/pmag_results.txt -c 30
# Out:
# 13    17.8     30.0

# %% [markdown]
# # site_edit.py
#
# This program requires user interaction and can only be used on the command line.

# %% [markdown]
# # specimens_results_magic.py
#
# This program has been superceded by Pmag GUI and is not maintained.

# %% [markdown]
# # stats.py

# %%
# !stats.py -f ../gaussian/gauss.out
# Out:
# 100 9.94986999 994.9869990000003 0.958167360921 9.62994855092

# %% [markdown]
# # strip_magic.py

# %%
# !strip_magic.py -f ../strip_magic/pmag_results.txt -x age -y lat -fmt png -sav
# Out:
# 2017-05-11 16:02:42.106 python[29387:18324787] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:42.119 python[29387:18324787] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  strat.png

# %%
Image(filename='strat.png')

# %% [markdown]
# # sundec.py

# %%
# !sundec.py -f ../sundec/sundec_example.dat
# Out:
#   154.2

# %% [markdown]
# # thellier_magic.py
#
# This program is no longer maintained - try Thellier GUI instead.

# %% [markdown]
# # thellier_magic_redo.py
#
# The function of this program has been incorporated into Thellier GUI so you should use that instead.

# %% [markdown]
# # tk03.py

# %%
# !tk03.py -lat 30 > ../tk03/tk03.out
# !eqarea.py -f ../tk03/tk03.out -fmt png -sav
# Out:
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/tk03.py", line 73, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/tk03.py", line 63, in main
#     vec= pmag.getvec(gh,L,int)  # send field model and lat to getvec
#   File "/Users/nebula/Python/PmagPy/pmagpy/pmag.py", line 8611, in getvec
#     x, y, z, f = magsyn(gh, sv, date, date, itype, alt, colat, lon)
#   File "/Users/nebula/Python/PmagPy/pmagpy/pmag.py", line 7063, in magsyn
#     one = elong * 0.0174532925
# TypeError: unsupported operand type(s) for *: 'type' and 'float'
# /Users/nebula/Python/PmagPy/programs/eqarea.py:70: UserWarning: loadtxt: Empty input file: "../tk03/tk03.out"
#   DI=numpy.loadtxt(fname)
# 2017-05-11 16:02:48.364 python[29424:18325930] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:48.374 python[29424:18325930] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  tk03_eq.png

# %%
Image(filename='tk03_eq.png')

# %% [markdown]
# # uniform.py

# %%
# !uniform.py -n 50 |head
# Out:
#   284.0    -5.0
#   135.2    33.1
#   338.7   -34.3
#   175.8    32.4
#   295.6   -36.4
#   186.0     2.2
#    55.4     9.3
#   272.3    29.7
#    40.4   -42.9
#   277.8   -56.8
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/uniform.py", line 41, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/uniform.py", line 36, in main
#     print('%7.1f %7.1f'%(dir[0],dir[1]))
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/colorama/ansitowin32.py", line 40, in write
#     self.__convertor.write(text)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/colorama/ansitowin32.py", line 141, in write
#     self.write_and_convert(text)
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/colorama/ansitowin32.py", line 169, in write_and_convert
#     self.write_plain_text(text, cursor, len(text))
#   File "/Users/nebula/anaconda/lib/python3.5/site-packages/colorama/ansitowin32.py", line 175, in write_plain_text
#     self.wrapped.flush()
# BrokenPipeError: [Errno 32] Broken pipe
# Exception ignored in: <colorama.ansitowin32.StreamWrapper object at 0x10d26fc50>
# BrokenPipeError: [Errno 32] Broken pipe

# %%
# !uniform.py -n 50 > ../uniform/uniform.out
# !eqarea.py -f ../uniform/uniform.out -fmt png -sav
# Out:
# 2017-05-11 16:02:54.496 python[29457:18326938] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:02:54.508 python[29457:18326938] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  uniform_eq.png

# %%
Image(filename='uniform_eq.png')

# %% [markdown]
# # update_measurements.txt
#
# This program has been superceded by Pmag GUI, so you should use that.

# %% [markdown]
# # upload_magic.py
#
# program has been superceded by Pmag GUI, so you should use that.

# %% [markdown]
# # vdm_b.py

# %%
# !vdm_b.py -f ../vdm_b/vdm_b_example.dat
# Out:
#  3.300e-05

# %%
# !cat ../b_vdm/b_vdm_example.dat
# Out:
# 33 22

# %% [markdown]
# # vector_mean.py

# %%
# !vector_mean.py -f ../vector_mean/vector_mean_example.dat
# Out:
#     1.3    49.6    2.289e+06 100

# %% [markdown]
# # vgp_di.py

# %%
# !vgp_di.py -f ../vgp_di/vgp_di_example.dat
# Out:
#   335.6    62.9

# %% [markdown]
# # vgpmap_magic2.py

# %%
# !vgpmap_magic2.py -f ../vgpmap_magic/pmag_results.txt \
    -crd g -prj ortho -eye 60 0 -etp -sym wo 10 -fmt png -sav
# Out:
# 2017-05-11 16:03:02.957 python[29494:18328193] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:03:02.969 python[29494:18328193] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Snake_River_VGP_map.png

# %%
if basemap_present:
    image = Image(filename='Snake_River_VGP_map.png')
else:
    image = None
image

# %% [markdown]
# # watsons_f.py

# %%
# !watsons_f.py -f ../watsonsF/watsonsF_example_file1.dat \
-f2 ../watsonsF/watsonsF_example_file2.dat
# Out:
#    5.23    3.26

# %% [markdown]
# # watsons_v.py

# %%
# !watsons_v.py -f ../watsonsF/watsonsF_example_file1.dat \
-f2 ../watsonsF/watsonsF_example_file2.dat -fmt png -sav
# Out:
# Watson's V,  Vcrit:
#          10.5        6.5
# 2017-05-11 16:03:15.025 python[29512:18329677] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-11 16:03:15.036 python[29512:18329677] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  watsons_v_watsonsF_example_file1_watsonsF_example_file2.png

# %%
Image(filename="watsons_v_watsonsF_example_file1_watsonsF_example_file2.png")

# %% [markdown]
# # zeq.py
#
# This program requires interaction and can only be run from the command line.

# %% [markdown]
# # zeq_magic.py
#
# This program is no longer maintained.  It has been superceded by demag_gui.py

# %% [markdown]
# # cleanup the directory

# %%
# !rm *.png  
# !rm ..*.png
# !rm ../dayplot_magic/*.svg
# Out:
# rm: ../dayplot_magic/*.svg: No such file or directory

# %%
# !rm *.txt
