# %% [markdown]
# This notebook tests the PmagPy distribution files using the examples in the PmagPy cookbook:  http://earthref.org/PmagPy/
#
# It is meant to function from within the PmagPy data_files/notebooks directory and calls are relative to that.
# To specify a working directory, many programs have the hidden command line argument -WD.

# %%
#import pmagpy.ipmag as ipmag
import pmagpy.pmagplotlib as pmagplotlib
import pmagpy.pmag as pmag
from IPython.display import Image
import matplotlib as plt
basemap_present = True
try: 
    from mpl_toolkits.basemap import Basemap
except ImportError:
    print("Your Python installation doesn't have Basemap.  You won't be able to run certain plotting programs")
    basemap_present = False

# %matplotlib inline

# %% [markdown]
# # aarm_magic.py

# %%
# !sio_magic2.py -f ../aarm_magic/arm_magic_example.dat -loc Bushveld -LP AF:ANI \
    -F ../aarm_magic/aarm_measurements.txt -ncn 3 -ac 180 -dc 50 -1 -1
# Out:
# 126  records written to file  ../aarm_magic/aarm_measurements.txt
# results put in  ../aarm_magic/aarm_measurements.txt

# %%
# !aarm_magic.py -f ../aarm_magic/aarm_measurements.txt
# Out:
# 7  records written to file  ./arm_anisotropy.txt
# specimen tensor elements stored in  ./arm_anisotropy.txt
# 7  records written to file  ./aarm_results.txt
# specimen statistics and eigenparameters stored in  ./aarm_results.txt

# %% [markdown]
# # angle.py

# %%
# !angle.py -f ../angle/angle.dat | tail
# Out:
#   107.1
#   115.8
#   111.3
#   124.6
#    88.1
#    66.9
#    99.9
#    76.7
#    71.4
#   100.8

# %% [markdown]
# # ANI_depthplot.py

# %%
# !ani_depthplot.py -f ../ani_depthplot/rmag_anisotropy.txt -fsa ../ani_depthplot/er_samples.txt \
    -fb ../ani_depthplot/magic_measurements.txt -sav -fmt png
Image(filename='U1361A_ani_depthplot.png')
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fa
# -
# -I- using default for arg: fsum
# -
# -I- using default for arg: ds
# -
# -I- using default for arg: d
# -
# Saved file: U1361A_ani_depthplot.png in folder: /Users/nebula/Python/PmagPy/data_files/notebooks

# %% [markdown]
# # aniso_magic2.py

# %%
# !aniso_magic2.py -f ../aniso_magic/dike_anisotropy.txt -gtc 110 2 -par -v -crd g \
   -F ../aniso_magic/rmag_results.txt -fmt png -sav
# Out:
# 2017-05-12 12:53:45.377 python[39180:19623888] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:53:45.389 python[39180:19623888] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:53:45.503 python[39180:19623888] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:53:45.511 python[39180:19623888] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:53:45.603 python[39180:19623888] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:53:45.610 python[39180:19623888] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Doing bootstrap - be patient
# 3  saved in  Scripps Beach_g_TY__aniso-tcdf_.png
# 1  saved in  Scripps Beach_g_TY__aniso-data_.png
# 2  saved in  Scripps Beach_g_TY__aniso-conf_.png
# 7  records written to file  ./../aniso_magic/rmag_results.txt

# %%
Image(filename='Scripps Beach_g_TY__aniso-tcdf_.png')

# %%
Image(filename='Scripps Beach_g_TY__aniso-data_.png')

# %%
Image(filename='Scripps Beach_g_TY__aniso-conf_.png')

# %% [markdown]
# # apwp.py

# %%
# !apwp.py -f ../apwp/apwp_example.dat
# Out:
#    100.0    38.8   352.4    58.1    81.5   198.3

# %% [markdown]
# # atrm_magic.py

# %%
# !sio_magic2.py -f ../atrm_magic/atrm_magic_example.dat -loc Africa -LP T:ANI\
    -F ../atrm_magic/atrm_measurements.txt -ncn 1 -dc 40 -1 -1
# Out:
# 210  records written to file  ../atrm_magic/atrm_measurements.txt
# results put in  ../atrm_magic/atrm_measurements.txt

# %%
# !atrm_magic.py -f ../atrm_magic/atrm_measurements.txt\
   -Fa ../atrm_magic/trm_anisotropy.txt -Fr ../atrm_magic/atrm_results.txt
# Out:
# 30  records written to file  ./../atrm_magic/trm_anisotropy.txt
# specimen tensor elements stored in  ./../atrm_magic/trm_anisotropy.txt
# 30  records written to file  ./../atrm_magic/atrm_results.txt
# specimen statistics and eigenparameters stored in  ./../atrm_magic/atrm_results.txt

# %% [markdown]
# # azdip_magic.py

# %%
# !azdip_magic.py -f ../azdip_magic/azdip_magic_example.dat -ncn 1\
   -mcd FS-FD:SO-POM -loc "Northern Iceland" -F ../azdip_magic/er_samples.txt
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: app
# -
# checked_args: [['f', '../azdip_magic/azdip_magic_example.dat'], ['ncn', '1'], ['mcd', 'FS-FD:SO-POM'], ['loc', 'Northern', 'Iceland'], ['F', '../azdip_magic/er_samples.txt'], ['A', ''], ['WD', '.'], ['ID', '.'], ['Fsa', 'er_samples.txt'], ['Fsi', 'er_sites.txt'], ['app', False]]
# 916  records written to file  ./er_samples.txt
# Data saved in  ./er_samples.txt

# %% [markdown]
# # b_vdm.py

# %%
# !b_vdm.py -f ../b_vdm/b_vdm_example.dat
# Out:
#  7.159e+22

# %% [markdown]
# # basemap_magic.py

# %% [markdown]
# basemap_magic doesn't work anymore.

# %% [markdown]
# # biplot_magic.py

# %%
# !biplot_magic.py -f ../biplot_magic/biplot_magic_example.dat \
       -x LP-X -y LT-AF-I -fmt png -sav
# Out:
# 2017-05-12 12:53:58.376 python[39246:19624899] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:53:58.387 python[39246:19624899] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# LP-X  selected for X axis
# LT-AF-I  selected for Y axis
# All
# measurement_magn_mass  being used for plotting Y
# measurement_chi_mass  being used for plotting X.
# 1  saved in  All_fig.png

# %%
Image(filename='All_fig.png')

# %% [markdown]
# # bootams.py

# %%
# !bootams.py -par -f ../bootams/bootams_example.dat
# Out:
# Doing bootstrap - be patient
#
# tau tau_sigma V_dec V_inc V_eta V_eta_dec V_eta_inc V_zeta V_zeta_dec V_zeta_inc
#
# 0.33505 0.00020     5.3    14.7    11.4   266.3    29.8    25.7   119.9    55.5
# 0.33334 0.00023   124.5    61.7    20.1   240.1    12.6    22.9   335.6    23.1
# 0.33161 0.00027   268.8    23.6    11.0     7.0    18.7    20.9   132.2    59.5

# %% [markdown]
# # cart_dir.py

# %%
# !cart_dir.py -f ../cart_dir/cart_dir_example.dat
# Out:
#   340.0    65.0  1.000e+00
#   176.0   -55.0  1.000e+00

# %% [markdown]
# ## chartmaker.py

# %% [markdown]
# You can't do chartmaker from within the notebook.  And chi_magic.py is still a bit buggy (problem with legend and 4th plot still shows up.)

# %% [markdown]
# ## chi_magic.py

# %%
# !chi_magic.py -f ../chi_magic/chi_magic_example.dat -fmt png -sav
# Out:
# IRM-Kappa-2352 1 out of  2
# IRM-OldBlue-1892 2 out of  2
# 2017-05-12 12:54:07.815 python[39270:19625364] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:07.826 python[39270:19625364] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:07.999 python[39270:19625364] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:08.008 python[39270:19625364] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:08.149 python[39270:19625364] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:08.159 python[39270:19625364] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Skipping susceptibitily - AC field plot as a function of temperature
# 1  saved in  IRM-OldBlue-1892_1.png
# 2  saved in  IRM-OldBlue-1892_2.png
# 3  saved in  IRM-OldBlue-1892_3.png

# %%
Image(filename='IRM-OldBlue-1892_1.png')

# %%
Image(filename='IRM-OldBlue-1892_3.png')

# %%
Image(filename='IRM-OldBlue-1892_2.png')

# %% [markdown]
# ## common_mean.py

# %%
# !common_mean.py -f ../common_mean/common_mean_ex_file1.dat\
   -f2 ../common_mean/common_mean_ex_file2.dat -sav -fmt png
# Out:
# Doing first set of directions, please be patient..
# Doing second  set of directions, please be patient..
# 2017-05-12 12:54:11.666 python[39282:19625575] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:11.678 python[39282:19625575] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:11.790 python[39282:19625575] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:11.807 python[39282:19625575] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:11.902 python[39282:19625575] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:11.912 python[39282:19625575] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 3  saved in  CD_Z.png
# 2  saved in  CD_Y.png
# 1  saved in  CD_X.png

# %%
Image(filename='CD_X.png')

# %%
Image(filename='CD_Y.png')

# %%
Image(filename='CD_Z.png')

# %% [markdown]
# ## cont_rot.py

# %%
# !cont_rot.py -con af:sam -prj ortho\
    -eye -20 0 -sym k-  1 -age 180 -res l  -fmt png -sav
# Out:
# 2017-05-12 12:54:14.183 python[39288:19625669] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:14.194 python[39288:19625669] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Cont_rot.png

# %%
if basemap_present:
    image = Image(filename="Cont_rot.png")
else: 
    image = None
image

# %% [markdown]
# # convert_samples.py

# %%
# !convert_samples.py -f ../convert_samples/convert_samples_example.dat\
   -F ../convert_samples/orient_Northern_Iceland.txt
# Out:
# file_type er_samples
# 916  records written to file  ./../convert_samples/orient_Northern_Iceland.txt
# Data saved in:  ./../convert_samples/orient_Northern_Iceland.txt

# %% [markdown]
# ## core_depthplot.py

# %%
# !core_depthplot.py -fsa ../core_depthplot/er_samples.txt -LP AF 15 \
    -f ../core_depthplot/magic_measurements.txt -log \
    -d 50 150 -ts gts12 23 34 -D -fmt png -sav
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fsum
# -
# -I- using default for arg: fwig
# -
# -I- using default for arg: fa
# -
# -I- using default for arg: fsp
# -
# -I- using default for arg: fres
# -
# -I- using default for arg: n
# -
# -I- using default for arg: L
# -
# -I- using default for arg: S
# -
# -I- using default for arg: I
# -
# -I- using default for arg: M
# -
# -I- using default for arg: ds
# -
# -I- using default for arg: sym
# -
# 9328  measurements read in from  ./../core_depthplot/magic_measurements.txt
# spec file found

# %%
Image(filename='DSDP Site 522_m__LT-AF-Z_core-depthplot.png')

# %% [markdown]
# # curie.py

# %%
# !curie.py -f ../curie/curie_example.dat -w 10 -fmt png -sav
# Out:
# 2017-05-12 12:54:38.991 python[39358:19626745] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:39.004 python[39358:19626745] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:39.192 python[39358:19626745] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:39.201 python[39358:19626745] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:39.426 python[39358:19626745] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:39.441 python[39358:19626745] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# second derivative maximum is at T=552
# 2017-05-12 12:54:39.870 python[39358:19626745] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:39.883 python[39358:19626745] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 3  saved in  der2.png
# 1  saved in  M_T.png
# 2  saved in  der1.png
# 4  saved in  Curie.png

# %%
Image(filename='M_T.png')

# %% [markdown]
# # customize_criteria.py

# %% [markdown]
# You can't use customize_criteria in the notebook.

# %% [markdown]
# # dayplot_magic2.py

# %%
# !dayplot_magic2.py -WD ../dayplot_magic/ -f dayplot_magic_example.dat \
    -fmt png -sav
# Out:
# 2017-05-12 12:54:42.085 python[39376:19626946] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:42.096 python[39376:19626946] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:42.223 python[39376:19626946] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:42.233 python[39376:19626946] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:42.322 python[39376:19626946] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:42.333 python[39376:19626946] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:42.424 python[39376:19626946] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:42.432 python[39376:19626946] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 3  saved in  unknown_S-Bcr.png
# 2  saved in  unknown_S-Bc.png
# 1  saved in  unknown_day.png

# %%
Image(filename='unknown_day.png')

# %% [markdown]
# # demag_gui.py

# %% [markdown]
# Use demag_gui.py from the command line or from within pmag_gui.py (Pmag GUI).

# %% [markdown]
# # di_eq.py

# %%
# !di_eq.py -f ../di_eq/di_eq_example.dat | tail #|head
# Out:
# 0.393981 0.117451
# -0.017726 0.406002
# 0.154273 0.367000
# 0.213903 0.335760
# 0.103221 0.372202
# 0.231833 0.283245
# 0.072160 0.351538
# 0.007802 0.319236
# 0.152583 0.265350
# 0.248133 0.136412

# %% [markdown]
# # di_geo.py

# %%
# !di_geo.py -f ../di_geo/di_geo_example.dat -F ../di_geo/di_geo.out
# Out:
# ../di_geo/di_geo.out  opened for output

# %% [markdown]
# # di_rot.py

# %%
# !eqarea.py -f ../di_geo/di_geo.out -fmt png -sav
# Out:
# 2017-05-12 12:54:48.304 python[39408:19627285] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:48.315 python[39408:19627285] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  di_geo_eq.png

# %%
Image(filename='di_geo_eq.png')

# %%
# !fishrot.py -I 42 > ../di_rot/fishrot.out
# !gofish.py -f ../di_rot/fishrot.out
# Out:
#   360.0    40.9    100    95.1978     20.6     3.2    17.8

# %%
# !di_rot.py -f ../di_rot/fishrot.out -F ../di_rot/dirot.out -D 359.3 -I 42.1
# !eqarea.py -f ../di_rot/fishrot.out -fmt png -sav
# Out:
# 2017-05-12 12:54:55.147 python[39457:19627676] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:55.158 python[39457:19627676] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  fishrot_eq.png

# %%
Image(filename='fishrot_eq.png')

# %%
# !eqarea.py -f ../di_rot/dirot.out -fmt png -sav
# Out:
# 2017-05-12 12:54:57.096 python[39469:19627782] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:54:57.107 python[39469:19627782] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  dirot_eq.png

# %%
Image(filename='dirot_eq.png')

# %% [markdown]
# # di_tilt.py

# %%
# !di_tilt.py < ../di_tilt/di_tilt_example.dat | tail
# Out:
#   179.6   -27.0
#   180.1   -29.0
#   172.0   -47.0
#   171.0   -38.9
#   177.8   -58.0
#   195.0   -25.7
#   188.4   -56.8
#   166.3   -27.0
#   182.3   -57.6
#   181.9   -40.0

# %% [markdown]
# # di_vgp.py

# %%
# !di_vgp.py -f ../di_vgp/di_vgp_example.dat
# Out:
#   154.7    77.3
#     6.6   -69.6

# %% [markdown]
# # dipole_pinc.py

# %%
# !dipole_pinc.py -f ../dipole_pinc/dipole_pinc_example.dat
# Out:
#   -41.7

# %% [markdown]
# # dipole_plat.py

# %%
# !dipole_plat.py -f ../dipole_plat/dipole_plat_example.dat
# Out:
#    12.0

# %% [markdown]
# # dir_cart.py

# %%
# !dir_cart.py -f ../dir_cart/dir_cart_example.dat
# Out:
# 8.4859e-01 3.0886e-01 9.3514e-01
# -3.8223e+00 3.3441e-01 -1.7083e+00

# %% [markdown]
# # dmag_magic2.py

# %%
# !dmag_magic2.py -f ../dmag_magic/dmag_magic_example.dat -LT AF -fmt png -sav
# Out:
# 2017-05-12 12:55:08.520 python[39519:19628259] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:08.536 python[39519:19628259] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 5921  records read from  ../dmag_magic/dmag_magic_example.dat
# 1  saved in  McMurdo_LT-AF-Z.png

# %%
Image(filename='McMurdo_LT-AF-Z.png')

# %% [markdown]
# # download_magic.py

# %%
# !download_magic.py -WD ../download_magic -f ../download_magic/zmab0083201tmp03.txt
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: O
# -
# 1  records written to file  ../download_magic/er_locations.txt
# 27  records written to file  ../download_magic/er_sites.txt
# 271  records written to file  ../download_magic/er_samples.txt
# 177  records written to file  ../download_magic/er_specimens.txt
# 20  records written to file  ../download_magic/er_ages.txt
# 17  records written to file  ../download_magic/er_citations.txt
# 3072  records written to file  ../download_magic/magic_measurements.txt
# 225  records written to file  ../download_magic/pmag_specimens.txt
# 166  records written to file  ../download_magic/pmag_samples.txt
# 30  records written to file  ../download_magic/pmag_sites.txt
# 24  records written to file  ../download_magic/pmag_results.txt
# 7  records written to file  ../download_magic/pmag_criteria.txt
# 32  records written to file  ../download_magic/magic_methods.txt

# %% [markdown]
# # eigs_s.py

# %%
# !eigs_s.py -f ../eigs_s/eigs_s_example.dat
# Out:
# 0.33416328 0.33280227 0.33303446 -0.00016631 0.00123163 0.00135521
# 0.33555713 0.33197427 0.33246869 0.00085685 0.00025266 0.00098151
# 0.33585301 0.33140355 0.33274350 0.00132308 0.00117787 0.00000455
# 0.33479390 0.33140817 0.33379796 -0.00043088 0.00048858 0.00045610
# 0.33502916 0.33117944 0.33379149 -0.00106313 0.00029828 0.00035883
# 0.33407047 0.33226910 0.33366045 -0.00000638 0.00098445 0.00005996
# 0.33486328 0.33215088 0.33298591 -0.00034279 0.00038178 0.00020145
# 0.33509853 0.33195898 0.33294258 0.00076976 0.00056717 0.00011960

# %% [markdown]
# # eq_di.py

# %%
# !eq_di.py -f ../eq_di/eq_di_example.dat > ../eq_di/eq_di.out
# !eqarea.py -f ../eq_di/eq_di.out -fmt png -sav
# Out:
# 2017-05-12 12:55:18.799 python[39562:19628737] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:18.810 python[39562:19628737] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  eq_di_eq.png

# %%
Image(filename='eq_di_eq.png')

# %% [markdown]
# # eqarea.py

# %%
# !eqarea.py -f ../eqarea/fishrot.out -fmt png -sav
# Out:
# 2017-05-12 12:55:20.778 python[39574:19628862] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:20.789 python[39574:19628862] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  fishrot_eq.png

# %%
Image(filename='fishrot_eq.png')

# %% [markdown]
# # eqarea_ell.py

# %%
# !eqarea_ell.py -f ../eqarea_ell/tk03.out -ell B -fmt png -sav
# Out:
# 2017-05-12 12:55:22.688 python[39592:19628978] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:22.699 python[39592:19628978] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
#      inc    60.3
#      Zeta     4.5
#      Einc    10.0
#      Edec   105.7
#      Zdec    21.0
#      dec   357.8
#      n        20
#      Zinc   -27.6
#      Eta     4.5
# 1  saved in  ..-eqarea_ell-tk03.out_eq.png

# %%
Image(filename='..-eqarea_ell-tk03.out_eq.png')

# %% [markdown]
# # eqarea_magic2.py

# %%
# !eqarea_magic2.py -obj loc -crd g -f ../eqarea_magic/pmag_results.txt\
    -ell Be -fmt png -sav
# Out:
# 2017-05-12 12:55:24.670 python[39604:19629164] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:24.684 python[39604:19629164] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  Snake_River_gu_eqarea.png

# %%
Image(filename='Snake_River_gu_eqarea.png')

# %% [markdown]
# # find_EI.py

# %%
# !find_EI.py -f ../find_EI/find_EI_example.dat -fmt png -sav
# Out:
# 2017-05-12 12:55:28.169 python[39610:19629341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:28.179 python[39610:19629341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:28.308 python[39610:19629341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:28.317 python[39610:19629341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:28.366 python[39610:19629341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:28.378 python[39610:19629341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:28.436 python[39610:19629341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:55:28.448 python[39610:19629341] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Bootstrapping.... be patient
# 25  out of  1000
# 50  out of  1000
# 75  out of  1000
# 100  out of  1000
# 125  out of  1000
# 150  out of  1000
# 175  out of  1000
# 200  out of  1000
# 225  out of  1000
# 250  out of  1000
# 275  out of  1000
# 300  out of  1000
# 325  out of  1000
# 350  out of  1000
# 375  out of  1000
# 400  out of  1000
# 425  out of  1000
# 450  out of  1000
# 475  out of  1000
# 500  out of  1000
# 525  out of  1000
# 550  out of  1000
# 575  out of  1000
# 600  out of  1000
# 625  out of  1000
# 650  out of  1000
# 675  out of  1000
# 700  out of  1000
# 725  out of  1000
# 750  out of  1000
# 775  out of  1000
# 800  out of  1000
# 825  out of  1000
# 850  out of  1000
# 875  out of  1000
# 900  out of  1000
# 925  out of  1000
# 950  out of  1000
# 975  out of  1000
# 1000  out of  1000
# 3  saved in  findEI_cdf.png
# 4  saved in  findEI_v2.png
# 1  saved in  findEI_eq.png
# 2  saved in  findEI_ei.png

# %%
Image(filename='findEI_ei.png')

# %%
Image(filename='findEI_cdf.png')

# %%
Image(filename='findEI_eq.png')

# %%
Image(filename='findEI_v2.png')

# %% [markdown]
# # fisher.py

# %%
# !fisher.py -k 30 -n 10 |head
# Out:
#    97.0    84.2
#    17.1    83.9
#   152.0    81.1
#    81.8    78.5
#    72.3    62.6
#   322.1    82.6
#   197.7    79.6
#    44.1    88.1
#    89.0    74.9
#    95.6    81.3

# %% [markdown]
# # fishqq.py

# %%
# !fishqq.py -f ../fishqq/fishqq_example.txt -fmt png -sav
# Out:
# 2017-05-12 12:56:30.036 python[39657:19634004] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:56:30.048 python[39657:19634004] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:56:30.177 python[39657:19634004] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:56:30.191 python[39657:19634004] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2  saved in  ..-fishqq-fishqq_example.txt_exp1.png
# 1  saved in  ..-fishqq-fishqq_example.txt_unf1.png

# %%
Image(filename='..-fishqq-fishqq_example.txt_unf1.png')

# %%
Image(filename='..-fishqq-fishqq_example.txt_exp1.png')

# %% [markdown]
# # fishrot.py

# %%
# !fishrot.py -n 5 -D 33 -I 41 -k 50
# Out:
#    23.4    33.9
#    27.7    50.8
#    25.4    38.0
#    47.8    51.8
#    35.0    38.2

# %% [markdown]
# # foldtest.py

# %%
# !foldtest.py -f ../foldtest/foldtest_example.dat -fmt png -sav
# Out:
# 2017-05-12 12:56:34.055 python[39676:19634338] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:56:34.067 python[39676:19634338] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:56:34.208 python[39676:19634338] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:56:34.218 python[39676:19634338] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:56:34.330 python[39676:19634338] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:56:34.343 python[39676:19634338] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# doing  1000  iterations...please be patient.....
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 83 - 119 Percent Unfolding
# range of all bootstrap samples:  74  -  136
# 1  saved in  foldtest_ge.png
# 3  saved in  foldtest_ta.png
# 2  saved in  foldtest_st.png

# %%
Image(filename='foldtest_ta.png')

# %%
Image(filename='foldtest_st.png')

# %%
Image(filename='foldtest_ge.png')

# %% [markdown]
# # foldtest_magic.py

# %%
# !download_magic.py -WD ../foldtest_magic -f ../foldtest_magic/magic_contribution_11087.txt |tail
# Out:
# -I- using default for arg: Fsi
# -
# -I- using default for arg: O
# -
# 2  records written to file  ../foldtest_magic/er_locations.txt
# 30  records written to file  ../foldtest_magic/er_sites.txt
# 5  records written to file  ../foldtest_magic/er_citations.txt
# 60  records written to file  ../foldtest_magic/pmag_sites.txt
# 32  records written to file  ../foldtest_magic/pmag_results.txt
# 9  records written to file  ../foldtest_magic/magic_methods.txt

# %%
# !foldtest_magic.py -f ../foldtest_magic/pmag_sites.txt \
    -fsi ../foldtest_magic/er_sites.txt -fmt png -sav
# Out:
# 2017-05-12 12:58:39.051 python[39710:19636328] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:58:39.066 python[39710:19636328] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:58:39.174 python[39710:19636328] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:58:39.185 python[39710:19636328] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:58:39.291 python[39710:19636328] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:58:39.306 python[39710:19636328] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# doing  1000  iterations...please be patient.....
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 94 - 149 Percent Unfolding
# 2  saved in  foldtest_st.png
# 1  saved in  foldtest_ge.png
# 3  saved in  foldtest_ta.png

# %%
Image(filename='foldtest_ge.png')

# %%
Image(filename='foldtest_st.png')

# %%
Image(filename='foldtest_ta.png')

# %% [markdown]
# # gaussian.py

# %%
# !gaussian.py -s 3 -n 1000 -m 10. -F ../gaussian/gaussian.out
# !histplot.py -f ../gaussian/gaussian.out -fmt png -sav
# Out:
# hist.png
# 2017-05-12 12:59:56.796 python[39743:19637576] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 12:59:56.807 python[39743:19637576] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# plot saved in  hist.png

# %%
Image(filename='hist.png')

# %% [markdown]
# # gobing.py

# %%
# !gobing.py -f ../eqarea_ell/tk03.out
# Out:
#   357.8    60.3     4.5   105.7    10.0     4.5    21.0   -27.6 20

# %% [markdown]
# # gofish.py

# %%
# !gofish.py -f ../gofish/fishrot.out
# Out:
#    10.8    39.6    10     9.8484     59.4     6.3    10.5

# %% [markdown]
# # gokent.py

# %%
# !gokent.py -f ../gokent/tk03.out
# Out:
#   359.2    55.0     9.3   147.7    30.8     7.8   246.8    14.9 20

# %% [markdown]
# # goprinc.py

# %%
# !goprinc.py -f ../goprinc/tk03.out
# Out:
# 0.93863    11.0    58.6 0.04258   226.4    26.5 0.01879   128.3    15.6 20

# %% [markdown]
# # grab_magic_key.py

# %%
# !grab_magic_key.py -f ../download_magic/er_sites.txt -key site_lat |head
# Out:
# 42.60264
# 42.60264
# 42.60352
# 42.60104
# 42.73656
# 42.8418
# 42.8657
# 42.92031
# 42.56857
# 42.49964

# %% [markdown]
# # histplot.py
#
# see gaussian.py

# %% [markdown]
# # hysteresis_magic.py

# %%
# !hysteresis_magic.py -f ../hysteresis_magic/hysteresis_magic_example.dat \
    -spc IS06a-1  -fmt png -sav
# Out:
# 2017-05-12 13:00:08.179 python[39782:19637990] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:08.192 python[39782:19637990] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:08.299 python[39782:19637990] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:08.311 python[39782:19637990] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:08.398 python[39782:19637990] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:08.412 python[39782:19637990] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# IS06a-1
# 2017-05-12 13:00:08.694 python[39782:19637990] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:08.704 python[39782:19637990] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2  saved in  _IS06a-1_deltaM.png
# 5  saved in  _IS06a-1_irm.png
# 1  saved in  _IS06a-1_hyst.png
# 3  saved in  _IS06a-1_DdeltaM.png

# %%
Image(filename='_IS06a-1_hyst.png')

# %% [markdown]
# # igrf.py

# %%
# !igrf.py -ages -3000 1950 50 -loc 33 -117 -mod pfm9k -plt -fmt png -sav
# Out:
# 2017-05-12 13:00:11.545 python[39788:19638145] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:11.557 python[39788:19638145] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# Figure saved as:  igrf.png

# %%
Image(filename='igrf.png')

# %% [markdown]
# # install_etopo.py

# %%
# !install_etopo.py
# Out:
# installing etopo20 files from  /Users/nebula/Python/PmagPy/data_files/etopo20/etopo20*
# to the basemap data directory:  /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/data

# %% [markdown]
# # incfish.py

# %%
# !incfish.py -f ../incfish/incfish_example_inc.dat
# Out:
#    57.1    61.0  100     92.9    13.9     1.0

# %% [markdown]
# # irmaq_magic.py

# %%
# !sio_magic2.py -f ../irmaq_magic/U1359A_IRM_coil2.txt -LP I -V 2 \
    -F ../irmaq_magic/U1359A_IRM_coil2.magic -loc U1359A -spc 0 -ncn 5
# !sio_magic2.py -f ../irmaq_magic/U1359A_IRM_coil3.txt -LP I -V 3 \
    -F ../irmaq_magic/U1359A_IRM_coil3.magic -loc U1359A -spc 0 -ncn 5
# !combine_magic.py -F ../irmaq_magic/magic_measurements.txt \
    -f ../irmaq_magic/U1359A_IRM_coil2.magic \
    ../irmaq_magic/U1359A_IRM_coil3.magic -dm 2
# Out:
# 536  records written to file  ../irmaq_magic/U1359A_IRM_coil2.magic
# results put in  ../irmaq_magic/U1359A_IRM_coil2.magic
# 23  records written to file  ../irmaq_magic/U1359A_IRM_coil3.magic
# results put in  ../irmaq_magic/U1359A_IRM_coil3.magic
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# File  ./../irmaq_magic/U1359A_IRM_coil2.magic  read in with  536  records
# File  ./../irmaq_magic/U1359A_IRM_coil3.magic  read in with  23  records
# 559  records written to file  ./../irmaq_magic/magic_measurements.txt
# All records stored in  ./../irmaq_magic/magic_measurements.txt

# %%
# !irmaq_magic.py -f ../irmaq_magic/magic_measurements.txt -fmt png -sav
# Out:
# 2017-05-12 13:00:24.383 python[39845:19639458] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:24.396 python[39845:19639458] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# U1359A
# 1  saved in  U1359A_LP-IRM.png

# %%
Image(filename='U1359A_LP-IRM.png')

# %% [markdown]
# # k15_magic.py

# %%
# !k15_magic.py -WD ../k15_magic  -spc 0 -f ../k15_s/k15_example.dat -loc "Troodos Ophiolite"
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: Fa
# -
# -I- using default for arg: Fr
# -
# -I- using default for arg: ncn
# -
# 12  records written to file  ../k15_magic/er_samples.txt
# 24  records written to file  ../k15_magic/rmag_anisotropy.txt
# 24  records written to file  ../k15_magic/rmag_results.txt
# 120  records written to file  ../k15_magic/magic_measurements.txt
# Data saved to:  ../k15_magic/er_samples.txt ../k15_magic/rmag_anisotropy.txt ../k15_magic/rmag_results.txt ../k15_magic/magic_measurements.txt

# %%
# !k15_s.py -f ../k15_s/k15_example.dat
# Out:
# 0.33146986 0.33413991 0.33439023 0.00075095 -0.00083439 -0.00016688 0.00008618
# 0.33335925 0.33335925 0.33328149 -0.00155521 -0.00132193 0.00116641 0.00017193
# 0.33097634 0.33573565 0.33328801 0.00163177 0.00013598 0.00000000 0.00018131
# 0.33150029 0.33465420 0.33384551 -0.00064696 -0.00056609 -0.00048522 0.00014863
# 0.33121986 0.33521197 0.33356816 -0.00046966 -0.00046966 -0.00086104 0.00018376
# 0.33179570 0.33405602 0.33414828 -0.00009226 -0.00004613 -0.00027677 0.00010474
# 0.33243163 0.33439898 0.33316939 0.00106564 0.00032789 0.00000000 0.00017624
# 0.33175478 0.33512715 0.33311808 0.00078928 0.00000000 -0.00007175 0.00011116

# %%
# !kly4s_magic.py -ID kly4s_magic -WD kly4s_magic -f KLY4S_magic_example.dat -spc 0 -ncn 5
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fad
# -
# -I- using default for arg: fsa
# -
# -I- using default for arg: fsp
# -
# -I- using default for arg: Fsp
# -
# -I- using default for arg: Fa
# -
# -I- using default for arg: ocn
# -
# -I- using default for arg: usr
# -
# -I- using default for arg: loc
# -
# -I- using default for arg: ins
# -
# Error opening file:  kly4s_magic/KLY4S_magic_example.dat

# %% [markdown]
# # lnp_magic.py

# %%
# !download_magic.py  -WD ../lnp_magic -ID ../lnp_magic -f zmab0001193tmp02.txt | tail
# Out:
# 306  records written to file  ../lnp_magic/er_specimens.txt
# 15  records written to file  ../lnp_magic/er_ages.txt
# 11  records written to file  ../lnp_magic/er_citations.txt
# 4142  records written to file  ../lnp_magic/magic_measurements.txt
# 196  records written to file  ../lnp_magic/pmag_specimens.txt
# 189  records written to file  ../lnp_magic/pmag_samples.txt
# 35  records written to file  ../lnp_magic/pmag_sites.txt
# 17  records written to file  ../lnp_magic/pmag_results.txt
# 7  records written to file  ../lnp_magic/pmag_criteria.txt
# 24  records written to file  ../lnp_magic/magic_methods.txt

# %%
# !lnp_magic.py -f ../lnp_magic/pmag_specimens.txt -crd g -fmt png -sav |head
# Out:
# 2017-05-12 13:00:35.678 python[39896:19640758] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:35.690 python[39896:19640758] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# sv01
# Site lines planes  kappa   a95   dec   inc
# sv01 0  5     286      6.6    179.0    -54.3  4.9948
# % tilt correction:  0
# 1  saved in  sv01_g_eqarea.png
# sv02
# Site lines planes  kappa   a95   dec   inc
# sv02 4  2     113      6.6    338.8     38.6  5.9647
# % tilt correction:  0
# 1  saved in  sv02_g_eqarea.png

# %%
Image(filename='sv01_g_eqarea.png')

# %%
# !lowrie.py -f ../lowrie/lowrie_example.dat -fmt png -sav | tail
# Out:
# 2017-05-12 13:00:44.221 python[39954:19641326] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:44.234 python[39954:19641326] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 318-U1359A-014H-6-W-13
# 1  saved in  lowrie__318-U1359A-014H-6-W-13_.png
# 318-U1359A-015H-2-W-56
# 1  saved in  lowrie__318-U1359A-015H-2-W-56_.png
# 318-U1359A-015H-4-W-83
# 1  saved in  lowrie__318-U1359A-015H-4-W-83_.png
# 318-U1359A-018X-6-W-57
# 1  saved in  lowrie__318-U1359A-018X-6-W-57_.png
# 318-U1359A-022X-2-W-95
# 1  saved in  lowrie__318-U1359A-022X-2-W-95_.png

# %%
Image(filename='lowrie__318-U1359A-002H-1-W-109_.png')

# %% [markdown]
# # lowrie_magic.py

# %%
# !lowrie_magic.py -f ../lowrie_magic/lowrie_magic_example.dat -fmt png -sav | head
# Out:
# 2017-05-12 13:00:51.261 python[40008:19642210] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:00:51.276 python[40008:19642210] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# ./../lowrie_magic/lowrie_magic_example.dat
# 318-U1359A-002H-1-W-109
# 1  saved in  lowrie__318-U1359A-002H-1-W-109_.png
# 318-U1359A-002H-4-W-65
# 1  saved in  lowrie__318-U1359A-002H-4-W-65_.png
# 318-U1359A-002H-6-W-7
# 1  saved in  lowrie__318-U1359A-002H-6-W-7_.png
# 318-U1359A-003H-2-W-37
# 1  saved in  lowrie__318-U1359A-003H-2-W-37_.png
# 318-U1359A-003H-6-W-66

# %%
Image(filename='lowrie__318-U1359A-002H-1-W-109_.png')

# %% [markdown]
# # magic_select.py

# %%
# !magic_select.py -f ../magic_select/pmag_specimens.txt \
    -key magic_method_codes LP-DIR-AF has -F ../magic_select/AF_specimens.txt
# Out:
# 76  records written to file  ./../magic_select/AF_specimens.txt

# %% [markdown]
# # measurements_normalize.py

# %%
# !measurements_normalize.py -f ../measurements_normalize/irm_measurements.txt \
    -fsp ../measurements_normalize/specimens_weights.txt \
    -F ../measurements_normalize/irm_norm_measurements.txt
# Out:
# 17721  records written to file  ./../measurements_normalize/irm_norm_measurements.txt
# Data saved in  ./../measurements_normalize/irm_norm_measurements.txt

# %% [markdown]
# # mk_redo.py

# %%
# !mk_redo.py -f pmag_specimens.txt -WD ../mk_redo
# Out:
# Redo files saved to:  ../mk_redo/zeq_redo ../mk_redo/thellier_redo

# %%
# !head ../mk_redo/zeq_redo
# Out:
# sr01a1 DE-BFL 473 823 A
# sr01a2 DE-BFL 473 848 A
# sr01c2 DE-BFL 473 823 A
# sr01d1 DE-BFL 373 798 A
# sr01e2 DE-BFL 0.01 0.18 A
# sr01f2 DE-BFL 423 923 A
# sr01g2 DE-BFL 0.01 0.16 A
# sr01i1 DE-BFL 473 823 A
# sr03a1 DE-BFL 473 823 A
# sr03b1 DE-BFL 673 823 A

# %%
# !head ../mk_redo/thellier_redo
# Out:
# sr01a1 573 823
# sr01a2 573 848
# sr01c2 673 823
# sr01d1 373 823
# sr01i1 373 773
# sr03a1 373 673
# sr03b1 373 673
# sr03c1 423 673
# sr03e1 423 673
# sr09f1 373 573

# %% [markdown]
# # nrm_specimens_magic.py

# %%
# !download_magic.py -WD ../nrm_specimens_magic \
-f ../nrm_specimens_magic/zmab0083201tmp03.txt |tail
# Out:
# 177  records written to file  ../nrm_specimens_magic/er_specimens.txt
# 20  records written to file  ../nrm_specimens_magic/er_ages.txt
# 17  records written to file  ../nrm_specimens_magic/er_citations.txt
# 3072  records written to file  ../nrm_specimens_magic/magic_measurements.txt
# 225  records written to file  ../nrm_specimens_magic/pmag_specimens.txt
# 166  records written to file  ../nrm_specimens_magic/pmag_samples.txt
# 30  records written to file  ../nrm_specimens_magic/pmag_sites.txt
# 24  records written to file  ../nrm_specimens_magic/pmag_results.txt
# 7  records written to file  ../nrm_specimens_magic/pmag_criteria.txt
# 32  records written to file  ../nrm_specimens_magic/magic_methods.txt

# %%
# !nrm_specimens_magic.py -WD ../nrm_specimens_magic -crd g
# Out:
# ../nrm_specimens_magic/er_samples.txt  read in with  271  records
# 177  records written to file  ../nrm_specimens_magic/nrm_specimens.txt
# Data saved in  ../nrm_specimens_magic/nrm_specimens.txt

# %%
# !eqarea_magic2.py -f ../nrm_specimens_magic/nrm_specimens.txt -crd g -fmt png -sav
# Out:
# 2017-05-12 13:01:09.699 python[40171:19645053] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:09.711 python[40171:19645053] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  Snake_River_g_eqarea.png

# %%
Image(filename='Snake_River_g_eqarea.png')

# %% [markdown]
# # orientation_magic.py

# %%
# !orientation_magic.py -WD ../orienation_magic -f orient_example.txt | tail
# Out:
# -I- using default for arg: gmt
# -
# -I- using default for arg: mcd
# -
# -I- using default for arg: a
# -
# -I- using default for arg: DM
# -
# saving data...
# Data saved in  ../orienation_magic/samples.txt  and  ../orienation_magic/sites.txt

# %%
# !parse_measurements.py -WD ../parse_measurements |tail
# Out:
# site record in er_sites table not found for:  318-U1359A-010H-2-W-73
# site record in er_sites table not found for:  318-U1359A-017H-2-W-64
# site record in er_sites table not found for:  318-U1359A-018X-6-W-57
# site record in er_sites table not found for:  318-U1359A-019X-4-W-40
# site record in er_sites table not found for:  318-U1359A-021X-4-W-18
# site record in er_sites table not found for:  318-U1359A-022X-2-W-95
# 63  records written to file  ../parse_measurements/er_specimens.txt
#  Er_Specimen data (with updated info from site if necessary)  saved in  ../parse_measurements/er_specimens.txt
# 1  records written to file  ../parse_measurements/magic_instruments.txt
#  Instruments data saved in  ../parse_measurements/magic_instruments.txt

# %% [markdown]
# # pca.py

# %%
# !pca.py -dir L 1 10 -f ../pca/zeq_example.dat
# Out:
# eba24a DE-BFL
# 0 0.00 339.9 57.9 9.2830e-05
# 1 2.50 325.7 49.1 7.5820e-05
# 2 5.00 321.3 45.9 6.2920e-05
# 3 10.00 314.8 41.7 5.2090e-05
# 4 15.00 310.3 38.7 4.4550e-05
# 5 20.00 305.0 37.0 3.9540e-05
# 6 30.00 303.9 34.7 3.2570e-05
# 7 40.00 303.0 32.3 2.5670e-05
# 8 50.00 303.6 32.4 2.2520e-05
# 9 60.00 299.8 30.8 1.9820e-05
# 10 70.00 292.5 31.0 1.3890e-05
# 11 80.00 297.0 25.6 1.2570e-05
# 12 90.00 299.3 11.3 0.5030e-05
# eba24a DE-BFL 10    2.50  70.00    8.8   334.9    51.5

# %% [markdown]
# # plotXY.py

# %%
# !plotXY.py -f ../plotXY/plotXY_example.txt -fmt png -sav
# Out:
# Figure saved as  plotXY.png

# %%
Image(filename='plotXY.png')

# %% [markdown]
# # plot_cdf.py

# %%
# !plot_cdf.py -f ../plot_cdf/gaussian.out -fmt png -sav
# Out:
# 2017-05-12 13:01:18.900 python[40237:19646297] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:18.914 python[40237:19646297] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  CDF_.png

# %%
Image(filename='CDF_.png')

# %% [markdown]
# # plot_mapPTS.py

# %%
# !plot_map_pts.py -f ../plot_mapPTS/uniform.out -B -R \
    -prj ortho -eye 30 0 -etp -sym wo 10 -fmt png -sav
# Out:
# 2017-05-12 13:01:20.819 python[40246:19646585] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:20.831 python[40246:19646585] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# please wait to draw points
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Map_PTS.png

# %%
if basemap_present:
    image = Image(filename='Map_PTS.png')
else:
    image = None
image

# %% [markdown]
# # plotdi_a.py

# %%
# !plotdi_a.py -f ../plotdi_a/plotdi_a_example.dat -fmt png -sav
# Out:
# 2017-05-12 13:01:25.439 python[40263:19647208] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:25.451 python[40263:19647208] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  eq.png

# %%
Image(filename='eq.png')

# %% [markdown]
# # pmag_results_extract.py

# %%
# !pmag_results_extract.py -WD ../pmag_results_extract -f pmag_results.txt
# Out:
# data saved in:  /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/Directions.txt /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/Intensities.txt /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/SiteNfo.txt

# %% [markdown]
# # pt_rot.py

# %%
# !awk '{print $1,$2}' ../pt_rot/pt_rot.input > ../pt_rot/lon_lat
# !plot_map_pts.py -prj moll -f ../pt_rot/lon_lat -sym g^ 10 -R -B -eye 0 0 -fmt png -sav
# Out:
# 2017-05-12 13:01:29.574 python[40301:19647926] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:29.590 python[40301:19647926] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# please wait to draw points
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Map_PTS.png

# %%
if basemap_present:
    image = Image(filename='Map_PTS.png')
else:
    image = None
image

# %%
# !cat ../pt_rot/pt_rot.input
# !pt_rot.py -f ../pt_rot/pt_rot.input > ../pt_rot/pt_rot.out
# Out:
# -84.7 39.1 nam 80 saf

# %%
# !plot_map_pts.py -prj moll -f ../pt_rot/pt_rot.out -sym ro 10 -R -B -eye 0 0 -fmt png -sav
# Out:
# 2017-05-12 13:01:34.253 python[40354:19648659] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:34.263 python[40354:19648659] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# please wait to draw points
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Map_PTS.png

# %%
if basemap_present:
    image = Image(filename='Map_PTS.png')
else:
    image = None
image

# %% [markdown]
# Something still weird about pt_rot.py (the -ff option).

# %%
# !pt_rot.py -ff ../pt_rot/nam_180-200.txt ../pt_rot/nam_panA.frp > ../pt_rot/pt_rot_panA.out

# %%
# !plot_map_pts.py -f ../pt_rot/pt_rot_panA.out -prj ortho -eye 60 90 -sym ro 10 -B -R -fmt png -sav
# Out:
# 2017-05-12 13:01:38.829 python[40399:19649296] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:38.844 python[40399:19649296] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# please wait to draw points
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Map_PTS.png

# %%
if basemap_present:
    image = Image(filename='Map_PTS.png')
else:
    image = None
image

# %% [markdown]
# # qqplot.py

# %%
# !qqplot.py -f ../qqplot/gauss.out -fmt png -sav
# Out:
# 2017-05-12 13:01:42.057 python[40433:19649480] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:42.070 python[40433:19649480] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# mean,sigma, d, Dc
# -0.09482124000000011 0.941267146559 0.0770098421346 0.0886
# 1  saved in  qq.png

# %%
Image(filename='qq.png')

# %% [markdown]
# # quick_hyst2.py

# %%
# !quick_hyst2.py -f ../hysteresis_magic/hysteresis_magic_example.dat -fmt png -sav |head
# Out:
# 2017-05-12 13:01:43.976 python[40447:19649593] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:43.987 python[40447:19649593] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# verbose 0
# working on t:  273
# 1  saved in  IS06_IS06a_IS06a-1_hyst.png
# working on t:  273
# 1  saved in  IS06_IS06a_IS06a-2_hyst.png
# working on t:  273
# 1  saved in  IS06_IS06a_IS06a-3_hyst.png
# working on t:  273
# 1  saved in  IS06_IS06a_IS06a-4_hyst.png
# working on t:  273

# %%
Image(filename='IS06_IS06a_IS06a-1_hyst.png')

# %% [markdown]
# # revtest.py

# %%
# !revtest.py -f ../revtest/revtest_example.txt -fmt png -sav
# Out:
# 2017-05-12 13:01:46.932 python[40470:19650052] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:46.944 python[40470:19650052] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:47.075 python[40470:19650052] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:47.089 python[40470:19650052] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:47.190 python[40470:19650052] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:47.205 python[40470:19650052] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# doing first mode, be patient
# doing second mode, be patient
# 3  saved in  REV_Z.png
# 2  saved in  REV_Y.png
# 1  saved in  REV_X.png

# %%
Image(filename='REV_X.png')

# %%
Image(filename='REV_Y.png')

# %%
Image(filename='REV_Z.png')

# %% [markdown]
# # revtest_magic.py

# %%
# !revtest_magic.py -f ../revtest_magic/revtest_magic_example.txt -fmt png -sav
# Out:
# 2017-05-12 13:01:51.481 python[40492:19650587] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:51.495 python[40492:19650587] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:51.644 python[40492:19650587] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:51.658 python[40492:19650587] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:51.754 python[40492:19650587] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:01:51.762 python[40492:19650587] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# doing first mode, be patient
# doing second mode, be patient
# 1  saved in  REV_X.png
# 2  saved in  REV_Y.png
# 3  saved in  REV_Z.png

# %%
Image(filename='REV_X.png')

# %% [markdown]
# # s_eigs.py

# %%
# !s_eigs.py -f ../s_eigs/s_eigs_example.dat
# Out:
# 0.33127186 239.53  44.70 0.33351338 126.62  21.47 0.33521473  19.03  37.54
# 0.33177859 281.12   6.18 0.33218277 169.79  73.43 0.33603862  12.82  15.32
# 0.33046979 283.57  27.30 0.33328307 118.37  61.91 0.33624712  16.75   6.13
# 0.33123776 261.36  12.07 0.33377582 141.40  66.82 0.33498645 355.70  19.48
# 0.33085680 255.71   7.13 0.33379164 130.85  77.65 0.33535156 346.97  10.03
# 0.33175930 268.51  26.79 0.33405024 169.66  16.95 0.33419049  51.04  57.53
# 0.33194992 261.59  20.68 0.33313262  92.18  68.99 0.33491743 352.93   3.54
# 0.33157593 281.42  21.32 0.33312121 117.04  67.94 0.33530283  13.54   5.41

# %% [markdown]
# # s_geo.py

# %%
# !s_geo.py -f ../s_geo/s_geo_example.dat
# Out:
# 0.33412680 0.33282733 0.33304587 -0.00015289 0.00124843 0.00135721
# 0.33556300 0.33198264 0.33245432 0.00087259 0.00024141 0.00096166
# 0.33584908 0.33140627 0.33274469 0.00131845 0.00118816 0.00002986
# 0.33479756 0.33142531 0.33377719 -0.00047493 0.00049539 0.00044303
# 0.33505613 0.33114848 0.33379540 -0.00101375 0.00028536 0.00034852
# 0.33406156 0.33226916 0.33366925 -0.00002267 0.00098548 0.00005553
# 0.33486596 0.33216032 0.33297369 -0.00035492 0.00039254 0.00015403
# 0.33510646 0.33196402 0.33292958 0.00075965 0.00057242 0.00010112

# %% [markdown]
# # s_hext.py

# %%
# !s_geo.py -f ../s_geo/s_geo_example.dat | s_hext.py
# Out:
# F =  5.79 F12 =  3.55 F23 =  3.66
# N =  8  sigma =  0.000641809950
# 0.33505     5.3    14.7    25.5   124.5    61.7    13.3   268.8    23.6
# 0.33334   124.5    61.7    25.1   268.8    23.6    25.5     5.3    14.7
# 0.33161   268.8    23.6    13.3     5.3    14.7    25.1   124.5    61.7

# %% [markdown]
# # s_tilt.py

# %%
# !s_tilt.py -f ../s_tilt/s_tilt_example.dat
# Out:
# 0.33455709 0.33192658 0.33351630 -0.00043562 0.00092779 0.00105006
# 0.33585501 0.33191565 0.33222935 0.00055960 -0.00005316 0.00064732
# 0.33586669 0.33084923 0.33328408 0.00142266 0.00013234 0.00009203
# 0.33488664 0.33138493 0.33372843 -0.00056597 -0.00039085 0.00004873
# 0.33506602 0.33127019 0.33366373 -0.00105193 -0.00057257 -0.00029959
# 0.33407688 0.33177567 0.33414748 0.00007007 0.00018447 0.00005073
# 0.33483925 0.33197853 0.33318222 -0.00028447 0.00003518 -0.00029262
# 0.33513144 0.33175036 0.33311823 0.00077914 -0.00006402 0.00004612

# %% [markdown]
# # s_magic.py

# %%
# !s_magic.py -WD ../s_magic -f s_magic_example.dat
# Out:
# 8  records written to file  ../s_magic/rmag_anisotropy.txt
# data saved in  ../s_magic/rmag_anisotropy.txt

# %% [markdown]
# # scalc.py

# %%
# !scalc.py -f ../scalc/scalc_example.txt
# Out:
# 99    19.5     90.0

# %%
# !scalc.py -f ../scalc/scalc_example.txt -v
# Out:
# 89    15.2     32.3

# %%
# !scalc.py -f ../scalc/scalc_example.txt -v -b
# Out:
# please be patient...   bootstrapping
# 89    15.2    13.4     16.9    32.3

# %% [markdown]
# # scalc_magic.py

# %%
# !scalc_magic.py -f ../scalc_magic/pmag_results.txt -c 30
# Out:
# 13    17.8     30.0

# %% [markdown]
# # site_edit.py
#
# This program requires user interaction and can only be used on the command line.

# %% [markdown]
# # specimens_results_magic.py
#
# This program has been superceded by Pmag GUI and is not maintained.

# %% [markdown]
# # stats.py

# %%
# !stats.py -f ../gaussian/gauss.out
# Out:
# 100 9.94986999 994.9869990000003 0.958167360921 9.62994855092

# %% [markdown]
# # strip_magic.py

# %%
# !strip_magic.py -f ../strip_magic/pmag_results.txt -x age -y lat -fmt png -sav
# Out:
# 2017-05-12 13:02:34.849 python[40600:19654886] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:02:34.863 python[40600:19654886] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  strat.png

# %%
Image(filename='strat.png')

# %% [markdown]
# # sundec.py

# %%
# !sundec.py -f ../sundec/sundec_example.dat
# Out:
#   154.2

# %% [markdown]
# # thellier_magic.py
#
# This program is no longer maintained - try Thellier GUI instead.

# %% [markdown]
# # thellier_magic_redo.py
#
# The function of this program has been incorporated into Thellier GUI so you should use that instead.

# %% [markdown]
# # tk03.py

# %%
# !tk03.py -lat 30 > ../tk03/tk03.out
# !eqarea.py -f ../tk03/tk03.out -fmt png -sav
# Out:
# 2017-05-12 13:02:40.973 python[40639:19655641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:02:40.983 python[40639:19655641] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  tk03_eq.png

# %%
Image(filename='tk03_eq.png')

# %% [markdown]
# # uniform.py

# %%
# !uniform.py -n 50 | tail
# Out:
#   159.5    46.4
#   349.7    31.0
#   332.9    27.5
#   219.5   -23.8
#   215.6   -20.9
#    58.3   -52.8
#   106.2     3.4
#   208.5   -52.4
#   155.2    -2.1
#   105.5    32.5

# %%
# !uniform.py -n 50 > ../uniform/uniform.out
# !eqarea.py -f ../uniform/uniform.out -fmt png -sav
# Out:
# 2017-05-12 13:02:47.056 python[40688:19656530] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:02:47.067 python[40688:19656530] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  uniform_eq.png

# %%
Image(filename='uniform_eq.png')

# %% [markdown]
# # update_measurements.txt
#
# This program has been superceded by Pmag GUI, so you should use that.

# %% [markdown]
# # upload_magic.py
#
# program has been superceded by Pmag GUI, so you should use that.

# %% [markdown]
# # vdm_b.py

# %%
# !vdm_b.py -f ../vdm_b/vdm_b_example.dat
# Out:
#  3.300e-05

# %%
# !cat ../b_vdm/b_vdm_example.dat
# Out:
# 33 22

# %% [markdown]
# # vector_mean.py

# %%
# !vector_mean.py -f ../vector_mean/vector_mean_example.dat
# Out:
#     1.3    49.6    2.289e+06 100

# %% [markdown]
# # vgp_di.py

# %%
# !vgp_di.py -f ../vgp_di/vgp_di_example.dat
# Out:
#   335.6    62.9

# %% [markdown]
# # vgpmap_magic2.py

# %%
# !vgpmap_magic2.py -f ../vgpmap_magic/pmag_results.txt \
    -crd g -prj ortho -eye 60 0 -etp -sym wo 10 -fmt png -sav
# Out:
# 2017-05-12 13:02:54.950 python[40733:19657132] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:02:54.960 python[40733:19657132] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/nebula/anaconda/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1  saved in  Snake_River_VGP_map.png

# %%
if basemap_present:
    image = Image(filename='Snake_River_VGP_map.png')
else:
    image = None
image

# %% [markdown]
# # watsons_f.py

# %%
# !watsons_f.py -f ../watsonsF/watsonsF_example_file1.dat \
-f2 ../watsonsF/watsonsF_example_file2.dat
# Out:
#    5.23    3.26

# %% [markdown]
# # watsons_v.py

# %%
# !watsons_v.py -f ../watsonsF/watsonsF_example_file1.dat \
-f2 ../watsonsF/watsonsF_example_file2.dat -fmt png -sav
# Out:
# Watson's V,  Vcrit:
#          10.5        6.3
# 2017-05-12 13:03:05.899 python[40764:19657654] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 2017-05-12 13:03:05.913 python[40764:19657654] setCanCycle: is deprecated.  Please use setCollectionBehavior instead
# 1  saved in  watsons_v_watsonsF_example_file1_watsonsF_example_file2.png

# %%
Image(filename="watsons_v_watsonsF_example_file1_watsonsF_example_file2.png")

# %% [markdown]
# # zeq.py
#
# This program requires interaction and can only be run from the command line.

# %% [markdown]
# # zeq_magic.py
#
# This program is no longer maintained.  It has been superceded by demag_gui.py

# %% [markdown]
# # cleanup the directory

# %%
# !rm *.png  
# !rm ..*.png
# !rm ../dayplot_magic/*.svg
# Out:
# rm: ../dayplot_magic/*.svg: No such file or directory

# %%
# !rm *.txt
