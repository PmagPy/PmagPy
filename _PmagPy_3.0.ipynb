# %%
#import pmagpy.ipmag as ipmag
import pmagpy.pmagplotlib as pmagplotlib
import pmagpy.pmag as pmag
from IPython.display import Image
import matplotlib as plt
import sys
# %matplotlib inline

# %%
# !python programs/eqarea_magic3.0.py -WD 3_0/McMurdo -f custom_sites.txt -sav -fmt "png"
Image(filename="LO:_McMurdo_SI:_mc01_SA:__SP:__CO:_g_TY:_eqarea_.png")
# Out:
# 1  saved in  LO:_McMurdo_SI:_mc01_SA:__SP:__CO:_g_TY:_eqarea_.png

# %%
# !python programs/dmag_magic3.0.py -WD 3_0/McMurdo -fsp custom_specimens.txt -obj spc -sav -fmt "png"
Image(filename="mc01f_LT-AF-Z.png")
# Out:
# 21454  records read from  measurements.txt
# 1  saved in  mc01f_LT-AF-Z.png
# 1  saved in  mc02c_LT-AF-Z.png
# 1  saved in  mc02e_LT-AF-Z.png
# 1  saved in  mc02g_LT-AF-Z.png
# 1  saved in  mc03b_LT-AF-Z.png
# 1  saved in  mc03d_LT-AF-Z.png
# 1  saved in  mc04a_LT-AF-Z.png
# 1  saved in  mc04h_LT-AF-Z.png
# 1  saved in  mc06c_LT-AF-Z.png
# 1  saved in  mc07e_LT-AF-Z.png
# 1  saved in  mc08d_LT-AF-Z.png
# 1  saved in  mc09h_LT-AF-Z.png
# 1  saved in  mc100a1_LT-AF-Z.png
# 1  saved in  mc100d1_LT-AF-Z.png
# 1  saved in  mc100e1_LT-AF-Z.png
# 1  saved in  mc100g1_LT-AF-Z.png
# 1  saved in  mc100h2_LT-AF-Z.png
# 1  saved in  mc101a1_LT-AF-Z.png
# 1  saved in  mc101b1_LT-AF-Z.png
# 1  saved in  mc101c1_LT-AF-Z.png
# 1  saved in  mc101d1_LT-AF-Z.png
# 1  saved in  mc101f1_LT-AF-Z.png
# 1  saved in  mc101h1_LT-AF-Z.png
# 1  saved in  mc102a1_LT-AF-Z.png
# 1  saved in  mc102b2_LT-AF-Z.png
# 1  saved in  mc102e1_LT-AF-Z.png
# 1  saved in  mc102f1_LT-AF-Z.png
# ...

# %%
# !python programs/dmag_magic3.0.py -WD 3_0/McMurdo -fsp custom_specimens.txt -fsa custom_samples.txt -obj sit -sav -fmt "png"
# Out:
# 21454  records read from  measurements.txt
# 1  saved in  mc01_LT-AF-Z.png
# 1  saved in  mc02_LT-AF-Z.png
# 1  saved in  mc03_LT-AF-Z.png
# 1  saved in  mc04_LT-AF-Z.png
# 1  saved in  mc06_LT-AF-Z.png
# 1  saved in  mc07_LT-AF-Z.png
# 1  saved in  mc08_LT-AF-Z.png
# 1  saved in  mc09_LT-AF-Z.png
# 1  saved in  mc10_LT-AF-Z.png
# 1  saved in  mc100_LT-AF-Z.png
# 1  saved in  mc101_LT-AF-Z.png
# 1  saved in  mc102_LT-AF-Z.png
# 1  saved in  mc103_LT-AF-Z.png
# 1  saved in  mc104_LT-AF-Z.png
# 1  saved in  mc105_LT-AF-Z.png
# 1  saved in  mc106_LT-AF-Z.png
# 1  saved in  mc107_LT-AF-Z.png
# 1  saved in  mc108_LT-AF-Z.png
# 1  saved in  mc109_LT-AF-Z.png
# 1  saved in  mc11_LT-AF-Z.png
# 1  saved in  mc110_LT-AF-Z.png
# 1  saved in  mc111_LT-AF-Z.png
# 1  saved in  mc112_LT-AF-Z.png
# 1  saved in  mc113_LT-AF-Z.png
# 1  saved in  mc114_LT-AF-Z.png
# 1  saved in  mc115_LT-AF-Z.png
# 1  saved in  mc116_LT-AF-Z.png
# 1  saved in  mc117_LT-AF-Z.png
# 1  saved in  mc118_LT-AF-Z.png
# ...

# %%
Image(filename="mc01_LT-AF-Z.png")

# %%
# !python programs/quick_hyst3.0.py -WD 3_0/McMurdo -spc mc04c-1 -fmt png
Image("LO:__SI:__SA:__SP:_mc04c-1_TY:_hyst_.png")
# Out:
# -W- No hysteresis data found

# %%
# !python programs/quick_hyst3.0.py -WD 3_0/Osler -fmt png
# Out:
# -W- No such file: /Users/nebula/Python/PmagPy/3_0/Osler/measurements.txt
# -W- No measurement file found

# %%
# !python programs/vgpmap_magic3.0.py -WD 3_0/McMurdo -f custom_sites.txt -crd g -prj ortho -eye 60 0  -sym ko 10 -fmt png -S -sav
Image("LO:_McMurdo_VGP_map.png")
# Out:
# 1  saved in  LO:_McMurdo_VGP_map.png

# %%
# !python programs/dayplot_magic3.0.py -WD 3_0/McMurdo -f custom_specimens.txt -sav -fmt png

Image("LO:__SI:__SA:__SP:__TY:_day_.png")
# Out:
# 3  saved in  LO:__SI:__SA:__SP:__TY:_S-Bcr_.png
# 1  saved in  LO:__SI:__SA:__SP:__TY:_day_.png
# 2  saved in  LO:__SI:__SA:__SP:__TY:_S-Bc_.png

# %%
# !python programs/aniso_magic3.0.py -WD 3_0/McMurdo/ -B -x -par -crd g -f custom_specimens.txt -fsa custom_samples.txt -fsi custom_sites.txt -sav -fmt png
Image("LO:_McMurdo_SI:__SA:__SP:__CO:_s_TY:_aniso-data_.png")
# Out:
# 1  saved in  LO:_McMurdo_SI:__SA:__SP:__CO:_s_TY:_aniso-data_.png
# 2  saved in  LO:_McMurdo_SI:__SA:__SP:__CO:_s_TY:_aniso-conf_.png

# %%
Image("LO:_McMurdo_SI:__SA:__SP:__CO:_s_TY:_aniso-conf_.png")

# %%
# !rm sites.txt samples.txt specimens.txt measurements.txt ages.txt contribution.txt images.txt criteria.txt locations.txt
# !rm *.png
# !rm *.jpg
# Out:
# rm: sites.txt: No such file or directory
# rm: samples.txt: No such file or directory
# rm: specimens.txt: No such file or directory
# rm: measurements.txt: No such file or directory
# rm: ages.txt: No such file or directory
# rm: contribution.txt: No such file or directory
# rm: images.txt: No such file or directory
# rm: criteria.txt: No such file or directory
# rm: locations.txt: No such file or directory
# rm: *.jpg: No such file or directory
