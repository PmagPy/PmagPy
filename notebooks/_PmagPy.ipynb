# %% [markdown]
# This notebook tests the PmagPy distribution files using the examples in the PmagPy cookbook:  http://earthref.org/PmagPy/
#
# It is meant to function from within the PmagPy/data_files directory and calls are relative to that.
# To specify a working directory, many programs have the hidden command line argument -WD.

# %%
#import pmagpy.ipmag as ipmag
import pmagpy.pmagplotlib as pmagplotlib
import pmagpy.pmag as pmag
from IPython.display import Image
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# # aarm_magic.py

# %%
# !sio_magic.py -f ../data_files/aarm_magic/arm_magic_example.dat -loc Bushveld -LP AF:ANI \
    -F ../data_files/aarm_magic/aarm_measurements.txt -ncn 3 -ac 180 -dc 50 -1 -1
# Out:
# 126  records written to file  ../data_files/aarm_magic/aarm_measurements.txt
# results put in  ../data_files/aarm_magic/aarm_measurements.txt

# %%
# !aarm_magic.py -f ../data_files/aarm_magic/aarm_measurements.txt
# Out:
# 7  records written to file  ./arm_anisotropy.txt
# specimen tensor elements stored in  ./arm_anisotropy.txt
# 7  records written to file  ./aarm_results.txt
# specimen statistics and eigenparameters stored in  ./aarm_results.txt

# %% [markdown]
# # angle.py

# %%
# !angle.py -f ../data_files/angle/angle.dat | head
# Out:
#    75.9
#   119.1
#   103.7
#    81.4
#   120.1
#   100.9
#    95.1
#    74.1
#    78.4
#   120.1

# %% [markdown]
# # ANI_depthplot.py

# %%
# !ani_depthplot.py -f ../data_files/ani_depthplot/rmag_anisotropy.txt -fsa ../data_files/ani_depthplot/er_samples.txt \
    -fb ../data_files/ani_depthplot/magic_measurements.txt -sav -fmt png
Image(filename='U1361A_ani_depthplot.png')
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fa
# -
# -I- using default for arg: fsum
# -
# -I- using default for arg: ds
# -
# -I- using default for arg: d
# -
# Saved file: U1361A_ani_depthplot.png in folder: /Users/nebula/Python/PmagPy/notebooks

# %% [markdown]
# # aniso_magic.py

# %%
# !aniso_magic.py -f ../data_files/aniso_magic/dike_anisotropy.txt -gtc 110 2 -par -v -crd g \
   -F ../data_files/aniso_magic/rmag_results.txt -fmt png -sav
# Out:
# Doing bootstrap - be patient
# 3  saved in  LO:_Scripps Beach_SI:__SA:__SP:__CO:_g_TY:_aniso-tcdf_.png
# 1  saved in  LO:_Scripps Beach_SI:__SA:__SP:__CO:_g_TY:_aniso-data_.png
# 2  saved in  LO:_Scripps Beach_SI:__SA:__SP:__CO:_g_TY:_aniso-conf_.png
# 7  records written to file  ./../data_files/aniso_magic/rmag_results.txt

# %%
Image(filename='LO:_Scripps Beach_SI:__SA:__SP:__CO:_g_TY:_aniso-tcdf_.png')

# %%
Image(filename='LO:_Scripps Beach_SI:__SA:__SP:__CO:_g_TY:_aniso-data_.png')

# %%
Image(filename='LO:_Scripps Beach_SI:__SA:__SP:__CO:_g_TY:_aniso-conf_.png')

# %% [markdown]
# # apwp.py

# %%
# !apwp.py -f ../data_files/apwp/apwp_example.dat
# Out:
#    100.0    38.8   352.4    58.1    81.5   198.3

# %% [markdown]
# # atrm_magic.py

# %%
# !sio_magic.py -f ../data_files/atrm_magic/atrm_magic_example.dat -loc Africa -LP T:ANI\
    -F ../data_files/atrm_magic/atrm_measurements.txt -ncn 1 -dc 40 -1 -1
# Out:
# 210  records written to file  ../data_files/atrm_magic/atrm_measurements.txt
# results put in  ../data_files/atrm_magic/atrm_measurements.txt

# %%
# !atrm_magic.py -f ../data_files/atrm_magic/atrm_measurements.txt\
   -Fa ../data_files/atrm_magic/trm_anisotropy.txt -Fr ../data_files/atrm_magic/atrm_results.txt
# Out:
# 30  records written to file  ./../data_files/atrm_magic/trm_anisotropy.txt
# specimen tensor elements stored in  ./../data_files/atrm_magic/trm_anisotropy.txt
# 30  records written to file  ./../data_files/atrm_magic/atrm_results.txt
# specimen statistics and eigenparameters stored in  ./../data_files/atrm_magic/atrm_results.txt

# %% [markdown]
# # azdip_magic.py

# %%
# !azdip_magic.py -f ../data_files/azdip_magic/azdip_magic_example.dat -ncn 1\
   -mcd FS-FD:SO-POM -loc "Northern Iceland" -F ../data_files/azdip_magic/er_samples.txt
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: app
# -
# checked_args: [['f', '../data_files/azdip_magic/azdip_magic_example.dat'], ['ncn', '1'], ['mcd', 'FS-FD:SO-POM'], ['loc', 'Northern', 'Iceland'], ['F', '../data_files/azdip_magic/er_samples.txt'], ['A', ''], ['WD', '.'], ['ID', '.'], ['Fsa', 'er_samples.txt'], ['Fsi', 'er_sites.txt'], ['app', False]]
# 916  records written to file  ./er_samples.txt
# Data saved in  ./er_samples.txt

# %% [markdown]
# # b_vdm.py

# %%
# !b_vdm.py -f ../data_files/b_vdm/b_vdm_example.dat
# Out:
#  7.159e+22

# %% [markdown]
# # basemap_magic.py

# %% [markdown]
# basemap_magic doesn't work anymore.

# %% [markdown]
# # biplot_magic.py

# %%
# !biplot_magic.py -f ../data_files/biplot_magic/biplot_magic_example.dat \
       -x LP-X -y LT-AF-I -fmt png -sav
# Out:
# LP-X  selected for X axis
# LT-AF-I  selected for Y axis
# All
# measurement_magn_mass  being used for plotting Y
# measurement_chi_mass  being used for plotting X.
# 1  saved in  All_fig.png

# %%
Image(filename='All_fig.png')

# %% [markdown]
# # bootams.py

# %%
# !bootams.py -par -f ../data_files/bootams/bootams_example.dat
# Out:
# Doing bootstrap - be patient
#
# tau tau_sigma V_dec V_inc V_eta V_eta_dec V_eta_inc V_zeta V_zeta_dec V_zeta_inc
#
# 0.33505 0.00020     5.3    14.7    11.7   266.7    28.8    26.6   121.3    56.2
# 0.33334 0.00022   124.5    61.7    19.5   241.2    13.2    23.6   336.9    22.8
# 0.33161 0.00026   268.8    23.6    10.7     8.3    21.6    20.7   136.6    57.5

# %% [markdown]
# # cart_dir.py

# %%
# !cart_dir.py -f ../data_files/cart_dir/cart_dir_example.dat
# Out:
#   340.0    65.0  1.000e+00
#   176.0   -55.0  1.000e+00

# %% [markdown]
# ## chartmaker.py

# %% [markdown]
# You can't do chartmaker from within the notebook.  And chi_magic.py is still a bit buggy (problem with legend and 4th plot still shows up.)

# %% [markdown]
# ## chi_magic.py

# %%
# !chi_magic.py -f ../data_files/chi_magic/chi_magic_example.dat -fmt png -sav
# Out:
# IRM-Kappa-2352 1 out of  2
# IRM-OldBlue-1892 2 out of  2
# Skipping susceptibitily - AC field plot as a function of temperature
# 1  saved in  IRM-OldBlue-1892_1.png
# 3  saved in  IRM-OldBlue-1892_3.png
# 2  saved in  IRM-OldBlue-1892_2.png

# %%
Image(filename='IRM-OldBlue-1892_1.png')

# %%
Image(filename='IRM-OldBlue-1892_3.png')

# %%
Image(filename='IRM-OldBlue-1892_2.png')

# %% [markdown]
# ## common_mean.py

# %%
# !common_mean.py -f ../data_files/common_mean/common_mean_ex_file1.dat\
   -f2 ../data_files/common_mean/common_mean_ex_file2.dat -sav -fmt png
# Out:
# Doing first set of directions, please be patient..
# Doing second  set of directions, please be patient..
# 2  saved in  CD_Y.png
# 1  saved in  CD_X.png
# 3  saved in  CD_Z.png

# %%
Image(filename='CD_X.png')

# %%
Image(filename='CD_Y.png')

# %%
Image(filename='CD_Z.png')

# %% [markdown]
# ## cont_rot.py

# %%
# !cont_rot.py -con af:sam -prj ortho\
    -eye -20 0 -sym k-  1 -age 180 -res l  -fmt png -sav
# Out:
# 1  saved in  Cont_rot.png

# %%
Image(filename="Cont_rot.png")

# %% [markdown]
# # convert_samples.py

# %%
# !convert_samples.py -f ../data_files/convert_samples/convert_samples_example.dat\
   -F ../data_files/convert_samples/orient_Northern_Iceland.txt
# Out:
# file_type er_samples
# 916  records written to file  ./../data_files/convert_samples/orient_Northern_Iceland.txt
# Data saved in:  ./../data_files/convert_samples/orient_Northern_Iceland.txt

# %% [markdown]
# ## core_depthplot.py

# %%
# !core_depthplot.py -fsa ../data_files/core_depthplot/er_samples.txt -LP AF 15 \
    -f ../data_files/core_depthplot/magic_measurements.txt -log \
    -d 50 150 -ts gts12 23 34 -D -fmt png -sav
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fsum
# -
# -I- using default for arg: fwig
# -
# -I- using default for arg: fa
# -
# -I- using default for arg: fsp
# -
# -I- using default for arg: fres
# -
# -I- using default for arg: n
# -
# -I- using default for arg: L
# -
# -I- using default for arg: S
# -
# -I- using default for arg: I
# -
# -I- using default for arg: M
# -
# -I- using default for arg: ds
# -
# -I- using default for arg: sym
# -
# 9328  measurements read in from  ./../data_files/core_depthplot/magic_measurements.txt
# spec file found

# %%
Image(filename='DSDP Site 522_m:_LT-AF-Z_core-depthplot.png')

# %% [markdown]
# # curie.py

# %%
# !curie.py -f ../data_files/curie/curie_example.dat -w 10 -fmt png -sav
# Out:
# second derivative maximum is at T=552
# 4  saved in  Curie.png
# 3  saved in  der2.png
# 2  saved in  der1.png
# 1  saved in  M_T.png

# %%
Image(filename='M_T.png')

# %% [markdown]
# # customize_criteria.py

# %% [markdown]
# You can't use customize_criteria in the notebook.

# %% [markdown]
# # dayplot_magic.py

# %%
# !dayplot_magic.py -f dayplot_magic/dayplot_magic_example.dat \
    -fmt png -sav
# Out:
# 3  saved in  LO:__SI:__SA:__SP:__TY:_S-Bcr_.png
# 1  saved in  LO:__SI:__SA:__SP:__TY:_day_.png
# 2  saved in  LO:__SI:__SA:__SP:__TY:_S-Bc_.png

# %%
Image(filename='LO:__SI:__SA:__SP:__TY:_day_.png')

# %% [markdown]
# # demag_gui.py

# %% [markdown]
# Use demag_gui.py from the command line or from within pmag_gui.py (Pmag GUI).

# %% [markdown]
# # di_eq.py

# %%
# !di_eq.py -f ../data_files/di_eq/di_eq_example.dat |head
# Out:
# -0.239410 -0.893491
# 0.436413 0.712161
# 0.063844 0.760300
# 0.321447 0.686216
# 0.322720 0.670562
# 0.407412 0.540654
# 0.580156 0.340376
# 0.105351 0.657728
# 0.247173 0.599687
# 0.182349 0.615600

# %% [markdown]
# # di_geo.py

# %%
# !di_geo.py -f ../data_files/di_geo/di_geo_example.dat -F ../data_files/di_geo/di_geo.out
# Out:
# ../data_files/di_geo/di_geo.out  opened for output

# %% [markdown]
# # di_rot.py

# %%
# !eqarea.py -f ../data_files/di_geo/di_geo.out -fmt png -sav
# Out:
# 1  saved in  ..-data_files-di_geo-di_geo.out.png

# %%
Image(filename='..-data_files-di_geo-di_geo.out.png')

# %%
# !fishrot.py -I 42 > ../data_files/di_rot/fishrot.out
# !gofish.py -f ../data_files/di_rot/fishrot.out
# Out:
#   357.8    42.2    100    95.2737     20.9     3.2    17.7

# %%
# !di_rot.py -f ../data_files/di_rot/fishrot.out -F ../data_files/di_rot/dirot.out -D 359.3 -I 42.1
# !eqarea.py -f ../data_files/di_rot/fishrot.out -fmt png -sav
# Out:
# 1  saved in  ..-data_files-di_rot-fishrot.out.png

# %%
Image(filename='..-data_files-di_rot-fishrot.out.png')

# %%
# !eqarea.py -f ../data_files/di_rot/dirot.out -fmt png -sav
# Out:
# 1  saved in  ..-data_files-di_rot-dirot.out.png

# %%
Image(filename='..-data_files-di_rot-dirot.out.png')

# %% [markdown]
# # di_tilt.py

# %%
# !di_tilt.py < ../data_files/di_tilt/di_tilt_example.dat |head
# Out:
#    37.5    49.6
#   336.5    60.9
#   338.0    23.0
#   355.7     7.5
#     8.2    58.6
#     6.2    29.8
#   357.0    50.0
#   342.8    58.6
#   339.3     0.3
#     3.9    21.7

# %% [markdown]
# # di_vgp.py

# %%
# !di_vgp.py -f ../data_files/di_vgp/di_vgp_example.dat
# Out:
#   154.7    77.3
#     6.6   -69.6

# %% [markdown]
# # dipole_pinc.py

# %%
# !dipole_pinc.py -f ../data_files/dipole_pinc/dipole_pinc_example.dat
# Out:
#   -41.7

# %% [markdown]
# # dipole_plat.py

# %%
# !dipole_plat.py -f ../data_files/dipole_plat/dipole_plat_example.dat
# Out:
#    12.0

# %% [markdown]
# # dir_cart.py

# %%
# !dir_cart.py -f ../data_files/dir_cart/dir_cart_example.dat
# Out:
# 8.4859e-01 3.0886e-01 9.3514e-01
# -3.8223e+00 3.3441e-01 -1.7083e+00

# %% [markdown]
# # dmag_magic.py

# %%
# !dmag_magic.py -f ../data_files/dmag_magic/dmag_magic_example.dat -LT AF -fmt png -sav
# Out:
# 5921  records read from  ../data_files/dmag_magic/dmag_magic_example.dat
# 1  saved in  McMurdo_LT-AF-Z.png

# %%
Image(filename='McMurdo_LT-AF-Z.png')

# %% [markdown]
# # download_magic.py

# %%
# !download_magic.py -WD ../data_files/download_magic -f ../data_files/download_magic/zmab0083201tmp03.txt |tail
# Out:
# 177  records written to file  ../data_files/download_magic/er_specimens.txt
# 20  records written to file  ../data_files/download_magic/er_ages.txt
# 17  records written to file  ../data_files/download_magic/er_citations.txt
# 3072  records written to file  ../data_files/download_magic/magic_measurements.txt
# 225  records written to file  ../data_files/download_magic/pmag_specimens.txt
# 166  records written to file  ../data_files/download_magic/pmag_samples.txt
# 30  records written to file  ../data_files/download_magic/pmag_sites.txt
# 24  records written to file  ../data_files/download_magic/pmag_results.txt
# 7  records written to file  ../data_files/download_magic/pmag_criteria.txt
# 32  records written to file  ../data_files/download_magic/magic_methods.txt

# %% [markdown]
# # eigs_s.py

# %%
# !eigs_s.py -f ../data_files/eigs_s/eigs_s_example.dat
# Out:
# 0.33416328 0.33280227 0.33303446 -0.00016631 0.00123163 0.00135521
# 0.33555713 0.33197427 0.33246869 0.00085685 0.00025266 0.00098151
# 0.33585301 0.33140355 0.33274350 0.00132308 0.00117787 0.00000455
# 0.33479390 0.33140817 0.33379796 -0.00043088 0.00048858 0.00045610
# 0.33502916 0.33117944 0.33379149 -0.00106313 0.00029828 0.00035883
# 0.33407047 0.33226910 0.33366045 -0.00000638 0.00098445 0.00005996
# 0.33486328 0.33215088 0.33298591 -0.00034279 0.00038178 0.00020145
# 0.33509853 0.33195898 0.33294258 0.00076976 0.00056717 0.00011960

# %% [markdown]
# # eq_di.py

# %%
# !eq_di.py -f ../data_files/eq_di/eq_di_example.dat > ../data_files/eq_di/eq_di.out
# !eqarea.py -f ../data_files/eq_di/eq_di.out -fmt png -sav
# Out:
# 1  saved in  ..-data_files-eq_di-eq_di.out.png

# %%
Image(filename='..-data_files-eq_di-eq_di.out.png')

# %% [markdown]
# # eqarea.py

# %%
# !eqarea.py -f ../data_files/eqarea/fishrot.out -fmt png -sav
# Out:
# 1  saved in  ..-data_files-eqarea-fishrot.out.png

# %%
Image(filename='..-data_files-eqarea-fishrot.out.png')

# %% [markdown]
# # eqarea_ell.py

# %%
# !eqarea_ell.py -f ../data_files/eqarea_ell/tk03.out -ell B -fmt png -sav
# Out:
#      Zdec    21.0
#      Edec   105.7
#      Eta     4.5
#      n        20
#      Einc    10.0
#      Zinc   -27.6
#      Zeta     4.5
#      dec   357.8
#      inc    60.3
# 1  saved in  ..-data_files-eqarea_ell-tk03.out_eq.png

# %%
Image(filename='..-data_files-eqarea_ell-tk03.out_eq.png')

# %% [markdown]
# # eqarea_magic.py

# %%
# !eqarea_magic.py -obj loc -crd g -f ../data_files/eqarea_magic/pmag_results.txt\
    -ell Be -fmt png -sav
# Out:
# 1  saved in  LO:_Snake River_SI:__SA:__SP:__CO:_gu_TY:_eqarea_.png

# %%
Image(filename='LO:_Snake River_SI:__SA:__SP:__CO:_gu_TY:_eqarea_.png')

# %% [markdown]
# # find_EI.py

# %%
# !find_EI.py -f ../data_files/find_EI/find_EI_example.dat -fmt png -sav
# Out:
# Bootstrapping.... be patient
# 25  out of  1000
# 50  out of  1000
# 75  out of  1000
# 100  out of  1000
# 125  out of  1000
# 150  out of  1000
# 175  out of  1000
# 200  out of  1000
# 225  out of  1000
# 250  out of  1000
# 275  out of  1000
# 300  out of  1000
# 325  out of  1000
# 350  out of  1000
# 375  out of  1000
# 400  out of  1000
# 425  out of  1000
# 450  out of  1000
# 475  out of  1000
# 500  out of  1000
# 525  out of  1000
# 550  out of  1000
# 575  out of  1000
# 600  out of  1000
# 625  out of  1000
# 650  out of  1000
# 675  out of  1000
# 700  out of  1000
# 725  out of  1000
# 750  out of  1000
# 775  out of  1000
# 800  out of  1000
# 825  out of  1000
# 850  out of  1000
# 875  out of  1000
# 900  out of  1000
# 925  out of  1000
# 950  out of  1000
# 975  out of  1000
# 1000  out of  1000
# 2  saved in  findEI_ei.png
# 3  saved in  findEI_cdf.png
# 1  saved in  findEI_eq.png
# 4  saved in  findEI_v2.png

# %%
Image(filename='findEI_ei.png')

# %%
Image(filename='findEI_cdf.png')

# %%
Image(filename='findEI_eq.png')

# %%
Image(filename='findEI_v2.png')

# %% [markdown]
# # fisher.py

# %%
# !fisher.py -k 30 -n 10 |head
# Out:
#   180.6    60.2
#   254.1    56.7
#   355.0    75.6
#   357.1    67.8
#    46.4    73.4
#   353.4    72.7
#   175.7    65.6
#   139.9    84.4
#   310.8    82.5
#   228.6    83.3

# %% [markdown]
# # fishqq.py

# %%
# !fishqq.py -f ../data_files/fishqq/fishqq_example.txt -fmt png -sav
# Out:
# 1  saved in  ..-data_files-fishqq-fishqq_example.txt_unf1.png
# 2  saved in  ..-data_files-fishqq-fishqq_example.txt_exp1.png

# %%
Image(filename='..-data_files-fishqq-fishqq_example.txt_unf1.png')

# %%
Image(filename='..-data_files-fishqq-fishqq_example.txt_exp1.png')

# %% [markdown]
# # fishrot.py

# %%
# !fishrot.py -n 5 -D 33 -I 41 -k 50
# Out:
#     7.8    53.3
#    39.2    49.0
#     7.3    39.1
#    28.9    33.4
#    34.9    27.3

# %% [markdown]
# # foldtest.py

# %%
# !foldtest.py -f ../data_files/foldtest/foldtest_example.dat -fmt png -sav
# Out:
# doing  1000  iterations...please be patient.....
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 83 - 119 Percent Unfolding
# range of all bootstrap samples:  74  -  128
# 3  saved in  foldtest_ta.png
# 2  saved in  foldtest_st.png
# 1  saved in  foldtest_ge.png

# %%
Image(filename='foldtest_ta.png')

# %%
Image(filename='foldtest_st.png')

# %%
Image(filename='foldtest_ge.png')

# %% [markdown]
# # foldtest_magic.py

# %%
# !download_magic.py -WD ../data_files/foldtest_magic -f ../data_files/foldtest_magic/magic_contribution_11087.txt |tail
# Out:
# -I- using default for arg: Fsi
# -
# -I- using default for arg: O
# -
# 2  records written to file  ../data_files/foldtest_magic/er_locations.txt
# 30  records written to file  ../data_files/foldtest_magic/er_sites.txt
# 5  records written to file  ../data_files/foldtest_magic/er_citations.txt
# 60  records written to file  ../data_files/foldtest_magic/pmag_sites.txt
# 32  records written to file  ../data_files/foldtest_magic/pmag_results.txt
# 9  records written to file  ../data_files/foldtest_magic/magic_methods.txt

# %%
# !foldtest_magic.py -f ../data_files/foldtest_magic/pmag_sites.txt \
    -fsi ../data_files/foldtest_magic/er_sites.txt -fmt png -sav
# Out:
# doing  1000  iterations...please be patient.....
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 95 - 149 Percent Unfolding
# 3  saved in  foldtest_ta.png
# 2  saved in  foldtest_st.png
# 1  saved in  foldtest_ge.png

# %%
Image(filename='foldtest_ge.png')

# %%
Image(filename='foldtest_st.png')

# %%
Image(filename='foldtest_ta.png')

# %% [markdown]
# # gaussian.py

# %%
# !gaussian.py -s 3 -n 1000 -m 10. -F ../data_files/gaussian/gaussian.out
# !histplot.py -f ../data_files/gaussian/gaussian.out -fmt png -sav
# Out:
# hist.png
# plot saved in  hist.png

# %%
Image(filename='hist.png')

# %% [markdown]
# # gobing.py

# %%
# !gobing.py -f ../data_files/eqarea_ell/tk03.out
# Out:
#   357.8    60.3     4.5   105.7    10.0     4.5    21.0   -27.6 20

# %% [markdown]
# # gofish.py

# %%
# !gofish.py -f ../data_files/gofish/fishrot.out
# Out:
#    10.8    39.6    10     9.8484     59.4     6.3    10.5

# %% [markdown]
# # gokent.py

# %%
# !gokent.py -f ../data_files/gokent/tk03.out
# Out:
#   359.2    55.0     9.3   147.7    30.8     7.8   246.8    14.9 20

# %% [markdown]
# # goprinc.py

# %%
# !goprinc.py -f ../data_files/goprinc/tk03.out
# Out:
# 0.93863    11.0    58.6 0.04258   226.4    26.5 0.01879   128.3    15.6 20

# %% [markdown]
# # grab_magic_key.py

# %%
# !grab_magic_key.py -f ../data_files/download_magic/er_sites.txt -key site_lat |head
# Out:
# 42.60264
# 42.60264
# 42.60352
# 42.60104
# 42.73656
# 42.8418
# 42.8657
# 42.92031
# 42.56857
# 42.49964

# %% [markdown]
# # histplot.py
#
# see gaussian.py

# %% [markdown]
# # hysteresis_magic.py

# %%
# !hysteresis_magic.py -f ../data_files/hysteresis_magic/hysteresis_magic_example.dat \
    -spc IS06a-1  -fmt png -sav
# Out:
# IS06a-1
# 1  saved in  _IS06a-1_hyst.png
# 3  saved in  _IS06a-1_DdeltaM.png
# 2  saved in  _IS06a-1_deltaM.png
# 5  saved in  _IS06a-1_irm.png

# %%
Image(filename='_IS06a-1_hyst.png')

# %% [markdown]
# # igrf.py

# %%
# !igrf.py -ages -3000 1950 50 -loc 33 -117 -mod pfm9k -plt -fmt png -sav
# Out:
# Figure saved as:  igrf.png

# %%
Image(filename='igrf.png')

# %% [markdown]
# # install_etopo.py

# %%
# !install_etopo.py
# Out:
# installing etopo20 files from  /Users/nebula/Python/PmagPy/data_files/etopo20/etopo20*
# to the basemap data directory:  /Users/nebula/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/mpl_toolkits/basemap/data

# %% [markdown]
# # incfish.py

# %%
# !incfish.py -f ../data_files/incfish/incfish_example_inc.dat
# Out:
#    57.1    61.0  100     92.9    13.9     1.0

# %% [markdown]
# # irm_magic.py

# %%
# !sio_magic.py -f ../data_files/irmaq_magic/U1359A_IRM_coil2.txt -LP I -V 2 \
    -F ../data_files/irmaq_magic/U1359A_IRM_coil2.magic -loc U1359A -spc 0 -ncn 5
# !sio_magic.py -f ../data_files/irmaq_magic/U1359A_IRM_coil3.txt -LP I -V 3 \
    -F ../data_files/irmaq_magic/U1359A_IRM_coil3.magic -loc U1359A -spc 0 -ncn 5
# !combine_magic.py -F ../data_files/irmaq_magic/magic_measurements.txt \
    -f ../data_files/irmaq_magic/U1359A_IRM_coil2.magic \
    ../data_files/irmaq_magic/U1359A_IRM_coil3.magic
# Out:
# 536  records written to file  ../data_files/irmaq_magic/U1359A_IRM_coil2.magic
# results put in  ../data_files/irmaq_magic/U1359A_IRM_coil2.magic
# 23  records written to file  ../data_files/irmaq_magic/U1359A_IRM_coil3.magic
# results put in  ../data_files/irmaq_magic/U1359A_IRM_coil3.magic
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: A
# -
# -I- using default for arg: WD
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# File  ./../data_files/irmaq_magic/U1359A_IRM_coil2.magic  read in with  536  records
# File  ./../data_files/irmaq_magic/U1359A_IRM_coil3.magic  read in with  23  records
# 559  records written to file  ./../data_files/irmaq_magic/magic_measurements.txt
# All records stored in  ./../data_files/irmaq_magic/magic_measurements.txt

# %%
# !irmaq_magic.py -f ../data_files/irmaq_magic/magic_measurements.txt -fmt png -sav
# Out:
# U1359A
# 1  saved in  U1359A_LP-IRM.png

# %%
Image(filename='U1359A_LP-IRM.png')

# %% [markdown]
# # k15_magic.py

# %%
# !k15_magic.py -WD ../data_files/k15_magic  -spc 0 -f ../data_files/k15_s/k15_example.dat -loc "Troodos Ophiolite"
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: ID
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: Fa
# -
# -I- using default for arg: Fr
# -
# -I- using default for arg: ncn
# -
# 12  records written to file  ../data_files/k15_magic/er_samples.txt
# 24  records written to file  ../data_files/k15_magic/rmag_anisotropy.txt
# 24  records written to file  ../data_files/k15_magic/rmag_results.txt
# 120  records written to file  ../data_files/k15_magic/magic_measurements.txt
# Data saved to:  ../data_files/k15_magic/er_samples.txt ../data_files/k15_magic/rmag_anisotropy.txt ../data_files/k15_magic/rmag_results.txt ../data_files/k15_magic/magic_measurements.txt

# %%
# !k15_s.py -f ../data_files/k15_s/k15_example.dat
# Out:
# 0.33146986 0.33413991 0.33439023 0.00075095 -0.00083439 -0.00016688 0.00008618
# 0.33335925 0.33335925 0.33328149 -0.00155521 -0.00132193 0.00116641 0.00017193
# 0.33097634 0.33573565 0.33328801 0.00163177 0.00013598 0.00000000 0.00018131
# 0.33150029 0.33465420 0.33384551 -0.00064696 -0.00056609 -0.00048522 0.00014863
# 0.33121986 0.33521197 0.33356816 -0.00046966 -0.00046966 -0.00086104 0.00018376
# 0.33179570 0.33405602 0.33414828 -0.00009226 -0.00004613 -0.00027677 0.00010474
# 0.33243163 0.33439898 0.33316939 0.00106564 0.00032789 0.00000000 0.00017624
# 0.33175478 0.33512715 0.33311808 0.00078928 0.00000000 -0.00007175 0.00011116

# %%
# !kly4s_magic.py -ID kly4s_magic -WD kly4s_magic -f KLY4S_magic_example.dat -spc 0 -ncn 5
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: fad
# -
# -I- using default for arg: fsa
# -
# -I- using default for arg: fsp
# -
# -I- using default for arg: Fsp
# -
# -I- using default for arg: Fa
# -
# -I- using default for arg: ocn
# -
# -I- using default for arg: usr
# -
# -I- using default for arg: loc
# -
# -I- using default for arg: ins
# -
# Error opening file:  kly4s_magic/KLY4S_magic_example.dat

# %% [markdown]
# # lnp_magic.py

# %%
# !download_magic.py  -WD ../data_files/lnp_magic -ID ../data_files/lnp_magic -f zmab0001193tmp02.txt |head
# Out:
# ['f', 'F', 'A', 'WD', 'ID', 'Fsa', 'Fsi'] 7
# -I- using default for arg: F
# -
# -I- using default for arg: A
# -
# -I- using default for arg: Fsa
# -
# -I- using default for arg: Fsi
# -
# -I- using default for arg: O

# %%
# !lnp_magic.py -f ../data_files/lnp_magic/pmag_specimens.txt -crd g -fmt png -sav |head
# Out:
# sv01
# Site lines planes  kappa   a95   dec   inc
# sv01 0  5     286      6.6    179.0    -54.3  4.9948
# % tilt correction:  0
# 1  saved in  sv01_g_eqarea.png
# sv02
# Site lines planes  kappa   a95   dec   inc
# sv02 4  2     113      6.6    338.8     38.6  5.9647
# % tilt correction:  0
# 1  saved in  sv02_g_eqarea.png

# %%
Image(filename='sv01_g_eqarea.png')

# %%
# !lowrie.py -f ../data_files/lowrie/lowrie_example.dat -fmt png -sav |head
# Out:
# 318-U1359A-002H-1-W-109
# 1  saved in  lowrie:_318-U1359A-002H-1-W-109_.png
# 318-U1359A-002H-4-W-65
# 1  saved in  lowrie:_318-U1359A-002H-4-W-65_.png
# 318-U1359A-002H-6-W-7
# 1  saved in  lowrie:_318-U1359A-002H-6-W-7_.png
# 318-U1359A-003H-2-W-37
# 1  saved in  lowrie:_318-U1359A-003H-2-W-37_.png
# 318-U1359A-003H-6-W-66
# 1  saved in  lowrie:_318-U1359A-003H-6-W-66_.png

# %%
Image(filename='lowrie:_318-U1359A-002H-1-W-109_.png')

# %% [markdown]
# # lowrie_magic.py

# %%
# !lowrie_magic.py -f ../data_files/lowrie_magic/lowrie_magic_example.dat -fmt png -sav |head
# Out:
# ./../data_files/lowrie_magic/lowrie_magic_example.dat
# 318-U1359A-002H-1-W-109
# 1  saved in  lowrie:_318-U1359A-002H-1-W-109_.png
# 318-U1359A-002H-4-W-65
# 1  saved in  lowrie:_318-U1359A-002H-4-W-65_.png
# 318-U1359A-002H-6-W-7
# 1  saved in  lowrie:_318-U1359A-002H-6-W-7_.png
# 318-U1359A-003H-2-W-37
# 1  saved in  lowrie:_318-U1359A-003H-2-W-37_.png
# 318-U1359A-003H-6-W-66

# %%
Image(filename='lowrie:_318-U1359A-002H-1-W-109_.png')

# %% [markdown]
# # magic_select.py

# %%
# !magic_select.py -f ../data_files/magic_select/pmag_specimens.txt \
    -key magic_method_codes LP-DIR-AF has -F ../data_files/magic_select/AF_specimens.txt
# Out:
# 76  records written to file  ./../data_files/magic_select/AF_specimens.txt

# %% [markdown]
# # measurements_normalize.py

# %%
# !measurements_normalize.py -f ../data_files/measurements_normalize/irm_measurements.txt \
    -fsp ../data_files/measurements_normalize/specimens_weights.txt \
    -F ../data_files/measurements_normalize/irm_norm_measurements.txt
# Out:
# 17721  records written to file  ./../data_files/measurements_normalize/irm_norm_measurements.txt
# Data saved in  ./../data_files/measurements_normalize/irm_norm_measurements.txt

# %% [markdown]
# # mk_redo.py

# %%
# !mk_redo.py -f pmag_specimens.txt -WD ../data_files/mk_redo
# Out:
# Redo files saved to:  ../data_files/mk_redo/zeq_redo ../data_files/mk_redo/thellier_redo

# %%
# !head ../data_files/mk_redo/zeq_redo
# Out:
# sr01a1 DE-BFL 473 823 A
# sr01a2 DE-BFL 473 848 A
# sr01c2 DE-BFL 473 823 A
# sr01d1 DE-BFL 373 798 A
# sr01e2 DE-BFL 0.01 0.18 A
# sr01f2 DE-BFL 423 923 A
# sr01g2 DE-BFL 0.01 0.16 A
# sr01i1 DE-BFL 473 823 A
# sr03a1 DE-BFL 473 823 A
# sr03b1 DE-BFL 673 823 A

# %%
# !head ../data_files/mk_redo/thellier_redo
# Out:
# sr01a1 573 823
# sr01a2 573 848
# sr01c2 673 823
# sr01d1 373 823
# sr01i1 373 773
# sr03a1 373 673
# sr03b1 373 673
# sr03c1 423 673
# sr03e1 423 673
# sr09f1 373 573

# %% [markdown]
# # nrm_specimens_magic.py

# %%
# !download_magic.py -WD ../data_files/nrm_specimens_magic \
-f ../data_files/nrm_specimens_magic/zmab0083201tmp03.txt |tail
# Out:
# 177  records written to file  ../data_files/nrm_specimens_magic/er_specimens.txt
# 20  records written to file  ../data_files/nrm_specimens_magic/er_ages.txt
# 17  records written to file  ../data_files/nrm_specimens_magic/er_citations.txt
# 3072  records written to file  ../data_files/nrm_specimens_magic/magic_measurements.txt
# 225  records written to file  ../data_files/nrm_specimens_magic/pmag_specimens.txt
# 166  records written to file  ../data_files/nrm_specimens_magic/pmag_samples.txt
# 30  records written to file  ../data_files/nrm_specimens_magic/pmag_sites.txt
# 24  records written to file  ../data_files/nrm_specimens_magic/pmag_results.txt
# 7  records written to file  ../data_files/nrm_specimens_magic/pmag_criteria.txt
# 32  records written to file  ../data_files/nrm_specimens_magic/magic_methods.txt

# %%
# !nrm_specimens_magic.py -WD ../data_files/nrm_specimens_magic -crd g
# Out:
# ../data_files/nrm_specimens_magic/er_samples.txt  read in with  271  records
# 177  records written to file  ../data_files/nrm_specimens_magic/nrm_specimens.txt
# Data saved in  ../data_files/nrm_specimens_magic/nrm_specimens.txt

# %%
# !eqarea_magic.py -f ../data_files/nrm_specimens_magic/nrm_specimens.txt -crd g -fmt png -sav
# Out:
# 1  saved in  LO:_Snake River_SI:__SA:__SP:__CO:_g_TY:_eqarea_.png

# %%
Image(filename='LO:_Snake River_SI:__SA:__SP:__CO:_g_TY:_eqarea_.png')

# %% [markdown]
# # orientation_magic.py

# %%
# !orientation_magic.py -WD ../data_files/orienation_magic -f orient_example.txt | tail
# Out:
# -I- using default for arg: gmt
# -
# -I- using default for arg: mcd
# -
# -I- using default for arg: a
# -
# -I- using default for arg: DM
# -
# saving data...
# Data saved in  ../data_files/orienation_magic/er_samples.txt  and  ../data_files/orienation_magic/er_sites.txt

# %%
# !parse_measurements.py -WD ../data_files/parse_measurements |tail
# Out:
# site record in er_sites table not found for:  318-U1359A-010H-2-W-73
# site record in er_sites table not found for:  318-U1359A-017H-2-W-64
# site record in er_sites table not found for:  318-U1359A-018X-6-W-57
# site record in er_sites table not found for:  318-U1359A-019X-4-W-40
# site record in er_sites table not found for:  318-U1359A-021X-4-W-18
# site record in er_sites table not found for:  318-U1359A-022X-2-W-95
# 63  records written to file  ../data_files/parse_measurements/er_specimens.txt
#  Er_Specimen data (with updated info from site if necessary)  saved in  ../data_files/parse_measurements/er_specimens.txt
# 1  records written to file  ../data_files/parse_measurements/magic_instruments.txt
#  Instruments data saved in  ../data_files/parse_measurements/magic_instruments.txt

# %% [markdown]
# # pca.py

# %%
# !pca.py -dir L 1 10 -f ../data_files/pca/zeq_example.dat
# Out:
# eba24a DE-BFL
# 0 0.00 339.9 57.9 9.2830e-05
# 1 2.50 325.7 49.1 7.5820e-05
# 2 5.00 321.3 45.9 6.2920e-05
# 3 10.00 314.8 41.7 5.2090e-05
# 4 15.00 310.3 38.7 4.4550e-05
# 5 20.00 305.0 37.0 3.9540e-05
# 6 30.00 303.9 34.7 3.2570e-05
# 7 40.00 303.0 32.3 2.5670e-05
# 8 50.00 303.6 32.4 2.2520e-05
# 9 60.00 299.8 30.8 1.9820e-05
# 10 70.00 292.5 31.0 1.3890e-05
# 11 80.00 297.0 25.6 1.2570e-05
# 12 90.00 299.3 11.3 0.5030e-05
# eba24a DE-BFL 10    2.50  70.00    8.8   334.9    51.5

# %% [markdown]
# # plotXY.py

# %%
# !plotXY.py -f ../data_files/plotXY/plotXY_example.txt -fmt png -sav
# Out:
# Figure saved as  plotXY.png

# %%
Image(filename='plotXY.png')

# %% [markdown]
# # plot_cdf.py

# %%
# !plot_cdf.py -f ../data_files/plot_cdf/gaussian.out -fmt png -sav
# Out:
# 1  saved in  CDF_.png

# %%
Image(filename='CDF_.png')

# %% [markdown]
# # plot_mapPTS.py

# %%
# !plot_map_pts.py -f ../data_files/plot_mapPTS/uniform.out -B -R \
    -prj ortho -eye 30 0 -etp -sym wo 10 -fmt png -sav
# Out:
# please wait to draw points
# 1  saved in  Map_PTS.png

# %%
Image(filename='Map_PTS.png')

# %% [markdown]
# # plotdi_a.py

# %%
# !plotdi_a.py -f ../data_files/plotdi_a/plotdi_a_example.dat -fmt png -sav
# Out:
# 1  saved in  eq.png

# %%
Image(filename='eq.png')

# %% [markdown]
# # pmag_results_extract.py

# %%
# !pmag_results_extract.py -WD ../data_files/pmag_results_extract -f pmag_results.txt
# Out:
# data saved in:  /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/Directions.txt /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/Intensities.txt /Users/nebula/Python/PmagPy/data_files/pmag_results_extract/SiteNfo.txt

# %% [markdown]
# # pt_rot.py

# %%
# !awk '{print $1,$2}' ../data_files/pt_rot/pt_rot.input > ../data_files/pt_rot/lon_lat
# !plot_map_pts.py -prj moll -f ../data_files/pt_rot/lon_lat -sym g^ 10 -R -B -eye 0 0 -fmt png -sav
# Out:
# please wait to draw points
# 1  saved in  Map_PTS.png

# %%
Image(filename='Map_PTS.png')

# %%
# !cat ../data_files/pt_rot/pt_rot.input
# !pt_rot.py -f ../data_files/pt_rot/pt_rot.input > ../data_files/pt_rot/pt_rot.out
# Out:
# -84.7 39.1 nam 80 saf

# %%
# !plot_map_pts.py -prj moll -f ../data_files/pt_rot/pt_rot.out -sym ro 10 -R -B -eye 0 0 -fmt png -sav
# Out:
# please wait to draw points
# 1  saved in  Map_PTS.png

# %%
Image(filename='Map_PTS.png')

# %% [markdown]
# Something still weird about pt_rot.py (the -ff option).

# %%
# !pt_rot.py -ff ../data_files/pt_rot/nam_180-200.txt ../data_files/pt_rot/nam_panA.frp > ../data_files/pt_rot/pt_rot_panA.out

# %%
# !plot_map_pts.py -f data_files/pt_rot/pt_rot_panA.out -prj ortho -eye 60 90 -sym ro 10 -B -R -fmt png -sav
# Out:
# Traceback (most recent call last):
#   File "/Users/nebula/Python/PmagPy/programs/plot_map_pts.py", line 219, in <module>
#     main()
#   File "/Users/nebula/Python/PmagPy/programs/plot_map_pts.py", line 134, in main
#     header=open(file,'rU').readlines()[0].split('\t')
# IOError: [Errno 2] No such file or directory: './data_files/pt_rot/pt_rot_panA.out'

# %%
Image(filename='Map_PTS.png')

# %% [markdown]
# # qqplot.py

# %%
# !qqplot.py -f ../data_files/qqplot/gauss.out -fmt png -sav
# Out:
# mean,sigma, d, Dc
# -0.09482124 0.941267146559 0.0770098421346 0.0886
# 1  saved in  qq.png

# %%
Image(filename='qq.png')

# %% [markdown]
# # quick_hyst.py

# %%
# !quick_hyst.py -f ../data_files/hysteresis_magic/hysteresis_magic_example.dat -fmt png -sav |head
# Out:
# verbose? True
# verbose 0
# working on t:  273
# 1  saved in  LO:__SI:_IS06_SA:_IS06a_SP:_IS06a-1_TY:_hyst_.png
# working on t:  273
# 1  saved in  LO:__SI:_IS06_SA:_IS06a_SP:_IS06a-2_TY:_hyst_.png
# working on t:  273
# 1  saved in  LO:__SI:_IS06_SA:_IS06a_SP:_IS06a-3_TY:_hyst_.png
# working on t:  273
# 1  saved in  LO:__SI:_IS06_SA:_IS06a_SP:_IS06a-4_TY:_hyst_.png

# %%
Image(filename='LO:__SI:_IS06_SA:_IS06a_SP:_IS06a-1_TY:_hyst_.png')

# %% [markdown]
# # revtest.py

# %%
# !revtest.py -f ../data_files/revtest/revtest_example.txt -fmt png -sav
# Out:
# doing first mode, be patient
# doing second mode, be patient
# 2  saved in  REV_Y.png
# 1  saved in  REV_X.png
# 3  saved in  REV_Z.png

# %%
Image(filename='REV_X.png')

# %%
Image(filename='REV_Y.png')

# %%
Image(filename='REV_Z.png')

# %% [markdown]
# # revtest_magic.py

# %%
# !revtest_magic.py -f ../data_files/revtest_magic/revtest_magic_example.txt -fmt png -sav
# Out:
# doing first mode, be patient
# doing second mode, be patient
# 2  saved in  REV_Y.png
# 1  saved in  REV_X.png
# 3  saved in  REV_Z.png

# %%
Image(filename='REV_X.png')

# %% [markdown]
# # s_eigs.py

# %%
# !s_eigs.py -f ../data_files/s_eigs/s_eigs_example.dat
# Out:
# 0.33127186 239.53  44.70 0.33351338 126.62  21.47 0.33521473  19.03  37.54
# 0.33177859 281.12   6.18 0.33218277 169.79  73.43 0.33603862  12.82  15.32
# 0.33046979 283.57  27.30 0.33328307 118.37  61.91 0.33624712  16.75   6.13
# 0.33123776 261.36  12.07 0.33377582 141.40  66.82 0.33498645 355.70  19.48
# 0.33085680 255.71   7.13 0.33379164 130.85  77.65 0.33535156 346.97  10.03
# 0.33175930 268.51  26.79 0.33405024 169.66  16.95 0.33419049  51.04  57.53
# 0.33194992 261.59  20.68 0.33313262  92.18  68.99 0.33491743 352.93   3.54
# 0.33157593 281.42  21.32 0.33312121 117.04  67.94 0.33530283  13.54   5.41

# %% [markdown]
# # s_geo.py

# %%
# !s_geo.py -f ../data_files/s_geo/s_geo_example.dat
# Out:
# 0.33412680 0.33282733 0.33304587 -0.00015289 0.00124843 0.00135721
# 0.33556300 0.33198264 0.33245432 0.00087259 0.00024141 0.00096166
# 0.33584908 0.33140627 0.33274469 0.00131845 0.00118816 0.00002986
# 0.33479756 0.33142531 0.33377719 -0.00047493 0.00049539 0.00044303
# 0.33505613 0.33114848 0.33379540 -0.00101375 0.00028536 0.00034852
# 0.33406156 0.33226916 0.33366925 -0.00002267 0.00098548 0.00005553
# 0.33486596 0.33216032 0.33297369 -0.00035492 0.00039254 0.00015403
# 0.33510646 0.33196402 0.33292958 0.00075965 0.00057242 0.00010112

# %% [markdown]
# # s_hext.py

# %%
# !s_geo.py -f ../data_files/s_geo/s_geo_example.dat | s_hext.py
# Out:
# F =  5.79 F12 =  3.55 F23 =  3.66
# N =  8  sigma =  0.000641809950
# 0.33505     5.3    14.7    25.5   124.5    61.7    13.3   268.8    23.6
# 0.33334   124.5    61.7    25.1   268.8    23.6    25.5     5.3    14.7
# 0.33161   268.8    23.6    13.3     5.3    14.7    25.1   124.5    61.7

# %% [markdown]
# # s_tilt.py

# %%
# !s_tilt.py -f ../data_files/s_tilt/s_tilt_example.dat
# Out:
# 0.33455709 0.33192658 0.33351630 -0.00043562 0.00092779 0.00105006
# 0.33585501 0.33191565 0.33222935 0.00055960 -0.00005316 0.00064732
# 0.33586669 0.33084923 0.33328408 0.00142266 0.00013234 0.00009203
# 0.33488664 0.33138493 0.33372843 -0.00056597 -0.00039085 0.00004873
# 0.33506602 0.33127019 0.33366373 -0.00105193 -0.00057257 -0.00029959
# 0.33407688 0.33177567 0.33414748 0.00007007 0.00018447 0.00005073
# 0.33483925 0.33197853 0.33318222 -0.00028447 0.00003518 -0.00029262
# 0.33513144 0.33175036 0.33311823 0.00077914 -0.00006402 0.00004612

# %% [markdown]
# # s_magic.py

# %%
# !s_magic.py -WD ../data_files/s_magic -f s_magic_example.dat
# Out:
# 8  records written to file  ../data_files/s_magic/rmag_anisotropy.txt
# data saved in  ../data_files/s_magic/rmag_anisotropy.txt

# %% [markdown]
# # scalc.py

# %%
# !scalc.py -f ../data_files/scalc/scalc_example.txt
# Out:
# 99    19.5     90.0

# %%
# !scalc.py -f ../data_files/scalc/scalc_example.txt -v
# Out:
# 89    15.2     32.3

# %%
# !scalc.py -f ../data_files/scalc/scalc_example.txt -v -b
# Out:
# please be patient...   bootstrapping
# 89    15.2    13.4     16.9    32.3

# %% [markdown]
# # scalc_magic.py

# %%
# !scalc_magic.py -f ../data_files/scalc_magic/pmag_results.txt -c 30
# Out:
# 13    17.8     30.0

# %% [markdown]
# # site_edit.py
#
# This program requires user interaction and can only be used on the command line.

# %% [markdown]
# # specimens_results_magic.py
#
# This program has been superceded by Pmag GUI and is not maintained.

# %% [markdown]
# # stats.py

# %%
# !stats.py -f ../data_files/gaussian/gauss.out
# Out:
# 100 9.94986999 994.986999 0.958167360921 9.62994855092

# %% [markdown]
# # strip_magic.py

# %%
# !strip_magic.py -f ../data_files/strip_magic/pmag_results.txt -x age -y lat -fmt png -sav
# Out:
# 1  saved in  strat.png

# %%
Image(filename='strat.png')

# %% [markdown]
# # sundec.py

# %%
# !sundec.py -f ../data_files/sundec/sundec_example.dat
# Out:
#   154.2

# %% [markdown]
# # thellier_magic.py
#
# This program is no longer maintained - try Thellier GUI instead.

# %% [markdown]
# # thellier_magic_redo.py
#
# The function of this program has been incorporated into Thellier GUI so you should use that instead.

# %% [markdown]
# # tk03.py

# %%
# !tk03.py -lat 30 > ../data_files/tk03/tk03.out
# !eqarea.py -f ../data_files/tk03/tk03.out -fmt png -sav
# Out:
# 1  saved in  ..-data_files-tk03-tk03.out.png

# %%
Image(filename='..-data_files-tk03-tk03.out.png')

# %% [markdown]
# # uniform.py

# %%
# !uniform.py -n 50 |head
# Out:
#   304.5    55.7
#   326.3    47.0
#    64.7    55.8
#   341.2   -28.8
#   255.8    -7.9
#   105.5   -59.4
#   209.6   -19.9
#   336.6    20.2
#    26.3   -41.5
#   209.7    50.8

# %%
# !uniform.py -n 50 > ../data_files/uniform/uniform.out
# !eqarea.py -f ../data_files/uniform/uniform.out -fmt png -sav
# Out:
# 1  saved in  ..-data_files-uniform-uniform.out.png

# %%
Image(filename='..-data_files-uniform-uniform.out.png')

# %% [markdown]
# # update_measurements.txt
#
# This program has been superceded by Pmag GUI, so you should use that.

# %% [markdown]
# # upload_magic.py
#
# program has been superceded by Pmag GUI, so you should use that.

# %% [markdown]
# # vdm_b.py

# %%
# !vdm_b.py -f ../data_files/vdm_b/vdm_b_example.dat
# Out:
#  3.300e-05

# %%
# !cat ../data_files/b_vdm/b_vdm_example.dat
# Out:
# 33 22

# %% [markdown]
# # vector_mean.py

# %%
# !vector_mean.py -f ../data_files/vector_mean/vector_mean_example.dat
# Out:
#     1.3    49.6    2.289e+06 100

# %% [markdown]
# # vgp_di.py

# %%
# !vgp_di.py -f ../data_files/vgp_di/vgp_di_example.dat
# Out:
#   335.6    62.9

# %% [markdown]
# # vgpmap_magic.py

# %%
# !vgpmap_magic.py -f ../data_files/vgpmap_magic/pmag_results.txt \
    -crd g -prj ortho -eye 60 0 -etp -sym wo 10 -fmt png -sav
# Out:
# 1  saved in  LO:_Snake River_VGP_map.png

# %%
Image(filename='LO:_Snake River_VGP_map.png')

# %% [markdown]
# # watsons_f.py

# %%
# !watsons_f.py -f ../data_files/watsonsF/watsonsF_example_file1.dat \
-f2 ../data_files/watsonsF/watsonsF_example_file2.dat
# Out:
#    5.23    3.26

# %% [markdown]
# # watsons_v.py

# %%
# !watsons_v.py -f ../data_files/watsonsF/watsonsF_example_file1.dat \
-f2 ../data_files/watsonsF/watsonsF_example_file2.dat -fmt png -sav
# Out:
# Watson's V,  Vcrit:
#          10.5        6.6
# 1  saved in  watsons_v_..-data_files-watsonsF-watsonsF_example_file1.dat_..-data_files-watsonsF-watsonsF_example_file2.dat.png

# %%
Image(filename="watsons_v_..-data_files-watsonsF-watsonsF_example_file1.dat_..-data_files-watsonsF-watsonsF_example_file2.dat.png")

# %% [markdown]
# # zeq.py
#
# This program requires interaction and can only be run from the command line.

# %% [markdown]
# # zeq_magic.py
#
# This program is no longer maintained.  It has been superceded by demag_gui.py

# %% [markdown]
# # cleanup the directory

# %%
# !rm *.png

# %%
# !rm *.txt
