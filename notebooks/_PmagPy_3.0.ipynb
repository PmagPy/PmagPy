# %%
#import pmagpy.ipmag as ipmag
import pmagpy.pmagplotlib as pmagplotlib
import pmagpy.pmag as pmag
from IPython.display import Image
import matplotlib as plt
import sys
# %matplotlib inline

# %%
# !python ../programs/eqarea_magic3.0.py -WD ../data_files/3_0/McMurdo -f sites.txt -sav -fmt "png"
Image(filename="LO:_McMurdo_SI:_mc01_SA:__SP:__CO:_g_TY:_eqarea_.png")
# Out:
# pmag_dir /Users/nebula/Python/PmagPy/
# -I- Importing controlled vocabularies from https://earthref.org
# 1  saved in  LO:_McMurdo_SI:_mc01_SA:__SP:__CO:_g_TY:_eqarea_.png

# %%
# !python ../programs/dmag_magic3.0.py -WD ../data_files/3_0/McMurdo -fsp specimens.txt -obj spc -sav -fmt "png" -LT T
# Out:
# pmag_dir /Users/nebula/Python/PmagPy/
# -I- Importing controlled vocabularies from https://earthref.org
# 25470  records read from  measurements.txt
# 1  saved in  mc01a_LT-T-Z.png
# 1  saved in  mc01b_LT-T-Z.png
# 1  saved in  mc01c_LT-T-Z.png
# 1  saved in  mc01d_LT-T-Z.png
# 1  saved in  mc01e_LT-T-Z.png
# 1  saved in  mc01g_LT-T-Z.png
# 1  saved in  mc01h_LT-T-Z.png
# 1  saved in  mc02a_LT-T-Z.png
# 1  saved in  mc02b_LT-T-Z.png
# 1  saved in  mc02f_LT-T-Z.png
# 1  saved in  mc02h_LT-T-Z.png
# 1  saved in  mc03a_LT-T-Z.png
# 1  saved in  mc03c_LT-T-Z.png
# 1  saved in  mc03f_LT-T-Z.png
# 1  saved in  mc03h_LT-T-Z.png
# 1  saved in  mc04b_LT-T-Z.png
# 1  saved in  mc04e_LT-T-Z.png
# 1  saved in  mc04f_LT-T-Z.png
# 1  saved in  mc04g_LT-T-Z.png
# 1  saved in  mc06a_LT-T-Z.png
# 1  saved in  mc06d_LT-T-Z.png
# 1  saved in  mc06g_LT-T-Z.png
# 1  saved in  mc06h_LT-T-Z.png
# 1  saved in  mc07b_LT-T-Z.png
# 1  saved in  mc07c_LT-T-Z.png
# 1  saved in  mc07d_LT-T-Z.png
# ...

# %%
Image(filename="mc01a_LT-T-Z.png")

# %%
Image("mc141c1_LT-T-Z.png")

# %%
# !python ../programs/dmag_magic3.0.py -WD ../data_files/3_0/McMurdo -fsp specimens.txt \
-fsa samples.txt -obj sit -sav -fmt "png" -LT T

# %%
Image(filename="mc01_LT-T-Z.png")

# %%
# !python ../programs/quick_hyst3.0.py -WD ../data_files/3_0/McMurdo -spc mc04c-1 -fmt png
#Image("LO:__SI:__SA:__SP:_mc04c-1_TY:_hyst_.png")
Image("LO:_McMurdo_SI:_mc04c_SA:_mc04c_SP:_mc04c-1_TY:_hyst_.png")

# %%
# !python ../programs/vgpmap_magic3.0.py -WD ../data_files/3_0/McMurdo -f sites.txt -crd g -prj ortho -eye 60 0  -sym ko 10 -fmt png -S -sav
Image("LO:_McMurdo_VGP_map.png")

# %%
# !python ../programs/dayplot_magic3.0.py -WD ../data_files/3_0/McMurdo -f specimens.txt -sav -fmt png

Image("LO:__SI:__SA:__SP:__TY:_day_.png")

# %%
# !python ../programs/aniso_magic3.0.py -WD ../data_files/3_0/McMurdo/ -B -x -par -crd g -f specimens.txt \
-fsa samples.txt -fsi sites.txt -sav -fmt png
Image("LO:_McMurdo_SI:__SA:__SP:__CO:_s_TY:_aniso-data_.png")

# %%
Image("LO:_McMurdo_SI:__SA:__SP:__CO:_s_TY:_aniso-conf_.png")

# %%
# !rm sites.txt samples.txt specimens.txt measurements.txt ages.txt contribution.txt images.txt criteria.txt locations.txt
# !rm *.png
# !rm *.jpg
# !rm ../data_files/3_0/McMurdo/_*.txt
# !rm ../data_files/3_0/McMurdo/fancy_sites.txt
# !rm ../data_files/3_0/Osler/_*.txt
# !rm ../data_files/3_0/_*.txt
# !rm stored.json
# !rm _*.txt
